# %% [markdown]
# ## **Task 1.4: Streaming Application**

# %% [markdown]
# ##### **Setup Spark Structured Streaming**

# %%
from pyspark.sql.types import  StructType, StructField, DoubleType, StringType
from pyspark.sql.functions import from_json, col
import os

os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.3.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0 pyspark-shell'

from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, element_at, when

#topic to subscribe
subscribe_topic = "climate_hotspot"

ip_address = "10.192.68.151"

#create spark structured streaming session
spark_session = (
    SparkSession.builder
    .master("local[*]")
    .appName("Analyse hotspot reports and match climate data")
    .getOrCreate()
)


#schema for deserialising stream data
deserialize_schema = StructType([
    StructField("producer_identifier", StringType()),
    StructField("GHI_w/m2", DoubleType()),
    StructField("precipitation ", StringType()),
    StructField("max_wind_speed", DoubleType()),
    StructField("windspeed_knots", DoubleType()),
    StructField("relative_humidity", DoubleType()),
    StructField("air_temperature_celcius", DoubleType()),
    StructField("longitude", DoubleType()),
    StructField("latitude", DoubleType()),
    StructField("date", StringType()),
    StructField("confidence", DoubleType()),
    StructField("surface_temperature_celcius", DoubleType()),
    StructField("created_time", StringType())
])

#create stream of dataframes from kafka topics
df_stream_kafka = (
    spark_session.readStream
        .format('kafka')
        .option('kafka.bootstrap.servers', f'{ip_address}:9092')
        .option('subscribe', subscribe_topic)
        .load()
)

#select only deserialised json data including only fields from climate/hotspot data
decoded_stream_kafka = (
    df_stream_kafka
        .select(from_json(col("value").cast("string"), deserialize_schema).alias("stream_data")) 
        .select("stream_data.*")
)

decoded_stream_kafka.printSchema()
# Out:
# root
#  |-- producer_identifier: string (nullable = true)
#  |-- GHI_w/m2: double (nullable = true)
#  |-- precipitation : string (nullable = true)
#  |-- max_wind_speed: double (nullable = true)
#  |-- windspeed_knots: double (nullable = true)
#  |-- relative_humidity: double (nullable = true)
#  |-- air_temperature_celcius: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- date: string (nullable = true)
#  |-- confidence: double (nullable = true)
#  |-- surface_temperature_celcius: double (nullable = true)
#  |-- created_time: string (nullable = true)

# %% [markdown]
# **Install geohashing library**

# %%
# !pip install python-geohash

# %% [markdown]
# ##### **Process streaming data and send to mongodb**

# %%
from pymongo import MongoClient
import geohash
from datetime import datetime, timedelta
from pprint import pprint

def merge_hotspots(hostspot_list):
    final_processed_hotspots = []
    geohashing_precision = 5
    processed_hotspot_ids = []  #store list indexes of hotspots already processed

    #match hotspot against every other hotspot in the list
    for i in range(len(hostspot_list)):
        hotspot_1 = hostspot_list[i]
        hotspot_1_hash = geohash.encode(hotspot_1["latitude"], hotspot_1["longitude"], geohashing_precision)
        hotspot_1_time = datetime.strptime(hotspot_1["created_time"], "%H:%M:%S")
        matched_hotspot_ids = []   #store list indexes of hotspots to be merged

        #skip hotspot if it has already been merged with another set
        if i in processed_hotspot_ids:
            continue 

        #iterate from i to end to skip hotspots that have already been processed
        for j in range(i+1, len(hostspot_list)):

            #skip hotspot if it has already been merged with another set
            if j in processed_hotspot_ids:
                continue 

            hotspot_2 = hostspot_list[j]
            hotspot_2_hash = geohash.encode(hotspot_2["latitude"], hotspot_2["longitude"], geohashing_precision)

            #check proximity
            if hotspot_1_hash == hotspot_2_hash:
                hotspot_2_time = datetime.strptime(hotspot_2["created_time"], "%H:%M:%S")
                time_diff = abs(hotspot_1_time - hotspot_2_time)

                #check if created time <= 10 mins
                if time_diff <= timedelta(minutes=10):
                    matched_hotspot_ids.append(j)   #store list indexes since it is to be merged
                    processed_hotspot_ids.append(j)

        
        matched_hotspot_ids.append(i)

        #merge hotspot data
        if len(matched_hotspot_ids) > 1:
            total_surface_temp = 0
            total_confidence = 0

            #calculate average surface temp and confidence for all hotspots to be merged
            for id in matched_hotspot_ids:
                total_surface_temp += hostspot_list[id]["surface_temperature_celcius"]
                total_confidence += hostspot_list[id]["confidence"]

            average_surface_temp = total_surface_temp/len(matched_hotspot_ids)
            average_confidence = total_confidence/len(matched_hotspot_ids)

            #merge hotspots by setting average temp and confidence and using remaining attributes of the first hotspot
            hostspot_list[i]["surface_temperature_celcius"] = average_surface_temp
            hostspot_list[i]["confidence"] = average_confidence

        #finally add ith hotspot to processed list
        if i not in processed_hotspot_ids:
            final_processed_hotspots.append(hostspot_list[i])
            processed_hotspot_ids.append(i)


    return final_processed_hotspots


def process_climate_hotspot(data):
    climate_data = None
    hotspots = []
                            
   #! Get climate report and hotspot report from batch
    for document in data:

        #get the last occurence of climate report in a batch and discard the rest
        if document["producer_identifier"] == "producer_1":
            climate_data = document

        #check if there are any hotspot reports in the current batch
        if (document["producer_identifier"] == "producer_2") or (document["producer_identifier"] == "producer_3"):
            hotspots.append(document)

    #return straight if no fire occurences or no climate report
    if (len(hotspots) == 0) or (climate_data == None):
        return climate_data
    
    #add embedded hotspots otherwise
    elif (len(hotspots) > 0) and (climate_data != None):
        climate_data["hotspots"] = []

    # Note: - If 'hotspots' field does not exist in climate_data, it implies no fire occurences for the day
    #       - But if 'hotspots' field exists in climate_data and is an empty list, it implies fires did occur on 
    #         that day but no fires were in proximity
    #       - Finally, if the 'hotspots' field is not an empty list, it implies fire occurences within proximity
    
    
    #! Merge reports for same hotspots
    merged_hotspots = merge_hotspots(hotspots)

    #! Climate-to-Hotspot matching
    geohashing_precision = 3
    
    #calculate proximity of climate report and hotspot report and process 
    for hotspot_data in merged_hotspots:
        hotspot_geohash = geohash.encode(hotspot_data["latitude"], hotspot_data["longitude"], geohashing_precision)
        climate_geohash = geohash.encode(climate_data["latitude"], climate_data["longitude"], geohashing_precision)

        #embed hotspot document if in proximity to climate report
        if climate_geohash == hotspot_geohash:
            filtered_hotspot_data = hotspot_data.copy()
            for field in hotspot_data.keys():
                if hotspot_data[field] == None:
                    filtered_hotspot_data.pop(field) #remove null fields added from climate fields in schema 

            climate_data["hotspots"].append(filtered_hotspot_data)

    #! Define cause of fire
    if (len(climate_data["hotspots"]) > 0):
        if (climate_data["air_temperature_celcius"] > 20) and (climate_data["GHI_w/m2"] > 180):
            climate_data["cause_of_fire"] = "natural"
        else:
            climate_data["cause_of_fire"] = "other"

    return climate_data


def store_to_mongodb(data_document):
    mongo_client = MongoClient(ip_address, 27017) #setup mongo client
    db = mongo_client["fit3182_assignment_db"]  #create or get database 
    streaming_climate_col = db.climates_streaming #get/create collection for streaming climate data
    streaming_climate_col.insert_one(data_document)  #store processed documents 


def process_stream(batch_df, batch_id):
    batch_df.show()  #uncomment to see batch data

    unprocessed_data = batch_df.collect()  #collect streaming data
    data_row_dicts = [entry.asDict() for entry in unprocessed_data]  #convert rows to dictionaries (documents)

    #process all data as required
    processed_climate_report = process_climate_hotspot(data_row_dicts)

    #remove null fields added from hotspot fields in schema
    if processed_climate_report != None:
        filtered_climate_report = processed_climate_report.copy()
        for field in processed_climate_report.keys():
            if processed_climate_report[field] == None:
                filtered_climate_report.pop(field)  
        
        #store data in mongodb
        store_to_mongodb(filtered_climate_report)
        print("Batch Result: Climate report produced below")
        pprint(filtered_climate_report)  
                
    else:
        print("Batch Result: No climate report in the current batch")
        

#writing stream data to data source (mongodb)
data_writer = (
    decoded_stream_kafka.writeStream
        .outputMode("append")
        .trigger(processingTime="10 seconds")   #process in batches of 10 seconds
        .foreachBatch(process_stream)
)

# %% [markdown]
# ##### **Begin data writer**

# %%
from pyspark.sql.streaming import StreamingQueryException

q_writer = data_writer

try:
    query = q_writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopped query')
except StreamingQueryException as exception:
    print(exception)
finally:
    query.stop()
# Out:
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----+----------+---------------------------+------------+
# |producer_identifier|GHI_w/m2|precipitation |max_wind_speed|windspeed_knots|relative_humidity|air_temperature_celcius|longitude|latitude|date|confidence|surface_temperature_celcius|created_time|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----+----------+---------------------------+------------+
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----+----------+---------------------------+------------+
#
# Batch Result: No climate report in the current batch
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
# |producer_identifier|GHI_w/m2|precipitation |max_wind_speed|windspeed_knots|relative_humidity|air_temperature_celcius|longitude|latitude|      date|confidence|surface_temperature_celcius|created_time|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
# |         producer_2|    null|          null|          null|           null|             null|                   null| 141.7446|-36.0895|      null|      74.0|                       48.0|    12:54:24|
# |         producer_2|    null|          null|          null|           null|             null|                   null| 146.2785| -36.102|      null|      80.0|                       53.0|    21:20:43|
# |         producer_1|   163.0|         0.00I|          11.1|            6.6|             61.1|                   21.0|  146.791| -37.189|2024-01-09|      null|                       null|        null|
# |         producer_3|    null|          null|          null|           null|             null|                   null| 142.5465|-37.9284|      null|      78.0|                       51.0|    06:52:14|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
#
# Batch Result: Climate report produced below
# {'GHI_w/m2': 163.0,
#  '_id': ObjectId('66540c71e28fd35c83db0dd3'),
#  'air_temperature_celcius': 21.0,
#  'date': '2024-01-09',
#  'hotspots': [],
#  'latitude': -37.189,
#  'longitude': 146.791,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 61.1,
#  'windspeed_knots': 6.6}
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
# |producer_identifier|GHI_w/m2|precipitation |max_wind_speed|windspeed_knots|relative_humidity|air_temperature_celcius|longitude|latitude|      date|confidence|surface_temperature_celcius|created_time|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
# |         producer_3|    null|          null|          null|           null|             null|                   null| 147.2512|-37.8475|      null|      76.0|                       50.0|    13:59:33|
# |         producer_1|    65.0|         0.12G|          15.0|            8.1|             40.5|                    7.0|  148.073| -37.336|2024-01-10|      null|                       null|        null|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
#
# Batch Result: Climate report produced below
# {'GHI_w/m2': 65.0,
#  '_id': ObjectId('66540c7be28fd35c83db0dd5'),
#  'air_temperature_celcius': 7.0,
#  'date': '2024-01-10',
#  'hotspots': [],
#  'latitude': -37.336,
#  'longitude': 148.073,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.5,
#  'windspeed_knots': 8.1}
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
# |producer_identifier|GHI_w/m2|precipitation |max_wind_speed|windspeed_knots|relative_humidity|air_temperature_celcius|longitude|latitude|      date|confidence|surface_temperature_celcius|created_time|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
# |         producer_2|    null|          null|          null|           null|             null|                   null|  143.375| -37.332|      null|      64.0|                       46.0|    06:10:53|
# |         producer_1|   105.0|         0.00G|          15.0|            8.8|             47.2|                   12.0|  141.078| -35.953|2024-01-11|      null|                       null|        null|
# |         producer_3|    null|          null|          null|           null|             null|                   null| 143.7526|-36.3883|      null|      56.0|                       39.0|    18:53:28|
# |         producer_3|    null|          null|          null|           null|             null|                   null| 142.4773|-36.4622|      null|      83.0|                       57.0|    16:01:13|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
#
# Batch Result: Climate report produced below
# {'GHI_w/m2': 105.0,
#  '_id': ObjectId('66540c85e28fd35c83db0dd7'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-01-11',
#  'hotspots': [],
#  'latitude': -35.953,
#  'longitude': 141.078,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 47.2,
#  'windspeed_knots': 8.8}
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
# |producer_identifier|GHI_w/m2|precipitation |max_wind_speed|windspeed_knots|relative_humidity|air_temperature_celcius|longitude|latitude|      date|confidence|surface_temperature_celcius|created_time|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
# |         producer_1|   159.0|         0.00I|          22.9|           16.8|             38.7|                   17.0| 142.5679|-35.2881|2024-01-12|      null|                       null|        null|
# |         producer_2|    null|          null|          null|           null|             null|                   null|  143.605|  -37.69|      null|      97.0|                       80.0|    21:15:43|
# +-------------------+--------+--------------+--------------+---------------+-----------------+-----------------------+---------+--------+----------+----------+---------------------------+------------+
#
# Batch Result: Climate report produced below
# {'GHI_w/m2': 159.0,
#  '_id': ObjectId('66540c8fe28fd35c83db0dd9'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-01-12',
#  'hotspots': [],
#  'latitude': -35.2881,
#  'longitude': 142.5679,
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 38.7,
#  'windspeed_knots': 16.8}
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/opt/conda/lib/python3.8/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# Interrupted by CTRL-C. Stopped query

# %% [markdown]
# ##### **Check data stored in mongodb collection**

# %%
from pprint import pprint
from pymongo import MongoClient

mongo_client = MongoClient(ip_address, 27017) 
db = mongo_client["fit3182_assignment_db"] 
streaming_climate_col = db.climates_streaming

data = streaming_climate_col.find()
for doc in data:
    pprint(doc)
# Out:
# {'GHI_w/m2': 66.0,
#  '_id': ObjectId('664f23ff7de308e5b7252811'),
#  'air_temperature_celcius': 7.0,
#  'date': '2024-01-06',
#  'hotspots': [],
#  'latitude': -36.3328,
#  'longitude': 146.0355,
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 37.2,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 117.0,
#  '_id': ObjectId('664f24087de308e5b7252813'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-01-07',
#  'latitude': -36.7084,
#  'longitude': 142.7354,
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.1,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 121.0,
#  '_id': ObjectId('664f24137de308e5b7252815'),
#  'air_temperature_celcius': 14.0,
#  'cause_of_fire': 'other',
#  'date': '2024-01-08',
#  'hotspots': [{'confidence': 77.0,
#                'created_time': '22:22:31',
#                'latitude': -37.6974,
#                'longitude': 142.9716,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 50.0}],
#  'latitude': -37.858,
#  'longitude': 143.428,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.5,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 105.0,
#  '_id': ObjectId('664f241d7de308e5b7252817'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-01-09',
#  'hotspots': [],
#  'latitude': -37.415,
#  'longitude': 148.105,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 47.0,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 93.0,
#  '_id': ObjectId('664f24277de308e5b7252819'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-01-10',
#  'hotspots': [],
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 39.4,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 143.0,
#  '_id': ObjectId('664f24317de308e5b725281b'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-01-11',
#  'hotspots': [],
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.9,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 65.0,
#  '_id': ObjectId('664f243a7de308e5b725281d'),
#  'air_temperature_celcius': 7.0,
#  'date': '2024-01-12',
#  'hotspots': [],
#  'latitude': -38.5,
#  'longitude': 146.938,
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.7,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 155.0,
#  '_id': ObjectId('664f24457de308e5b725281f'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-01-13',
#  'hotspots': [],
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.4,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 163.0,
#  '_id': ObjectId('664f244e7de308e5b7252821'),
#  'air_temperature_celcius': 20.0,
#  'date': '2024-01-14',
#  'hotspots': [],
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 55.8,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 161.0,
#  '_id': ObjectId('664f24597de308e5b7252823'),
#  'air_temperature_celcius': 20.0,
#  'date': '2024-01-15',
#  'hotspots': [],
#  'latitude': -36.277,
#  'longitude': 146.165,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 57.0,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 202.0,
#  '_id': ObjectId('664f24627de308e5b7252825'),
#  'air_temperature_celcius': 24.0,
#  'cause_of_fire': 'natural',
#  'date': '2024-01-16',
#  'hotspots': [{'confidence': 79.0,
#                'created_time': '03:22:34',
#                'latitude': -37.639,
#                'longitude': 142.0648,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 52.0}],
#  'latitude': -37.6662,
#  'longitude': 142.9874,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 51.9,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664f246c7de308e5b7252827'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-01-17',
#  'hotspots': [],
#  'latitude': -35.954,
#  'longitude': 141.076,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.13B',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.1,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 159.0,
#  '_id': ObjectId('664f24767de308e5b7252829'),
#  'air_temperature_celcius': 20.0,
#  'date': '2024-01-18',
#  'hotspots': [],
#  'latitude': -36.1858,
#  'longitude': 143.885,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.4,
#  'windspeed_knots': 4.7}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('664f24807de308e5b725282b'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-01-19',
#  'hotspots': [],
#  'latitude': -35.957,
#  'longitude': 141.088,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.4,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 196.0,
#  '_id': ObjectId('664f248a7de308e5b725282d'),
#  'air_temperature_celcius': 24.0,
#  'date': '2024-01-20',
#  'hotspots': [],
#  'latitude': -36.291,
#  'longitude': 146.159,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 55.4,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 113.0,
#  '_id': ObjectId('664f24947de308e5b725282f'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-01-21',
#  'hotspots': [],
#  'latitude': -37.459,
#  'longitude': 148.092,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 48.5,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 124.0,
#  '_id': ObjectId('664f249e7de308e5b7252831'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-01-22',
#  'hotspots': [],
#  'latitude': -37.692,
#  'longitude': 143.593,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 45.8,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 158.0,
#  '_id': ObjectId('664f24a87de308e5b7252833'),
#  'air_temperature_celcius': 19.0,
#  'date': '2024-01-23',
#  'hotspots': [],
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.8,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 113.0,
#  '_id': ObjectId('664f24b27de308e5b7252835'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-01-24',
#  'hotspots': [],
#  'latitude': -35.325,
#  'longitude': 143.497,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 48.5,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 120.0,
#  '_id': ObjectId('664f24bc7de308e5b7252837'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-01-25',
#  'hotspots': [],
#  'latitude': -36.752,
#  'longitude': 144.15,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.4,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 122.0,
#  '_id': ObjectId('664f24c67de308e5b7252839'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-01-26',
#  'hotspots': [],
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 56.1,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 73.0,
#  '_id': ObjectId('664f24d07de308e5b725283b'),
#  'air_temperature_celcius': 8.0,
#  'date': '2024-01-27',
#  'latitude': -37.477,
#  'longitude': 148.097,
#  'max_wind_speed': 6.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.6,
#  'windspeed_knots': 2.0}
# {'GHI_w/m2': 88.0,
#  '_id': ObjectId('664f24da7de308e5b725283d'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-01-28',
#  'hotspots': [],
#  'latitude': -38.116,
#  'longitude': 143.818,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.8,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 102.0,
#  '_id': ObjectId('664f24e47de308e5b725283f'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-01-29',
#  'hotspots': [],
#  'latitude': -36.7179,
#  'longitude': 142.2536,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.04G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.4,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 138.0,
#  '_id': ObjectId('664f24ee7de308e5b7252841'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-01-30',
#  'hotspots': [],
#  'latitude': -37.396,
#  'longitude': 148.086,
#  'max_wind_speed': 28.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 41.6,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 121.0,
#  '_id': ObjectId('664f24f87de308e5b7252843'),
#  'air_temperature_celcius': 14.0,
#  'cause_of_fire': 'other',
#  'date': '2024-01-31',
#  'hotspots': [{'confidence': 85.0,
#                'created_time': '08:14:22',
#                'latitude': -37.9052,
#                'longitude': 143.3512,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 60.0}],
#  'latitude': -37.858,
#  'longitude': 143.428,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.5,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 149.0,
#  '_id': ObjectId('664f25027de308e5b7252845'),
#  'air_temperature_celcius': 18.0,
#  'cause_of_fire': 'other',
#  'date': '2024-02-01',
#  'hotspots': [{'confidence': 69.0,
#                'created_time': '05:10:12',
#                'latitude': -37.6339,
#                'longitude': 143.4108,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 46.0},
#               {'confidence': 66.0,
#                'created_time': '09:34:23',
#                'latitude': -37.5074,
#                'longitude': 142.976,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 43.0}],
#  'latitude': -37.6767,
#  'longitude': 142.9892,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.8,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 99.0,
#  '_id': ObjectId('664f250c7de308e5b7252847'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-02-02',
#  'hotspots': [],
#  'latitude': -37.365,
#  'longitude': 148.052,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 43.8,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 183.0,
#  '_id': ObjectId('664f25167de308e5b7252849'),
#  'air_temperature_celcius': 23.0,
#  'date': '2024-02-03',
#  'hotspots': [],
#  'latitude': -36.2229,
#  'longitude': 143.4245,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.8,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 199.0,
#  '_id': ObjectId('664f25207de308e5b725284b'),
#  'air_temperature_celcius': 25.0,
#  'date': '2024-02-04',
#  'hotspots': [],
#  'latitude': -37.583,
#  'longitude': 149.316,
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.04G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 133.0,
#  '_id': ObjectId('664f252a7de308e5b725284d'),
#  'air_temperature_celcius': 16.0,
#  'cause_of_fire': 'other',
#  'date': '2024-02-05',
#  'hotspots': [{'confidence': 100.0,
#                'created_time': '19:41:10',
#                'latitude': -37.5701,
#                'longitude': 142.6497,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 94.0}],
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.6,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 142.0,
#  '_id': ObjectId('664f25347de308e5b725284f'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-02-06',
#  'hotspots': [],
#  'latitude': -37.9243,
#  'longitude': 144.1064,
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.0,
#  'windspeed_knots': 14.6}
# {'GHI_w/m2': 199.0,
#  '_id': ObjectId('664f253e7de308e5b7252851'),
#  'air_temperature_celcius': 25.0,
#  'date': '2024-02-07',
#  'hotspots': [],
#  'latitude': -37.583,
#  'longitude': 149.316,
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.04G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 88.0,
#  '_id': ObjectId('664f25487de308e5b7252853'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-02-08',
#  'hotspots': [],
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.3,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 138.0,
#  '_id': ObjectId('664f25527de308e5b7252855'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-02-09',
#  'hotspots': [],
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'max_wind_speed': 28.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 41.5,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 88.0,
#  '_id': ObjectId('664f255c7de308e5b7252857'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-02-10',
#  'hotspots': [],
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.3,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 173.0,
#  '_id': ObjectId('664f25667de308e5b7252859'),
#  'air_temperature_celcius': 21.0,
#  'cause_of_fire': 'other',
#  'date': '2024-02-11',
#  'hotspots': [{'confidence': 82.0,
#                'created_time': '04:01:06',
#                'latitude': -36.5757,
#                'longitude': 143.8756,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 55.0}],
#  'latitude': -37.946,
#  'longitude': 144.342,
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 54.9,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 123.0,
#  '_id': ObjectId('664f25707de308e5b725285b'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-02-12',
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 47.4,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664f257a7de308e5b725285d'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-02-13',
#  'hotspots': [],
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.6,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 147.0,
#  '_id': ObjectId('664f25847de308e5b725285f'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-02-14',
#  'hotspots': [],
#  'latitude': -36.0201,
#  'longitude': 143.7775,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 55.6,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 90.0,
#  '_id': ObjectId('664f258e7de308e5b7252861'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-02-15',
#  'hotspots': [],
#  'latitude': -37.013,
#  'longitude': 141.5355,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.39G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.1,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 129.0,
#  '_id': ObjectId('664f25987de308e5b7252863'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-02-16',
#  'hotspots': [],
#  'latitude': -37.472,
#  'longitude': 148.119,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.9,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 99.0,
#  '_id': ObjectId('664f25a27de308e5b7252865'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-02-17',
#  'hotspots': [],
#  'latitude': -36.2212,
#  'longitude': 143.1666,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.2,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 65.0,
#  '_id': ObjectId('664f25ad7de308e5b7252867'),
#  'air_temperature_celcius': 7.0,
#  'date': '2024-02-18',
#  'hotspots': [],
#  'latitude': -37.336,
#  'longitude': 148.073,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.5,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664f25b67de308e5b7252869'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-02-19',
#  'hotspots': [],
#  'latitude': -35.892,
#  'longitude': 145.62,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.04G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.6,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 129.0,
#  '_id': ObjectId('664f25c17de308e5b725286b'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-02-20',
#  'hotspots': [],
#  'latitude': -37.472,
#  'longitude': 148.119,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.9,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 93.0,
#  '_id': ObjectId('664f25cb7de308e5b725286d'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-02-21',
#  'hotspots': [],
#  'latitude': -36.984,
#  'longitude': 148.25,
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 39.9,
#  'windspeed_knots': 12.6}
# {'GHI_w/m2': 120.0,
#  '_id': ObjectId('664f25d57de308e5b725286f'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-02-22',
#  'hotspots': [],
#  'latitude': -35.962,
#  'longitude': 143.791,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.9,
#  'windspeed_knots': 6.8}
# {'GHI_w/m2': 89.0,
#  '_id': ObjectId('664f25de7de308e5b7252871'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-02-23',
#  'hotspots': [],
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 45.7,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 102.0,
#  '_id': ObjectId('664f25e97de308e5b7252873'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-02-24',
#  'hotspots': [],
#  'latitude': -37.57,
#  'longitude': 148.034,
#  'max_wind_speed': 26.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.4,
#  'windspeed_knots': 19.3}
# {'GHI_w/m2': 90.0,
#  '_id': ObjectId('664f25f37de308e5b7252875'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-02-25',
#  'hotspots': [],
#  'latitude': -37.448,
#  'longitude': 148.114,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.4,
#  'windspeed_knots': 5.6}
# {'GHI_w/m2': 80.0,
#  '_id': ObjectId('664f25fd7de308e5b7252877'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-02-26',
#  'latitude': -36.851,
#  'longitude': 148.117,
#  'max_wind_speed': 6.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 45.3,
#  'windspeed_knots': 2.5}
# {'GHI_w/m2': 109.0,
#  '_id': ObjectId('664f26077de308e5b7252879'),
#  'air_temperature_celcius': 12.0,
#  'cause_of_fire': 'other',
#  'date': '2024-02-27',
#  'hotspots': [{'confidence': 63.0,
#                'created_time': '10:52:26',
#                'latitude': -37.0207,
#                'longitude': 141.4778,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 41.0}],
#  'latitude': -37.9072,
#  'longitude': 141.9183,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 43.3,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 115.0,
#  '_id': ObjectId('664f26117de308e5b725287b'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-02-28',
#  'hotspots': [],
#  'latitude': -36.6511,
#  'longitude': 143.915,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.2,
#  'windspeed_knots': 5.6}
# {'GHI_w/m2': 119.0,
#  '_id': ObjectId('664f261b7de308e5b725287d'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-02-29',
#  'hotspots': [],
#  'latitude': -37.461,
#  'longitude': 148.109,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.7,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 84.0,
#  '_id': ObjectId('664f26257de308e5b725287f'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-03-01',
#  'hotspots': [],
#  'latitude': -37.434,
#  'longitude': 148.091,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.0,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 129.0,
#  '_id': ObjectId('664f262f7de308e5b7252881'),
#  'air_temperature_celcius': 15.0,
#  'cause_of_fire': 'other',
#  'date': '2024-03-02',
#  'hotspots': [{'confidence': 71.0,
#                'created_time': '12:43:44',
#                'latitude': -36.346,
#                'longitude': 143.631,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 49.0}],
#  'latitude': -35.323,
#  'longitude': 143.509,
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.3,
#  'windspeed_knots': 3.6}
# {'GHI_w/m2': 138.0,
#  '_id': ObjectId('664f26397de308e5b7252883'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-03-03',
#  'hotspots': [],
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'max_wind_speed': 28.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 41.5,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664f26437de308e5b7252885'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-03-04',
#  'hotspots': [],
#  'latitude': -37.247,
#  'longitude': 141.27,
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 43.1,
#  'windspeed_knots': 4.7}
# {'GHI_w/m2': 76.0,
#  '_id': ObjectId('664f264d7de308e5b7252887'),
#  'air_temperature_celcius': 8.0,
#  'date': '2024-03-05',
#  'hotspots': [],
#  'latitude': -36.1346,
#  'longitude': 145.2196,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 37.2,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 161.0,
#  '_id': ObjectId('664f26577de308e5b7252889'),
#  'air_temperature_celcius': 19.0,
#  'date': '2024-03-06',
#  'hotspots': [],
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 51.5,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 183.0,
#  '_id': ObjectId('664f26617de308e5b725288b'),
#  'air_temperature_celcius': 23.0,
#  'date': '2024-03-07',
#  'hotspots': [],
#  'latitude': -36.2127,
#  'longitude': 141.4938,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.8,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 156.0,
#  '_id': ObjectId('664f266a7de308e5b725288d'),
#  'air_temperature_celcius': 19.0,
#  'date': '2024-03-08',
#  'hotspots': [],
#  'latitude': -36.4553,
#  'longitude': 142.8786,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 55.3,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664f26757de308e5b725288f'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-03-09',
#  'hotspots': [],
#  'latitude': -35.892,
#  'longitude': 145.62,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.04G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.6,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 156.0,
#  '_id': ObjectId('664f267e7de308e5b7252891'),
#  'air_temperature_celcius': 20.0,
#  'date': '2024-03-10',
#  'hotspots': [],
#  'latitude': -37.1405,
#  'longitude': 144.1375,
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 60.8,
#  'windspeed_knots': 10.4}
# {'GHI_w/m2': 77.0,
#  '_id': ObjectId('664f26897de308e5b7252893'),
#  'air_temperature_celcius': 8.0,
#  'date': '2024-03-11',
#  'hotspots': [],
#  'latitude': -37.5268,
#  'longitude': 143.0551,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 35.0,
#  'windspeed_knots': 14.4}
# {'GHI_w/m2': 223.0,
#  '_id': ObjectId('664f26937de308e5b7252895'),
#  'air_temperature_celcius': 28.0,
#  'date': '2024-03-12',
#  'hotspots': [],
#  'latitude': -37.1875,
#  'longitude': 146.8024,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 121.0,
#  '_id': ObjectId('664f269d7de308e5b7252897'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-03-13',
#  'hotspots': [],
#  'latitude': -35.889,
#  'longitude': 145.614,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.2,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 131.0,
#  '_id': ObjectId('664f26a77de308e5b7252899'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-03-14',
#  'latitude': -36.8264,
#  'longitude': 142.6138,
#  'max_wind_speed': 25.1,
#  'precipitation ': ' 0.43G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 48.2,
#  'windspeed_knots': 14.7}
# {'GHI_w/m2': 200.0,
#  '_id': ObjectId('664f26b17de308e5b725289b'),
#  'air_temperature_celcius': 24.0,
#  'date': '2024-03-15',
#  'hotspots': [],
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.4,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 158.0,
#  '_id': ObjectId('664f26bb7de308e5b725289d'),
#  'air_temperature_celcius': 21.0,
#  'date': '2024-03-16',
#  'hotspots': [],
#  'latitude': -37.623,
#  'longitude': 149.284,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 1.26G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 64.5,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 142.0,
#  '_id': ObjectId('664f26c57de308e5b725289f'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-03-17',
#  'hotspots': [],
#  'latitude': -37.9243,
#  'longitude': 144.1064,
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.0,
#  'windspeed_knots': 14.6}
# {'GHI_w/m2': 169.0,
#  '_id': ObjectId('664f26cf7de308e5b72528a1'),
#  'air_temperature_celcius': 21.0,
#  'date': '2024-03-18',
#  'hotspots': [],
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 57.3,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('664f26d87de308e5b72528a3'),
#  'air_temperature_celcius': 19.0,
#  'cause_of_fire': 'other',
#  'date': '2024-03-19',
#  'hotspots': [{'confidence': 75.0,
#                'created_time': '23:47:05',
#                'latitude': -36.0189,
#                'longitude': 145.6844,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 49.0}],
#  'latitude': -36.285,
#  'longitude': 146.151,
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 56.3,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 72.0,
#  '_id': ObjectId('664f26e37de308e5b72528a5'),
#  'air_temperature_celcius': 8.0,
#  'date': '2024-03-20',
#  'hotspots': [],
#  'latitude': -38.495,
#  'longitude': 146.944,
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.39G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.6,
#  'windspeed_knots': 3.9}
# {'GHI_w/m2': 145.0,
#  '_id': ObjectId('664f26ed7de308e5b72528a7'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-03-21',
#  'hotspots': [],
#  'latitude': -37.63,
#  'longitude': 149.232,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 57.0,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('664f26f77de308e5b72528a9'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-03-22',
#  'hotspots': [],
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.9,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 186.0,
#  '_id': ObjectId('664f27017de308e5b72528ab'),
#  'air_temperature_celcius': 24.0,
#  'date': '2024-03-23',
#  'hotspots': [],
#  'latitude': -38.231,
#  'longitude': 147.172,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 61.6,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 169.0,
#  '_id': ObjectId('664f270b7de308e5b72528ad'),
#  'air_temperature_celcius': 21.0,
#  'date': '2024-03-24',
#  'hotspots': [],
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 57.3,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 196.0,
#  '_id': ObjectId('664f27157de308e5b72528af'),
#  'air_temperature_celcius': 24.0,
#  'date': '2024-03-25',
#  'hotspots': [],
#  'latitude': -36.291,
#  'longitude': 146.159,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 55.4,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 186.0,
#  '_id': ObjectId('664f271f7de308e5b72528b1'),
#  'air_temperature_celcius': 24.0,
#  'date': '2024-03-26',
#  'hotspots': [],
#  'latitude': -38.231,
#  'longitude': 147.172,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 61.6,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('664f27297de308e5b72528b3'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-03-27',
#  'hotspots': [],
#  'latitude': -36.8741,
#  'longitude': 143.91,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 41.9,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 99.0,
#  '_id': ObjectId('664f27337de308e5b72528b5'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-03-28',
#  'hotspots': [],
#  'latitude': -37.465,
#  'longitude': 148.153,
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 43.5,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 77.0,
#  '_id': ObjectId('664f273d7de308e5b72528b7'),
#  'air_temperature_celcius': 8.0,
#  'cause_of_fire': 'other',
#  'date': '2024-03-29',
#  'hotspots': [{'confidence': 84.0,
#                'created_time': '16:43:01',
#                'latitude': -36.8292,
#                'longitude': 142.1692,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 58.0}],
#  'latitude': -37.5268,
#  'longitude': 143.0551,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 35.0,
#  'windspeed_knots': 14.4}
# {'GHI_w/m2': 117.0,
#  '_id': ObjectId('664f27467de308e5b72528b9'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-03-30',
#  'latitude': -37.588,
#  'longitude': 141.259,
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.98G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 52.8,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 120.0,
#  '_id': ObjectId('664f27517de308e5b72528bb'),
#  'air_temperature_celcius': 14.0,
#  'cause_of_fire': 'other',
#  'date': '2024-03-31',
#  'hotspots': [{'confidence': 50.0,
#                'created_time': '06:20:12',
#                'latitude': -37.2166,
#                'longitude': 143.8674,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 38.0}],
#  'latitude': -36.752,
#  'longitude': 144.15,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.4,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 134.0,
#  '_id': ObjectId('664f275b7de308e5b72528bd'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-04-01',
#  'hotspots': [],
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 36.0,
#  'windspeed_knots': 15.9}
# {'GHI_w/m2': 106.0,
#  '_id': ObjectId('664f27647de308e5b72528bf'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-04-02',
#  'hotspots': [],
#  'latitude': -36.2693,
#  'longitude': 143.1768,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.6,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 140.0,
#  '_id': ObjectId('664f276f7de308e5b72528c1'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-04-03',
#  'hotspots': [],
#  'latitude': -36.701,
#  'longitude': 142.538,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.28G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 61.5,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 92.0,
#  '_id': ObjectId('664f27797de308e5b72528c3'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-04-04',
#  'hotspots': [],
#  'latitude': -37.497,
#  'longitude': 147.266,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 41.0,
#  'windspeed_knots': 14.1}
# {'GHI_w/m2': 130.0,
#  '_id': ObjectId('664f27837de308e5b72528c5'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-04-05',
#  'hotspots': [],
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.1,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 119.0,
#  '_id': ObjectId('664f278d7de308e5b72528c7'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-04-06',
#  'hotspots': [],
#  'latitude': -37.38,
#  'longitude': 148.053,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 51.0,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 73.0,
#  '_id': ObjectId('664f27977de308e5b72528c9'),
#  'air_temperature_celcius': 8.0,
#  'date': '2024-04-07',
#  'hotspots': [],
#  'latitude': -37.475,
#  'longitude': 148.134,
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 43.1,
#  'windspeed_knots': 3.4}
# {'GHI_w/m2': 136.0,
#  '_id': ObjectId('664f27a17de308e5b72528cb'),
#  'air_temperature_celcius': 16.0,
#  'date': '2024-04-08',
#  'hotspots': [],
#  'latitude': -36.293,
#  'longitude': 146.148,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.8,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 108.0,
#  '_id': ObjectId('664f27ab7de308e5b72528cd'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-04-09',
#  'hotspots': [],
#  'latitude': -37.7836,
#  'longitude': 141.4711,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.5,
#  'windspeed_knots': 11.1}
# {'GHI_w/m2': 99.0,
#  '_id': ObjectId('664f27b57de308e5b72528cf'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-04-10',
#  'hotspots': [],
#  'latitude': -37.365,
#  'longitude': 148.052,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 43.8,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 169.0,
#  '_id': ObjectId('664f27be7de308e5b72528d1'),
#  'air_temperature_celcius': 21.0,
#  'date': '2024-04-11',
#  'hotspots': [],
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 57.3,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 134.0,
#  '_id': ObjectId('664f27c97de308e5b72528d3'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-04-12',
#  'hotspots': [],
#  'latitude': -37.6745,
#  'longitude': 142.9848,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.5,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('664f27d37de308e5b72528d5'),
#  'air_temperature_celcius': 20.0,
#  'cause_of_fire': 'other',
#  'date': '2024-04-13',
#  'hotspots': [{'confidence': 83.0,
#                'created_time': '09:20:42',
#                'latitude': -38.2661,
#                'longitude': 143.9672,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 56.0}],
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 62.2,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 177.0,
#  '_id': ObjectId('664f27dd7de308e5b72528d7'),
#  'air_temperature_celcius': 21.0,
#  'date': '2024-04-14',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 51.7,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 114.0,
#  '_id': ObjectId('664f27e77de308e5b72528d9'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-04-15',
#  'hotspots': [],
#  'latitude': -36.3756,
#  'longitude': 143.7243,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 47.1,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 183.0,
#  '_id': ObjectId('664f27f17de308e5b72528db'),
#  'air_temperature_celcius': 23.0,
#  'date': '2024-04-16',
#  'hotspots': [],
#  'latitude': -36.2127,
#  'longitude': 141.4938,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.8,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 177.0,
#  '_id': ObjectId('664f27fb7de308e5b72528dd'),
#  'air_temperature_celcius': 21.0,
#  'cause_of_fire': 'other',
#  'date': '2024-04-17',
#  'hotspots': [{'confidence': 84.0,
#                'created_time': '03:45:03',
#                'latitude': -36.6152,
#                'longitude': 142.4911,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 58.0}],
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 51.7,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 111.0,
#  '_id': ObjectId('664f28057de308e5b72528df'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-04-18',
#  'hotspots': [],
#  'latitude': -37.858,
#  'longitude': 143.428,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.4,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 161.0,
#  '_id': ObjectId('664f280f7de308e5b72528e1'),
#  'air_temperature_celcius': 20.0,
#  'date': '2024-04-19',
#  'hotspots': [],
#  'latitude': -36.277,
#  'longitude': 146.165,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 57.0,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 159.0,
#  '_id': ObjectId('664f28197de308e5b72528e3'),
#  'air_temperature_celcius': 19.0,
#  'date': '2024-04-20',
#  'hotspots': [],
#  'latitude': -38.0427,
#  'longitude': 141.0271,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 52.9,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 136.0,
#  '_id': ObjectId('664f28237de308e5b72528e5'),
#  'air_temperature_celcius': 16.0,
#  'date': '2024-04-21',
#  'hotspots': [],
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 51.0,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 97.0,
#  '_id': ObjectId('664f282d7de308e5b72528e7'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-04-22',
#  'hotspots': [],
#  'latitude': -37.47,
#  'longitude': 148.089,
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.4,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 216.0,
#  '_id': ObjectId('664f28367de308e5b72528e9'),
#  'air_temperature_celcius': 26.0,
#  'date': '2024-04-23',
#  'hotspots': [],
#  'latitude': -37.627,
#  'longitude': 149.261,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.7,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 163.0,
#  '_id': ObjectId('664f28417de308e5b72528eb'),
#  'air_temperature_celcius': 20.0,
#  'date': '2024-04-24',
#  'hotspots': [],
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 55.8,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 134.0,
#  '_id': ObjectId('664f284a7de308e5b72528ed'),
#  'air_temperature_celcius': 14.0,
#  'cause_of_fire': 'other',
#  'date': '2024-04-25',
#  'hotspots': [{'confidence': 76.0,
#                'created_time': '16:59:46',
#                'latitude': -36.7204,
#                'longitude': 142.3638,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 50.0}],
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 36.0,
#  'windspeed_knots': 15.9}
# {'GHI_w/m2': 119.0,
#  '_id': ObjectId('664f28557de308e5b72528ef'),
#  'air_temperature_celcius': 14.0,
#  'cause_of_fire': 'other',
#  'date': '2024-04-26',
#  'hotspots': [{'confidence': 92.0,
#                'created_time': '17:03:00',
#                'latitude': -36.098,
#                'longitude': 143.74,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 67.0}],
#  'latitude': -36.3769,
#  'longitude': 144.7505,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.9,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 108.0,
#  '_id': ObjectId('664f285e7de308e5b72528f1'),
#  'air_temperature_celcius': 12.0,
#  'cause_of_fire': 'other',
#  'date': '2024-04-27',
#  'hotspots': [{'confidence': 75.0,
#                'created_time': '13:30:01',
#                'latitude': -37.4716,
#                'longitude': 143.2027,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 49.0}],
#  'latitude': -37.8072,
#  'longitude': 142.2406,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.2,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 141.0,
#  '_id': ObjectId('664f28687de308e5b72528f3'),
#  'air_temperature_celcius': 16.0,
#  'date': '2024-04-28',
#  'hotspots': [],
#  'latitude': -37.591,
#  'longitude': 149.33,
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.7,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 139.0,
#  '_id': ObjectId('664f28737de308e5b72528f5'),
#  'air_temperature_celcius': 16.0,
#  'date': '2024-04-29',
#  'hotspots': [],
#  'latitude': -37.61,
#  'longitude': 149.296,
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 48.3,
#  'windspeed_knots': 14.4}
# {'GHI_w/m2': 92.0,
#  '_id': ObjectId('664f287d7de308e5b72528f7'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-04-30',
#  'hotspots': [],
#  'latitude': -37.497,
#  'longitude': 147.266,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 41.0,
#  'windspeed_knots': 14.1}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('664f28877de308e5b72528f9'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-05-01',
#  'hotspots': [],
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.9,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 136.0,
#  '_id': ObjectId('664f28917de308e5b72528fb'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-05-02',
#  'hotspots': [],
#  'latitude': -36.098,
#  'longitude': 143.735,
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.04G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.1,
#  'windspeed_knots': 11.7}
# {'GHI_w/m2': 104.0,
#  '_id': ObjectId('664f28e17de308e5b72528fd'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-05-10',
#  'hotspots': [],
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.0,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 100.0,
#  '_id': ObjectId('664f28eb7de308e5b72528ff'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-05-11',
#  'hotspots': [],
#  'latitude': -37.376,
#  'longitude': 148.042,
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 43.2,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 105.0,
#  '_id': ObjectId('664f28f57de308e5b7252901'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-05-12',
#  'hotspots': [],
#  'latitude': -37.415,
#  'longitude': 148.105,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 47.0,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 103.0,
#  '_id': ObjectId('664f28fe7de308e5b7252903'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-05-13',
#  'hotspots': [],
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.9,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664f29097de308e5b7252905'),
#  'air_temperature_celcius': 17.0,
#  'cause_of_fire': 'other',
#  'date': '2024-05-14',
#  'hotspots': [{'confidence': 74.0,
#                'created_time': '17:14:33',
#                'latitude': -37.2109,
#                'longitude': 142.7966,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 52.0},
#               {'confidence': 54.0,
#                'created_time': '21:01:30',
#                'latitude': -37.8084,
#                'longitude': 143.1985,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 46.0}],
#  'latitude': -37.8147,
#  'longitude': 143.1062,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.4,
#  'windspeed_knots': 9.5}
# {'GHI_w/m2': 142.0,
#  '_id': ObjectId('664f29137de308e5b7252907'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-05-15',
#  'hotspots': [],
#  'latitude': -37.467,
#  'longitude': 143.351,
#  'max_wind_speed': 25.1,
#  'precipitation ': ' 0.16G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.4,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('664f291d7de308e5b7252909'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-05-16',
#  'hotspots': [],
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.6,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 152.0,
#  '_id': ObjectId('664f29277de308e5b725290b'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-05-17',
#  'latitude': -36.3782,
#  'longitude': 143.7313,
#  'max_wind_speed': 27.0,
#  'precipitation ': ' 0.24G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.9,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 111.0,
#  '_id': ObjectId('664f29317de308e5b725290d'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-05-18',
#  'hotspots': [],
#  'latitude': -36.369,
#  'longitude': 143.7132,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.1,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 149.0,
#  '_id': ObjectId('664f293b7de308e5b725290f'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-05-19',
#  'hotspots': [],
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 54.4,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 92.0,
#  '_id': ObjectId('664f29457de308e5b7252911'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-05-20',
#  'hotspots': [],
#  'latitude': -37.497,
#  'longitude': 147.266,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 41.0,
#  'windspeed_knots': 14.1}
# {'GHI_w/m2': 84.0,
#  '_id': ObjectId('664f294f7de308e5b7252913'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-05-21',
#  'hotspots': [],
#  'latitude': -37.6593,
#  'longitude': 143.3445,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.1,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 118.0,
#  '_id': ObjectId('664f29597de308e5b7252915'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-05-22',
#  'hotspots': [],
# ...
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 59.5,
#  'windspeed_knots': 12.4}
# {'GHI_w/m2': 141.0,
#  '_id': ObjectId('664f2d7c7de308e5b72529e9'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-03-20',
#  'latitude': -36.251,
#  'longitude': 142.5651,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.6,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664f2d877de308e5b72529eb'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-03-21',
#  'hotspots': [],
#  'latitude': -36.778,
#  'longitude': 145.1635,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.3,
#  'windspeed_knots': 11.7}
# {'GHI_w/m2': 166.0,
#  '_id': ObjectId('664f2d917de308e5b72529ed'),
#  'air_temperature_celcius': 20.0,
#  'cause_of_fire': 'other',
#  'date': '2024-03-22',
#  'hotspots': [{'confidence': 100.0,
#                'created_time': '04:47:37',
#                'latitude': -36.1532,
#                'longitude': 143.5527,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 90.0}],
#  'latitude': -36.1,
#  'longitude': 143.767,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.31G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.5,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 265.0,
#  '_id': ObjectId('664f2d9b7de308e5b72529ef'),
#  'air_temperature_celcius': 32.0,
#  'date': '2024-03-23',
#  'hotspots': [],
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 54.1,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 98.0,
#  '_id': ObjectId('664f2da57de308e5b72529f1'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-03-24',
#  'hotspots': [],
#  'latitude': -37.463,
#  'longitude': 148.109,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 45.1,
#  'windspeed_knots': 5.6}
# {'GHI_w/m2': 199.0,
#  '_id': ObjectId('664f2daf7de308e5b72529f3'),
#  'air_temperature_celcius': 25.0,
#  'date': '2024-03-25',
#  'hotspots': [],
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 167.0,
#  '_id': ObjectId('664f2db97de308e5b72529f5'),
#  'air_temperature_celcius': 20.0,
#  'date': '2024-03-26',
#  'hotspots': [],
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 52.9,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 66.0,
#  '_id': ObjectId('664f2dc37de308e5b72529f7'),
#  'air_temperature_celcius': 7.0,
#  'date': '2024-03-27',
#  'hotspots': [],
#  'latitude': -36.3328,
#  'longitude': 146.0355,
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 37.2,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('664f2dcc7de308e5b72529f9'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-03-28',
#  'hotspots': [],
#  'latitude': -37.8276,
#  'longitude': 142.7573,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.1,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664f2dd77de308e5b72529fb'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-03-29',
#  'hotspots': [],
#  'latitude': -36.778,
#  'longitude': 145.1635,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.02G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 46.3,
#  'windspeed_knots': 11.7}
# {'GHI_w/m2': 123.0,
#  '_id': ObjectId('664f2de17de308e5b72529fd'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-03-30',
#  'hotspots': [],
#  'latitude': -36.0313,
#  'longitude': 143.6296,
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.03G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 47.4,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 81.0,
#  '_id': ObjectId('664f2deb7de308e5b72529ff'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-03-31',
#  'hotspots': [],
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.0,
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 219.0,
#  '_id': ObjectId('664f2df57de308e5b7252a01'),
#  'air_temperature_celcius': 26.0,
#  'date': '2024-04-01',
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 52.2,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 120.0,
#  '_id': ObjectId('664f2dff7de308e5b7252a03'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-04-02',
#  'hotspots': [],
#  'latitude': -36.752,
#  'longitude': 144.15,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.01G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.4,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664f2e097de308e5b7252a05'),
#  'air_temperature_celcius': 19.0,
#  'date': '2024-04-03',
#  'hotspots': [],
#  'latitude': -37.0585,
#  'longitude': 143.8589,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.63G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 59.7,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 149.0,
#  '_id': ObjectId('664f2e137de308e5b7252a07'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-04-04',
#  'hotspots': [],
#  'latitude': -36.059,
#  'longitude': 143.7718,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.8,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 107.0,
#  '_id': ObjectId('664f2e1d7de308e5b7252a09'),
#  'air_temperature_celcius': 12.0,
#  'cause_of_fire': 'other',
#  'date': '2024-04-05',
#  'hotspots': [{'confidence': 71.0,
#                'created_time': '23:00:17',
#                'latitude': -37.367,
#                'longitude': 148.04,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 55.0}],
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.7,
#  'windspeed_knots': 11.4}
# {'GHI_w/m2': 265.0,
#  '_id': ObjectId('664f2e277de308e5b7252a0b'),
#  'air_temperature_celcius': 32.0,
#  'date': '2024-04-06',
#  'hotspots': [],
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 54.1,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('664f2e317de308e5b7252a0d'),
#  'air_temperature_celcius': 20.0,
#  'date': '2024-04-07',
#  'hotspots': [],
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 62.2,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 105.0,
#  '_id': ObjectId('664f2e3b7de308e5b7252a0f'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-04-08',
#  'hotspots': [],
#  'latitude': -37.367,
#  'longitude': 148.04,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 47.6,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 161.0,
#  '_id': ObjectId('664f2e457de308e5b7252a11'),
#  'air_temperature_celcius': 19.0,
#  'date': '2024-04-09',
#  'hotspots': [],
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 51.5,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 111.0,
#  '_id': ObjectId('664f2e4f7de308e5b7252a13'),
#  'air_temperature_celcius': 13.0,
#  'date': '2024-04-10',
#  'hotspots': [],
#  'latitude': -37.4437,
#  'longitude': 143.4924,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 50.7,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 157.0,
#  '_id': ObjectId('664f2e597de308e5b7252a15'),
#  'air_temperature_celcius': 19.0,
#  'date': '2024-04-11',
#  'hotspots': [],
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 54.3,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 107.0,
#  '_id': ObjectId('664f2e637de308e5b7252a17'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-04-12',
#  'hotspots': [],
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.9,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 121.0,
#  '_id': ObjectId('664f2e6d7de308e5b7252a19'),
#  'air_temperature_celcius': 14.0,
#  'date': '2024-04-13',
#  'hotspots': [],
#  'latitude': -37.858,
#  'longitude': 143.428,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.5,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('664f2e777de308e5b7252a1b'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-04-14',
#  'hotspots': [],
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.0,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 156.0,
#  '_id': ObjectId('664f2e817de308e5b7252a1d'),
#  'air_temperature_celcius': 19.0,
#  'date': '2024-04-15',
#  'hotspots': [],
#  'latitude': -36.4553,
#  'longitude': 142.8786,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 55.3,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 199.0,
#  '_id': ObjectId('664f2e8b7de308e5b7252a1f'),
#  'air_temperature_celcius': 25.0,
#  'date': '2024-04-16',
#  'hotspots': [],
#  'latitude': -37.583,
#  'longitude': 149.316,
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.04G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 75.0,
#  '_id': ObjectId('664f2e957de308e5b7252a21'),
#  'air_temperature_celcius': 8.0,
#  'date': '2024-04-17',
#  'hotspots': [],
#  'latitude': -36.5548,
#  'longitude': 142.5237,
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 38.6,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 132.0,
#  '_id': ObjectId('664f2e9f7de308e5b7252a23'),
#  'air_temperature_celcius': 16.0,
#  'date': '2024-04-18',
#  'hotspots': [],
#  'latitude': -37.295,
#  'longitude': 144.377,
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 54.8,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 105.0,
#  '_id': ObjectId('664f2ea97de308e5b7252a25'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-04-19',
#  'hotspots': [],
#  'latitude': -37.367,
#  'longitude': 148.04,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.12G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 47.6,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 133.0,
#  '_id': ObjectId('664f2eb37de308e5b7252a27'),
#  'air_temperature_celcius': 15.0,
#  'date': '2024-04-20',
#  'hotspots': [],
#  'latitude': -35.89,
#  'longitude': 145.606,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 45.6,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 104.0,
#  '_id': ObjectId('664f2ebd7de308e5b7252a29'),
#  'air_temperature_celcius': 12.0,
#  'date': '2024-04-21',
#  'hotspots': [],
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 49.0,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 84.0,
#  '_id': ObjectId('664f2ec77de308e5b7252a2b'),
#  'air_temperature_celcius': 9.0,
#  'date': '2024-04-22',
#  'hotspots': [],
#  'latitude': -37.434,
#  'longitude': 148.091,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.0,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664f2ed17de308e5b7252a2d'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-04-23',
#  'hotspots': [],
#  'latitude': -35.954,
#  'longitude': 141.076,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.13B',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 42.1,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664f2edb7de308e5b7252a2f'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-04-24',
#  'hotspots': [],
#  'latitude': -35.779,
#  'longitude': 143.1057,
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.7,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 153.0,
#  '_id': ObjectId('664f2ee57de308e5b7252a31'),
#  'air_temperature_celcius': 18.0,
#  'cause_of_fire': 'other',
#  'date': '2024-04-25',
#  'hotspots': [{'confidence': 71.0,
#                'created_time': '08:19:47',
#                'latitude': -37.4444,
#                'longitude': 142.9091,
#                'producer_identifier': 'producer_2',
#                'surface_temperature_celcius': 45.0}],
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 51.1,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 141.0,
#  '_id': ObjectId('664f2eef7de308e5b7252a33'),
#  'air_temperature_celcius': 17.0,
#  'date': '2024-04-26',
#  'hotspots': [],
#  'latitude': -36.251,
#  'longitude': 142.5651,
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.6,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664f2ef97de308e5b7252a35'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-04-27',
#  'latitude': -37.247,
#  'longitude': 141.27,
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 43.1,
#  'windspeed_knots': 4.7}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664f5ba97de308e5b7252a37'),
#  'air_temperature_celcius': 18.0,
#  'date': '2024-01-09',
#  'latitude': -36.275,
#  'longitude': 146.154,
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 53.3,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 75.0,
#  '_id': ObjectId('664f5bb37de308e5b7252a39'),
#  'air_temperature_celcius': 8.0,
#  'date': '2024-01-10',
#  'hotspots': [],
#  'latitude': -36.5548,
#  'longitude': 142.5237,
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 38.6,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 102.0,
#  '_id': ObjectId('664f5bbd7de308e5b7252a3b'),
#  'air_temperature_celcius': 11.0,
#  'date': '2024-01-11',
#  'hotspots': [],
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'max_wind_speed': 26.0,
#  'precipitation ': ' 0.00G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 40.5,
#  'windspeed_knots': 13.4}
# {'GHI_w/m2': 90.0,
#  '_id': ObjectId('664f5bc77de308e5b7252a3d'),
#  'air_temperature_celcius': 10.0,
#  'date': '2024-01-12',
#  'hotspots': [],
#  'latitude': -37.013,
#  'longitude': 141.5355,
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.39G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 44.1,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 174.0,
#  '_id': ObjectId('664f5bd17de308e5b7252a3f'),
#  'air_temperature_celcius': 23.0,
#  'date': '2024-01-13',
#  'hotspots': [],
#  'latitude': -36.941,
#  'longitude': 143.268,
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.08G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 63.8,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 159.0,
#  '_id': ObjectId('664f5bdb7de308e5b7252a41'),
#  'air_temperature_celcius': 19.0,
#  'cause_of_fire': 'other',
#  'date': '2024-01-14',
#  'hotspots': [{'confidence': 84.0,
#                'created_time': '01:32:54',
#                'latitude': -36.8272,
#                'longitude': 142.2097,
#                'producer_identifier': 'producer_3',
#                'surface_temperature_celcius': 57.0}],
#  'latitude': -37.34,
#  'longitude': 143.123,
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.47G',
#  'producer_identifier': 'producer_1',
#  'relative_humidity': 52.8,
#  'windspeed_knots': 12.5}

# %%
#! uncomment the following line to clear current contents from collection
# streaming_climate_col.delete_many({})
