# %% [markdown]
# ## **Task 1**

# %% [markdown]
# ##### **Chosen Data Model: Embedded**
#
# The designed schema consists of one collection: *climate_historic.csv* in which the documents from *hotspot_historic.csv* have been embedded. Since each climate record for a particular date may have several hotspot records, each document in the *climate_historic* collection has a key called *hotspots* which holds an araay of all the hotspot documents (fire occurences) having the same date as the climate record. Hence, this one-to-many relationship is modelled using embedded documents. The date field has been removed from each of embedded hotspot documents to prevent duplication.
#
# The structure of the data model is as follows:
#
# ```
# climate_document =  {
#     "_id": bson.objectid.ObjectId,
#     "station": int
#     "date": str,
#     "air_temperature_celcius": int,
#     "relative_humidity": float,
#     "windspeed_knots": float,
#     "max_wind_speed": float,
#     "preciptation": str,
#     "GHI_w/m2": int,
#     "hotspots": [
#                     {
#                         "latitude": float,
#                         "longitude": float,
#                         "datetime": str,
#                         "confidence": int,
#                         "surface_temperature_celcius": int
#                     }
#             ]
#     }
# ```
#
# **Example of climate document containing embedded corresponding hotspot documents:**
# ```
# {'GHI_w/m2': 152,
#  '_id': ObjectId('663d77f85178059695ff6188'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'hotspots': [{'confidence': 92,
#                'datetime': '2023-12-15 13:17:17',
#                'latitude': -37.627,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 42},
#               {'confidence': 78,
#                'datetime': '2023-12-15 13:17:17',
#                'latitude': -37.658,
#                'longitude': 149.339,
#                'surface_temperature_celcius': 36},
#               {'confidence': 51,
#                'datetime': '2023-12-15 13:17:17',
#                'latitude': -37.623,
#                'longitude': 149.323,
#                'surface_temperature_celcius': 38},
#               {'confidence': 65,
#                'datetime': '2023-12-15 01:16:23',
#                'latitude': -38.038,
#                'longitude': 142.986,
#                'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
#  ```

# %% [markdown]
# ##### **Reasons for choosing the embedded data model:**
# The embedded data model is chosen over the reference data model to optimise the read operations by facilitating the retrieval of related hotspot and climate data in lesser database queries. Below are the detailed reasons:
#
# - For the given use case, queries fetch related data from both the climate and hotspot documents more often as compared to fetching data distinctly from each individual dataset. For example, studying the surface temperature (hotspot data) together with air temperature (climate data) is a crucial metric for analysing trends in fire occurences. Many such queries using related data from both datasets are found in the given use case (task 2) whereas lesser queries using distinct data are applied. The embedded data model helps in fetching related/associated data in a single database operation resulting in efficient querying, whereas referencing requires multiple queries to fetch related data as the hotspot and climate collections would have to be queried separetely and the references would need to be resolved. Hence, embedded data model is the better fit for this case.
#
# - The given datasets for climate and hotspots are not very large, hence the embedded model fits in this case as referencing is often only used for extremely large datasets with over thousands of documents. Furthermore, even if the datasets were to expand, the scenario of having a very large number of fire occurences on the same day is highly unlikely. Therefore, the problem of exceeding the 16MB document size limit is not encountered with these datasets. Since the embedded documents are still relatively smaller in size, querying performance is not compromised.

# %% [markdown]
# ## **Task 2.1**

# %% [markdown]
# **Set up mongo client and get/create collection**

# %%
from pymongo import MongoClient

#setup mongo client
ip_address = '10.192.68.151'

mongo_client = MongoClient(ip_address, 27017)

#create or get database 
db = mongo_client["fit3182_assignment_db"]

#create collection for climate data
climate_col = db.climates_historic

# %% [markdown]
# *Note: Please run the test code below to clear up the current data in the collection before running the following cell which populates the climate_col collection with climate data*

# %%
#! uncomment the following line before running the next cell to clear current contents from collection
# climate_col.delete_many({})

# %% [markdown]
# **Feed climate data with embedded hotspots into created collection**

# %%
import pandas as pd
from pprint import pprint

#read csv files and extract rows
climate_data = pd.read_csv("climate_historic.csv").iterrows()
data = pd.read_csv("hotspot_historic.csv").iterrows()

hotspots = []

#extract hotspot documents
for id, data_row in data:
    row_dict = data_row.to_dict()  #convert csv row to document
    hotspots.append(row_dict)

#populate climate collection with documents
for id, data_row in climate_data:
    row_dict = data_row.to_dict()   #extract climate documents
    row_dict["hotspots"] = []

    #find all fires which occured on current climate record's date
    cur_climate_date = row_dict["date"]

    #embed all matching hotspots into climate document
    for hotspot in hotspots:
        if hotspot["date"] == cur_climate_date:

            #remove date to avoid data duplication since it already exists in the climate document
            embed_hotspot = hotspot.copy()
            embed_hotspot.pop("date")   #remove date field to avoid duplicate data

            row_dict["hotspots"].append(embed_hotspot)

    climate_col.insert_one(row_dict)
# Out:
# 366

# %%
from pprint import pprint
for document in climate_col.find({}):
    pprint(document)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('663d77f75178059695ff602c'),
#  'air_temperature_celcius': 19,
#  'date': '31/12/2022',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('663d77f75178059695ff602d'),
#  'air_temperature_celcius': 15,
#  'date': '2/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 50.7,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('663d77f75178059695ff602e'),
#  'air_temperature_celcius': 16,
#  'date': '3/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('663d77f75178059695ff602f'),
#  'air_temperature_celcius': 24,
#  'date': '4/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 61.6,
#  'station': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('663d77f75178059695ff6030'),
#  'air_temperature_celcius': 24,
#  'date': '5/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 62.3,
#  'station': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('663d77f75178059695ff6031'),
#  'air_temperature_celcius': 26,
#  'date': '6/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 60.8,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('663d77f75178059695ff6032'),
#  'air_temperature_celcius': 32,
#  'date': '7/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('663d77f75178059695ff6033'),
#  'air_temperature_celcius': 20,
#  'date': '8/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.7,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('663d77f75178059695ff6034'),
#  'air_temperature_celcius': 19,
#  'date': '9/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('663d77f75178059695ff6035'),
#  'air_temperature_celcius': 20,
#  'date': '10/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('663d77f75178059695ff6036'),
#  'air_temperature_celcius': 18,
#  'date': '11/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.3,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 179,
#  '_id': ObjectId('663d77f75178059695ff6037'),
#  'air_temperature_celcius': 22,
#  'date': '12/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.08G',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 157,
#  '_id': ObjectId('663d77f75178059695ff6038'),
#  'air_temperature_celcius': 19,
#  'date': '13/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.31G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('663d77f75178059695ff6039'),
#  'air_temperature_celcius': 17,
#  'date': '14/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 50.4,
#  'station': 948700,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('663d77f75178059695ff603a'),
#  'air_temperature_celcius': 16,
#  'date': '15/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('663d77f75178059695ff603b'),
#  'air_temperature_celcius': 24,
#  'date': '16/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.4,
#  'station': 948700,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 200,
#  '_id': ObjectId('663d77f75178059695ff603c'),
#  'air_temperature_celcius': 24,
#  'date': '17/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('663d77f75178059695ff603d'),
#  'air_temperature_celcius': 16,
#  'date': '18/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 46.7,
#  'station': 948700,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('663d77f75178059695ff603e'),
#  'air_temperature_celcius': 19,
#  'date': '19/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.98G',
#  'relative_humidity': 57.2,
#  'station': 948700,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('663d77f75178059695ff603f'),
#  'air_temperature_celcius': 16,
#  'date': '20/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': '0.03G',
#  'relative_humidity': 50.9,
#  'station': 948700,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('663d77f75178059695ff6040'),
#  'air_temperature_celcius': 17,
#  'date': '21/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 52.5,
#  'station': 948700,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 182,
#  '_id': ObjectId('663d77f75178059695ff6041'),
#  'air_temperature_celcius': 23,
#  'date': '22/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 59.0,
#  'station': 948700,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('663d77f75178059695ff6042'),
#  'air_temperature_celcius': 25,
#  'date': '23/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 22.0,
#  'precipitation': '0.04G',
#  'relative_humidity': 58.3,
#  'station': 948700,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('663d77f75178059695ff6043'),
#  'air_temperature_celcius': 16,
#  'date': '24/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.01G',
#  'relative_humidity': 48.2,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('663d77f75178059695ff6044'),
#  'air_temperature_celcius': 17,
#  'date': '25/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('663d77f75178059695ff6045'),
#  'air_temperature_celcius': 18,
#  'date': '26/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.5,
#  'station': 948700,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('663d77f75178059695ff6046'),
#  'air_temperature_celcius': 19,
#  'date': '27/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00A',
#  'relative_humidity': 56.1,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('663d77f75178059695ff6047'),
#  'air_temperature_celcius': 18,
#  'date': '28/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('663d77f75178059695ff6048'),
#  'air_temperature_celcius': 22,
#  'date': '29/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.0,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('663d77f75178059695ff6049'),
#  'air_temperature_celcius': 20,
#  'date': '30/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.01G',
#  'relative_humidity': 55.8,
#  'station': 948700,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('663d77f75178059695ff604a'),
#  'air_temperature_celcius': 16,
#  'date': '31/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 48.4,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 138,
#  '_id': ObjectId('663d77f75178059695ff604b'),
#  'air_temperature_celcius': 16,
#  'date': '1/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 48.9,
#  'station': 948700,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('663d77f75178059695ff604c'),
#  'air_temperature_celcius': 18,
#  'date': '2/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.0,
#  'station': 948700,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('663d77f75178059695ff604d'),
#  'air_temperature_celcius': 18,
#  'date': '3/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.4,
#  'station': 948700,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 216,
#  '_id': ObjectId('663d77f75178059695ff604e'),
#  'air_temperature_celcius': 26,
#  'date': '4/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('663d77f75178059695ff604f'),
#  'air_temperature_celcius': 21,
#  'date': '5/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '1.26G',
#  'relative_humidity': 64.5,
#  'station': 948700,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('663d77f75178059695ff6050'),
#  'air_temperature_celcius': 16,
#  'date': '6/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 48.1,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('663d77f75178059695ff6051'),
#  'air_temperature_celcius': 20,
#  'date': '7/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 22.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 239,
#  '_id': ObjectId('663d77f75178059695ff6052'),
#  'air_temperature_celcius': 31,
#  'date': '8/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 23.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 61.9,
#  'station': 948700,
#  'windspeed_knots': 14.1}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('663d77f75178059695ff6053'),
#  'air_temperature_celcius': 22,
#  'date': '9/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 62.7,
#  'station': 948700,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 164,
#  '_id': ObjectId('663d77f75178059695ff6054'),
#  'air_temperature_celcius': 21,
#  'date': '10/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 60.4,
#  'station': 948700,
#  'windspeed_knots': 6.8}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('663d77f75178059695ff6055'),
#  'air_temperature_celcius': 19,
#  'date': '11/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 53.8,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('663d77f75178059695ff6056'),
#  'air_temperature_celcius': 16,
#  'date': '12/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 48.3,
#  'station': 948700,
#  'windspeed_knots': 14.4}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('663d77f75178059695ff6057'),
#  'air_temperature_celcius': 16,
#  'date': '13/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': '0.16G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('663d77f75178059695ff6058'),
#  'air_temperature_celcius': 14,
#  'date': '14/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('663d77f75178059695ff6059'),
#  'air_temperature_celcius': 22,
#  'date': '15/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('663d77f75178059695ff605a'),
#  'air_temperature_celcius': 18,
#  'date': '16/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('663d77f75178059695ff605b'),
#  'air_temperature_celcius': 18,
#  'date': '17/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.4,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 134,
#  '_id': ObjectId('663d77f75178059695ff605c'),
#  'air_temperature_celcius': 15,
#  'date': '18/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 44.6,
#  'station': 948700,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 113,
#  '_id': ObjectId('663d77f75178059695ff605d'),
#  'air_temperature_celcius': 13,
#  'date': '19/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.71G',
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 130,
#  '_id': ObjectId('663d77f75178059695ff605e'),
#  'air_temperature_celcius': 15,
#  'date': '20/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': '0.01G',
#  'relative_humidity': 49.1,
#  'station': 948701,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('663d77f75178059695ff605f'),
#  'air_temperature_celcius': 16,
#  'date': '21/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 51.0,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('663d77f75178059695ff6060'),
#  'air_temperature_celcius': 23,
#  'date': '22/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.6,
#  'station': 948701,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('663d77f75178059695ff6061'),
#  'air_temperature_celcius': 18,
#  'date': '23/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.01G',
#  'relative_humidity': 55.5,
#  'station': 948701,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('663d77f75178059695ff6062'),
#  'air_temperature_celcius': 16,
#  'date': '24/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.01G',
#  'relative_humidity': 48.3,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('663d77f75178059695ff6063'),
#  'air_temperature_celcius': 17,
#  'date': '25/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 52.6,
#  'station': 948701,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 173,
#  '_id': ObjectId('663d77f75178059695ff6064'),
#  'air_temperature_celcius': 21,
#  'date': '26/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('663d77f75178059695ff6065'),
#  'air_temperature_celcius': 24,
#  'date': '27/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 190,
#  '_id': ObjectId('663d77f75178059695ff6066'),
#  'air_temperature_celcius': 23,
#  'date': '28/2/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('663d77f75178059695ff6067'),
#  'air_temperature_celcius': 21,
#  'date': '1/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.3,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('663d77f75178059695ff6068'),
#  'air_temperature_celcius': 20,
#  'date': '2/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 62.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('663d77f75178059695ff6069'),
#  'air_temperature_celcius': 21,
#  'date': '3/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 59.5,
#  'station': 948701,
#  'windspeed_knots': 12.4}
# {'GHI_w/m2': 170,
#  '_id': ObjectId('663d77f75178059695ff606a'),
#  'air_temperature_celcius': 22,
#  'date': '4/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 62.0,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('663d77f75178059695ff606b'),
#  'air_temperature_celcius': 20,
#  'date': '5/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.8,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('663d77f75178059695ff606c'),
#  'air_temperature_celcius': 20,
#  'date': '6/3/2023',
#  'hotspots': [{'confidence': 87,
#                'datetime': '2023-03-06 05:06:30',
#                'latitude': -34.3795,
#                'longitude': 141.6331,
#                'surface_temperature_celcius': 62},
#               {'confidence': 85,
#                'datetime': '2023-03-06 05:06:20',
#                'latitude': -34.3735,
#                'longitude': 141.6604,
#                'surface_temperature_celcius': 59}],
#  'max_wind_speed': 21.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.9,
#  'station': 948701,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('663d77f75178059695ff606d'),
#  'air_temperature_celcius': 19,
#  'date': '7/3/2023',
#  'hotspots': [{'confidence': 88,
#                'datetime': '2023-03-07 04:16:10',
#                'latitude': -37.7752,
#                'longitude': 141.9086,
#                'surface_temperature_celcius': 64}],
#  'max_wind_speed': 20.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.5,
#  'station': 948701,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 177,
#  '_id': ObjectId('663d77f75178059695ff606e'),
#  'air_temperature_celcius': 21,
#  'date': '8/3/2023',
#  'hotspots': [{'confidence': 68,
#                'datetime': '2023-03-08 04:51:00',
#                'latitude': -37.7885,
#                'longitude': 141.9352,
#                'surface_temperature_celcius': 55},
#               {'confidence': 75,
#                'datetime': '2023-03-08 00:30:30',
#                'latitude': -38.1031,
#                'longitude': 142.4797,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.7,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 192,
#  '_id': ObjectId('663d77f75178059695ff606f'),
#  'air_temperature_celcius': 23,
#  'date': '9/3/2023',
#  'hotspots': [{'confidence': 86,
#                'datetime': '2023-03-09 13:23:40',
#                'latitude': -37.996,
#                'longitude': 146.3535,
#                'surface_temperature_celcius': 41},
#               {'confidence': 54,
#                'datetime': '2023-03-09 03:57:00',
#                'latitude': -37.7171,
#                'longitude': 147.5866,
#                'surface_temperature_celcius': 44},
#               {'confidence': 78,
#                'datetime': '2023-03-09 03:56:50',
#                'latitude': -37.7074,
#                'longitude': 147.5849,
#                'surface_temperature_celcius': 55}],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('663d77f75178059695ff6070'),
#  'air_temperature_celcius': 19,
#  'date': '10/3/2023',
#  'hotspots': [{'confidence': 100,
#                'datetime': '2023-03-10 04:48:40',
#                'latitude': -37.223,
#                'longitude': 147.9431,
#                'surface_temperature_celcius': 105},
#               {'confidence': 100,
#                'datetime': '2023-03-10 04:46:20',
#                'latitude': -37.2252,
#                'longitude': 147.9363,
#                'surface_temperature_celcius': 109},
#               {'confidence': 94,
#                'datetime': '2023-03-10 04:45:30',
#                'latitude': -37.2284,
#                'longitude': 147.9187,
#                'surface_temperature_celcius': 73},
#               {'confidence': 97,
#                'datetime': '2023-03-10 04:45:30',
#                'latitude': -37.6572,
#                'longitude': 142.0703,
#                'surface_temperature_celcius': 80},
#               {'confidence': 81,
#                'datetime': '2023-03-10 04:43:50',
#                'latitude': -37.6592,
#                'longitude': 142.058,
#                'surface_temperature_celcius': 55},
#               {'confidence': 55,
#                'datetime': '2023-03-10 04:43:00',
#                'latitude': -36.2544,
#                'longitude': 148.0353,
#                'surface_temperature_celcius': 42},
#               {'confidence': 54,
#                'datetime': '2023-03-10 04:42:30',
#                'latitude': -37.2197,
#                'longitude': 147.9621,
#                'surface_temperature_celcius': 43},
#               {'confidence': 74,
#                'datetime': '2023-03-10 04:39:00',
#                'latitude': -37.2128,
#                'longitude': 147.9308,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('663d77f75178059695ff6071'),
#  'air_temperature_celcius': 20,
#  'date': '11/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.01G',
#  'relative_humidity': 59.7,
#  'station': 948701,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 168,
#  '_id': ObjectId('663d77f75178059695ff6072'),
#  'air_temperature_celcius': 21,
#  'date': '12/3/2023',
#  'hotspots': [{'confidence': 94,
#                'datetime': '2023-03-12 04:33:50',
#                'latitude': -37.4157,
#                'longitude': 147.0084,
#                'surface_temperature_celcius': 105},
#               {'confidence': 84,
#                'datetime': '2023-03-12 04:29:50',
#                'latitude': -37.0193,
#                'longitude': 148.1459,
#                'surface_temperature_celcius': 71},
#               {'confidence': 100,
#                'datetime': '2023-03-12 04:28:20',
#                'latitude': -37.4229,
#                'longitude': 147.027,
#                'surface_temperature_celcius': 99},
#               {'confidence': 80,
#                'datetime': '2023-03-12 04:28:00',
#                'latitude': -37.0055,
#                'longitude': 148.1582,
#                'surface_temperature_celcius': 68},
#               {'confidence': 85,
#                'datetime': '2023-03-12 04:27:20',
#                'latitude': -37.4128,
#                'longitude': 147.0242,
#                'surface_temperature_celcius': 98}],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00G',
#  'relative_humidity': 58.1,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('663d77f75178059695ff6073'),
#  'air_temperature_celcius': 20,
#  'date': '13/3/2023',
#  'hotspots': [{'confidence': 56,
#                'datetime': '2023-03-13 23:58:50',
#                'latitude': -37.0286,
#                'longitude': 148.155,
#                'surface_temperature_celcius': 42},
#               {'confidence': 52,
#                'datetime': '2023-03-13 12:57:00',
#                'latitude': -37.0316,
#                'longitude': 148.1519,
#                'surface_temperature_celcius': 35}],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('663d77f75178059695ff6074'),
#  'air_temperature_celcius': 25,
#  'date': '14/3/2023',
#  'hotspots': [{'confidence': 90,
#                'datetime': '2023-03-14 04:24:40',
#                'latitude': -34.357,
#                'longitude': 141.5361,
#                'surface_temperature_celcius': 67},
#               {'confidence': 93,
#                'datetime': '2023-03-14 04:22:20',
#                'latitude': -34.3539,
#                'longitude': 141.5547,
#                'surface_temperature_celcius': 72},
#               {'confidence': 90,
#                'datetime': '2023-03-14 04:20:50',
#                'latitude': -36.9939,
#                'longitude': 148.2244,
#                'surface_temperature_celcius': 68},
#               {'confidence': 73,
#                'datetime': '2023-03-14 04:19:30',
#                'latitude': -36.998,
#                'longitude': 148.1994,
#                'surface_temperature_celcius': 48},
#               {'confidence': 95,
#                'datetime': '2023-03-14 04:16:30',
#                'latitude': -36.9959,
#                'longitude': 148.2118,
#                'surface_temperature_celcius': 75},
#               {'confidence': 89,
#                'datetime': '2023-03-14 04:16:20',
#                'latitude': -34.3654,
#                'longitude': 141.543,
#                'surface_temperature_celcius': 65},
#               {'confidence': 73,
#                'datetime': '2023-03-14 04:14:40',
#                'latitude': -37.0228,
#                'longitude': 148.1996,
#                'surface_temperature_celcius': 52},
#               {'confidence': 81,
#                'datetime': '2023-03-14 04:14:40',
#                'latitude': -34.3539,
#                'longitude': 141.5629,
#                'surface_temperature_celcius': 55},
#               {'confidence': 96,
#                'datetime': '2023-03-14 04:14:30',
#                'latitude': -34.3554,
#                'longitude': 141.5413,
#                'surface_temperature_celcius': 79},
#               {'confidence': 94,
#                'datetime': '2023-03-14 04:14:30',
#                'latitude': -34.3555,
#                'longitude': 141.5495,
#                'surface_temperature_celcius': 75}],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.3,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('663d77f75178059695ff6075'),
#  'air_temperature_celcius': 28,
#  'date': '15/3/2023',
#  'hotspots': [{'confidence': 76,
#                'datetime': '2023-03-15 05:02:00',
#                'latitude': -37.4108,
#                'longitude': 147.0196,
#                'surface_temperature_celcius': 50},
#               {'confidence': 74,
#                'datetime': '2023-03-15 04:59:10',
#                'latitude': -37.4058,
#                'longitude': 147.0117,
#                'surface_temperature_celcius': 48},
#               {'confidence': 52,
#                'datetime': '2023-03-15 00:42:50',
#                'latitude': -37.4075,
#                'longitude': 147.0233,
#                'surface_temperature_celcius': 43},
#               {'confidence': 66,
#                'datetime': '2023-03-15 00:42:50',
#                'latitude': -37.0228,
#                'longitude': 148.1281,
#                'surface_temperature_celcius': 43},
#               {'confidence': 51,
#                'datetime': '2023-03-15 00:42:40',
#                'latitude': -37.002,
#                'longitude': 148.2055,
#                'surface_temperature_celcius': 44},
#               {'confidence': 75,
#                'datetime': '2023-03-15 00:38:10',
#                'latitude': -37.0249,
#                'longitude': 148.1561,
#                'surface_temperature_celcius': 49},
#               {'confidence': 70,
#                'datetime': '2023-03-15 00:37:20',
#                'latitude': -37.4098,
#                'longitude': 147.0489,
#                'surface_temperature_celcius': 45}],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.04G',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('663d77f75178059695ff6076'),
#  'air_temperature_celcius': 18,
#  'date': '16/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 53.3,
#  'station': 948701,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('663d77f75178059695ff6077'),
#  'air_temperature_celcius': 18,
#  'date': '17/3/2023',
#  'hotspots': [{'confidence': 76,
#                'datetime': '2023-03-17 04:48:20',
#                'latitude': -34.3383,
#                'longitude': 141.543,
#                'surface_temperature_celcius': 56},
#               {'confidence': 94,
#                'datetime': '2023-03-17 04:48:20',
#                'latitude': -36.7152,
#                'longitude': 141.3853,
#                'surface_temperature_celcius': 74},
#               {'confidence': 78,
#                'datetime': '2023-03-17 04:46:40',
#                'latitude': -34.328,
#                'longitude': 141.5402,
#                'surface_temperature_celcius': 58},
#               {'confidence': 84,
#                'datetime': '2023-03-17 04:45:10',
#                'latitude': -36.6867,
#                'longitude': 141.137,
#                'surface_temperature_celcius': 59},
#               {'confidence': 76,
#                'datetime': '2023-03-17 04:45:00',
#                'latitude': -36.6889,
#                'longitude': 141.1239,
#                'surface_temperature_celcius': 50},
#               {'confidence': 86,
#                'datetime': '2023-03-17 04:45:00',
#                'latitude': -36.7128,
#                'longitude': 141.3986,
#                'surface_temperature_celcius': 60}],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.1,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('663d77f75178059695ff6078'),
#  'air_temperature_celcius': 21,
#  'date': '18/3/2023',
#  'hotspots': [{'confidence': 64,
#                'datetime': '2023-03-18 13:16:50',
#                'latitude': -37.4313,
#                'longitude': 147.0343,
#                'surface_temperature_celcius': 37},
#               {'confidence': 100,
#                'datetime': '2023-03-18 03:50:50',
#                'latitude': -37.017,
#                'longitude': 148.1297,
#                'surface_temperature_celcius': 121},
#               {'confidence': 97,
#                'datetime': '2023-03-18 03:50:40',
#                'latitude': -37.0155,
#                'longitude': 148.1432,
#                'surface_temperature_celcius': 80}],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('663d77f75178059695ff6079'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2023',
#  'hotspots': [{'confidence': 85,
#                'datetime': '2023-03-19 04:39:50',
#                'latitude': -37.6605,
#                'longitude': 142.1116,
#                'surface_temperature_celcius': 60},
#               {'confidence': 58,
#                'datetime': '2023-03-19 04:39:20',
#                'latitude': -37.9164,
#                'longitude': 143.4866,
#                'surface_temperature_celcius': 54},
#               {'confidence': 96,
#                'datetime': '2023-03-19 04:39:20',
#                'latitude': -37.6622,
#                'longitude': 142.1001,
#                'surface_temperature_celcius': 79},
#               {'confidence': 63,
#                'datetime': '2023-03-19 04:39:20',
#                'latitude': -37.9257,
#                'longitude': 143.4891,
#                'surface_temperature_celcius': 54},
#               {'confidence': 64,
#                'datetime': '2023-03-19 04:36:00',
#                'latitude': -37.3982,
#                'longitude': 147.0001,
#                'surface_temperature_celcius': 58},
#               {'confidence': 90,
#                'datetime': '2023-03-19 04:36:00',
#                'latitude': -37.4523,
#                'longitude': 147.0175,
#                'surface_temperature_celcius': 66},
#               {'confidence': 59,
#                'datetime': '2023-03-19 04:35:00',
#                'latitude': -37.4023,
#                'longitude': 147.0394,
#                'surface_temperature_celcius': 56},
#               {'confidence': 60,
#                'datetime': '2023-03-19 04:33:50',
#                'latitude': -37.4336,
#                'longitude': 147.0534,
#                'surface_temperature_celcius': 51},
#               {'confidence': 61,
#                'datetime': '2023-03-19 04:33:30',
#                'latitude': -37.4003,
#                'longitude': 147.0448,
#                'surface_temperature_celcius': 55},
#               {'confidence': 53,
#                'datetime': '2023-03-19 04:33:30',
#                'latitude': -37.9184,
#                'longitude': 143.4745,
#                'surface_temperature_celcius': 55},
#               {'confidence': 61,
#                'datetime': '2023-03-19 04:33:10',
#                'latitude': -37.3911,
#                'longitude': 147.037,
#                'surface_temperature_celcius': 50},
#               {'confidence': 98,
#                'datetime': '2023-03-19 04:33:00',
#                'latitude': -37.4261,
#                'longitude': 147.0323,
#                'surface_temperature_celcius': 83},
#               {'confidence': 100,
#                'datetime': '2023-03-19 04:32:50',
#                'latitude': -37.3949,
#                'longitude': 147.0175,
#                'surface_temperature_celcius': 91},
#               {'confidence': 84,
#                'datetime': '2023-03-19 04:32:50',
#                'latitude': -37.671,
#                'longitude': 144.6536,
#                'surface_temperature_celcius': 58},
#               {'confidence': 66,
#                'datetime': '2023-03-19 04:32:50',
#                'latitude': -37.9277,
#                'longitude': 143.477,
#                'surface_temperature_celcius': 55},
#               {'confidence': 100,
#                'datetime': '2023-03-19 04:32:40',
#                'latitude': -37.4224,
#                'longitude': 147.0511,
#                'surface_temperature_celcius': 113},
#               {'confidence': 92,
#                'datetime': '2023-03-19 04:32:40',
#                'latitude': -37.6625,
#                'longitude': 144.287,
#                'surface_temperature_celcius': 70},
#               {'confidence': 100,
#                'datetime': '2023-03-19 04:32:40',
#                'latitude': -37.4375,
#                'longitude': 147.0336,
#                'surface_temperature_celcius': 106},
#               {'confidence': 73,
#                'datetime': '2023-03-19 04:32:40',
#                'latitude': -37.4414,
#                'longitude': 147.0139,
#                'surface_temperature_celcius': 60},
#               {'confidence': 77,
#                'datetime': '2023-03-19 00:15:50',
#                'latitude': -37.4295,
#                'longitude': 147.0428,
#                'surface_temperature_celcius': 59},
#               {'confidence': 60,
#                'datetime': '2023-03-19 00:12:50',
#                'latitude': -37.3942,
#                'longitude': 147.0455,
#                'surface_temperature_celcius': 44}],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 174,
#  '_id': ObjectId('663d77f75178059695ff607a'),
#  'air_temperature_celcius': 23,
#  'date': '20/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.08G',
#  'relative_humidity': 63.8,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('663d77f75178059695ff607b'),
#  'air_temperature_celcius': 20,
#  'date': '21/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.63G',
#  'relative_humidity': 67.4,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('663d77f75178059695ff607c'),
#  'air_temperature_celcius': 18,
#  'date': '22/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 57.5,
#  'station': 948701,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('663d77f75178059695ff607d'),
#  'air_temperature_celcius': 18,
#  'date': '23/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('663d77f75178059695ff607e'),
#  'air_temperature_celcius': 20,
#  'date': '24/3/2023',
#  'hotspots': [{'confidence': 65,
#                'datetime': '2023-03-24 04:58:00',
#                'latitude': -37.1603,
#                'longitude': 142.8088,
#                'surface_temperature_celcius': 50},
#               {'confidence': 55,
#                'datetime': '2023-03-24 04:56:10',
#                'latitude': -37.1684,
#                'longitude': 142.8183,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('663d77f75178059695ff607f'),
#  'air_temperature_celcius': 23,
#  'date': '25/3/2023',
#  'hotspots': [{'confidence': 76,
#                'datetime': '2023-03-25 04:03:10',
#                'latitude': -37.8025,
#                'longitude': 145.8702,
#                'surface_temperature_celcius': 49},
#               {'confidence': 62,
#                'datetime': '2023-03-25 04:03:10',
#                'latitude': -37.8992,
#                'longitude': 143.4534,
#                'surface_temperature_celcius': 54},
#               {'confidence': 78,
#                'datetime': '2023-03-25 03:59:50',
#                'latitude': -37.8758,
#                'longitude': 145.8371,
#                'surface_temperature_celcius': 52},
#               {'confidence': 82,
#                'datetime': '2023-03-25 03:59:50',
#                'latitude': -37.8973,
#                'longitude': 143.4754,
#                'surface_temperature_celcius': 65},
#               {'confidence': 87,
#                'datetime': '2023-03-25 03:58:10',
#                'latitude': -37.7829,
#                'longitude': 143.5056,
#                'surface_temperature_celcius': 62},
#               {'confidence': 95,
#                'datetime': '2023-03-25 03:58:10',
#                'latitude': -37.7805,
#                'longitude': 143.5003,
#                'surface_temperature_celcius': 75},
#               {'confidence': 85,
#                'datetime': '2023-03-25 03:57:10',
#                'latitude': -37.5629,
#                'longitude': 144.752,
#                'surface_temperature_celcius': 59},
#               {'confidence': 100,
#                'datetime': '2023-03-25 03:57:10',
#                'latitude': -37.8122,
#                'longitude': 146.0807,
#                'surface_temperature_celcius': 111},
#               {'confidence': 95,
#                'datetime': '2023-03-25 03:57:10',
#                'latitude': -37.8774,
#                'longitude': 145.8213,
#                'surface_temperature_celcius': 77},
#               {'confidence': 75,
#                'datetime': '2023-03-25 03:56:50',
#                'latitude': -37.5742,
#                'longitude': 144.7536,
#                'surface_temperature_celcius': 49},
#               {'confidence': 100,
#                'datetime': '2023-03-25 03:56:40',
#                'latitude': -37.8881,
#                'longitude': 145.8229,
#                'surface_temperature_celcius': 99},
#               {'confidence': 73,
#                'datetime': '2023-03-25 03:56:40',
#                'latitude': -37.5612,
#                'longitude': 144.7701,
#                'surface_temperature_celcius': 49},
#               {'confidence': 57,
#                'datetime': '2023-03-25 03:56:40',
#                'latitude': -37.9022,
#                'longitude': 143.4607,
#                'surface_temperature_celcius': 57}],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('663d77f75178059695ff6080'),
#  'air_temperature_celcius': 23,
#  'date': '26/3/2023',
#  'hotspots': [{'confidence': 74,
#                'datetime': '2023-03-26 04:47:20',
#                'latitude': -37.665,
#                'longitude': 142.1339,
#                'surface_temperature_celcius': 48},
#               {'confidence': 74,
#                'datetime': '2023-03-26 04:43:40',
#                'latitude': -38.0564,
#                'longitude': 142.8525,
#                'surface_temperature_celcius': 48},
#               {'confidence': 81,
#                'datetime': '2023-03-26 04:43:20',
#                'latitude': -38.018,
#                'longitude': 143.899,
#                'surface_temperature_celcius': 54},
#               {'confidence': 68,
#                'datetime': '2023-03-26 04:41:10',
#                'latitude': -38.1131,
#                'longitude': 143.7173,
#                'surface_temperature_celcius': 44},
#               {'confidence': 80,
#                'datetime': '2023-03-26 04:40:50',
#                'latitude': -38.1106,
#                'longitude': 143.7314,
#                'surface_temperature_celcius': 53},
#               {'confidence': 75,
#                'datetime': '2023-03-26 04:40:10',
#                'latitude': -37.8289,
#                'longitude': 145.9315,
#                'surface_temperature_celcius': 49},
#               {'confidence': 81,
#                'datetime': '2023-03-26 04:39:50',
#                'latitude': -38.0652,
#                'longitude': 142.9781,
#                'surface_temperature_celcius': 54},
#               {'confidence': 71,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -37.522,
#                'longitude': 143.3874,
#                'surface_temperature_celcius': 73},
#               {'confidence': 91,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -38.0674,
#                'longitude': 142.965,
#                'surface_temperature_celcius': 68},
#               {'confidence': 92,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -38.0715,
#                'longitude': 142.9591,
#                'surface_temperature_celcius': 70},
#               {'confidence': 100,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -38.0693,
#                'longitude': 142.9722,
#                'surface_temperature_celcius': 89},
#               {'confidence': 82,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -37.9488,
#                'longitude': 143.8882,
#                'surface_temperature_celcius': 55},
#               {'confidence': 87,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -37.9462,
#                'longitude': 143.9026,
#                'surface_temperature_celcius': 62},
#               {'confidence': 60,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -37.8469,
#                'longitude': 143.5343,
#                'surface_temperature_celcius': 50},
#               {'confidence': 84,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -37.8468,
#                'longitude': 142.8775,
#                'surface_temperature_celcius': 58},
#               {'confidence': 67,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -37.1956,
#                'longitude': 141.0252,
#                'surface_temperature_celcius': 44},
#               {'confidence': 74,
#                'datetime': '2023-03-26 04:39:10',
#                'latitude': -38.0542,
#                'longitude': 142.8655,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 26.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 142,
#  '_id': ObjectId('663d77f75178059695ff6081'),
#  'air_temperature_celcius': 17,
#  'date': '27/3/2023',
#  'hotspots': [],
#  'max_wind_speed': 25.1,
#  'precipitation': '0.16G',
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('663d77f75178059695ff6082'),
#  'air_temperature_celcius': 18,
#  'date': '28/3/2023',
#  'hotspots': [{'confidence': 88,
#                'datetime': '2023-03-28 04:38:00',
#                'latitude': -36.4721,
#                'longitude': 142.2586,
#                'surface_temperature_celcius': 64},
#               {'confidence': 72,
#                'datetime': '2023-03-28 04:37:30',
#                'latitude': -36.7241,
#                'longitude': 141.0073,
#                'surface_temperature_celcius': 46},
#               {'confidence': 86,
#                'datetime': '2023-03-28 04:33:40',
#                'latitude': -38.004,
#                'longitude': 143.9249,
#                'surface_temperature_celcius': 60},
#               {'confidence': 92,
#                'datetime': '2023-03-28 04:33:30',
#                'latitude': -36.4557,
#                'longitude': 142.2434,
#                'surface_temperature_celcius': 71},
#               {'confidence': 95,
#                'datetime': '2023-03-28 04:33:30',
#                'latitude': -36.8009,
#                'longitude': 142.7259,
#                'surface_temperature_celcius': 76},
#               {'confidence': 74,
#                'datetime': '2023-03-28 04:33:20',
#                'latitude': -36.4737,
#                'longitude': 142.2474,
#                'surface_temperature_celcius': 55},
#               {'confidence': 93,
#                'datetime': '2023-03-28 04:32:20',
#                'latitude': -36.8099,
#                'longitude': 142.728,
#                'surface_temperature_celcius': 73},
#               {'confidence': 76,
#                'datetime': '2023-03-28 04:31:50',
#                'latitude': -36.8202,
#                'longitude': 141.9362,
#                'surface_temperature_celcius': 50},
#               {'confidence': 70,
#                'datetime': '2023-03-28 04:31:50',
#                'latitude': -36.9576,
#                'longitude': 141.5387,
#                'surface_temperature_celcius': 45},
#               {'confidence': 83,
#                'datetime': '2023-03-28 04:30:50',
#                'latitude': -36.811,
#                'longitude': 142.2655,
#                'surface_temperature_celcius': 56},
#               {'confidence': 80,
#                'datetime': '2023-03-28 04:30:20',
#                'latitude': -34.395,
#                'longitude': 142.0522,
#                'surface_temperature_celcius': 54},
#               {'confidence': 94,
#                'datetime': '2023-03-28 04:30:10',
#                'latitude': -36.7806,
#                'longitude': 141.5597,
#                'surface_temperature_celcius': 74},
#               {'confidence': 79,
#                'datetime': '2023-03-28 04:30:10',
#                'latitude': -37.639,
#                'longitude': 142.0648,
#                'surface_temperature_celcius': 52},
#               {'confidence': 72,
#                'datetime': '2023-03-28 04:30:10',
#                'latitude': -36.7791,
#                'longitude': 141.5711,
#                'surface_temperature_celcius': 46},
#               {'confidence': 98,
#                'datetime': '2023-03-28 04:30:10',
#                'latitude': -34.3526,
#                'longitude': 141.6458,
#                'surface_temperature_celcius': 82},
#               {'confidence': 81,
#                'datetime': '2023-03-28 04:30:10',
#                'latitude': -36.8189,
#                'longitude': 142.73,
#                'surface_temperature_celcius': 54},
#               {'confidence': 97,
#                'datetime': '2023-03-28 04:30:10',
#                'latitude': -37.0924,
#                'longitude': 141.897,
#                'surface_temperature_celcius': 80},
#               {'confidence': 77,
#                'datetime': '2023-03-28 04:30:10',
#                'latitude': -36.4827,
#                'longitude': 142.2494,
#                'surface_temperature_celcius': 51},
#               {'confidence': 53,
#                'datetime': '2023-03-28 04:29:30',
#                'latitude': -37.6195,
#                'longitude': 143.4212,
#                'surface_temperature_celcius': 46},
#               {'confidence': 81,
#                'datetime': '2023-03-28 04:28:30',
#                'latitude': -34.386,
#                'longitude': 142.0503,
#                'surface_temperature_celcius': 54},
#               {'confidence': 79,
#                'datetime': '2023-03-28 04:28:30',
#                'latitude': -36.8293,
#                'longitude': 141.9382,
#                'surface_temperature_celcius': 52},
#               {'confidence': 88,
# ...
#  'relative_humidity': 56.2,
#  'station': 948702,
#  'windspeed_knots': 16.9}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('663d77f85178059695ff617c'),
#  'air_temperature_celcius': 14,
#  'date': '3/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.03G',
#  'relative_humidity': 48.2,
#  'station': 948702,
#  'windspeed_knots': 12.5}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('663d77f85178059695ff617d'),
#  'air_temperature_celcius': 14,
#  'date': '4/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 48.2,
#  'station': 948702,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 142,
#  '_id': ObjectId('663d77f85178059695ff617e'),
#  'air_temperature_celcius': 17,
#  'date': '5/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 22.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.0,
#  'station': 948702,
#  'windspeed_knots': 14.6}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('663d77f85178059695ff617f'),
#  'air_temperature_celcius': 16,
#  'date': '6/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 51.7,
#  'station': 948702,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('663d77f85178059695ff6180'),
#  'air_temperature_celcius': 15,
#  'date': '7/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '1.26G',
#  'relative_humidity': 51.0,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('663d77f85178059695ff6181'),
#  'air_temperature_celcius': 15,
#  'date': '8/12/2023',
#  'hotspots': [{'confidence': 77,
#                'datetime': '2023-12-08 13:11:44',
#                'latitude': -36.273,
#                'longitude': 146.155,
#                'surface_temperature_celcius': 36},
#               {'confidence': 100,
#                'datetime': '2023-12-08 13:11:44',
#                'latitude': -36.284,
#                'longitude': 146.145,
#                'surface_temperature_celcius': 54},
#               {'confidence': 100,
#                'datetime': '2023-12-08 13:11:44',
#                'latitude': -36.282,
#                'longitude': 146.157,
#                'surface_temperature_celcius': 71},
#               {'confidence': 100,
#                'datetime': '2023-12-08 13:11:43',
#                'latitude': -36.293,
#                'longitude': 146.148,
#                'surface_temperature_celcius': 52},
#               {'confidence': 56,
#                'datetime': '2023-12-08 13:11:43',
#                'latitude': -36.291,
#                'longitude': 146.159,
#                'surface_temperature_celcius': 40}],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 48.1,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('663d77f85178059695ff6182'),
#  'air_temperature_celcius': 17,
#  'date': '9/12/2023',
#  'hotspots': [{'confidence': 87,
#                'datetime': '2023-12-09 00:14:34',
#                'latitude': -36.294,
#                'longitude': 146.149,
#                'surface_temperature_celcius': 61},
#               {'confidence': 81,
#                'datetime': '2023-12-09 00:14:34',
#                'latitude': -36.285,
#                'longitude': 146.151,
#                'surface_temperature_celcius': 54},
#               {'confidence': 84,
#                'datetime': '2023-12-09 00:14:33',
#                'latitude': -36.277,
#                'longitude': 146.165,
#                'surface_temperature_celcius': 58},
#               {'confidence': 86,
#                'datetime': '2023-12-09 00:14:33',
#                'latitude': -36.275,
#                'longitude': 146.154,
#                'surface_temperature_celcius': 60}],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('663d77f85178059695ff6183'),
#  'air_temperature_celcius': 17,
#  'date': '10/12/2023',
#  'hotspots': [{'confidence': 50,
#                'datetime': '2023-12-10 00:57:59',
#                'latitude': -37.987,
#                'longitude': 144.005,
#                'surface_temperature_celcius': 38},
#               {'confidence': 67,
#                'datetime': '2023-12-10 00:56:57',
#                'latitude': -34.289,
#                'longitude': 141.712,
#                'surface_temperature_celcius': 54}],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('663d77f85178059695ff6184'),
#  'air_temperature_celcius': 17,
#  'date': '11/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 156,
#  '_id': ObjectId('663d77f85178059695ff6185'),
#  'air_temperature_celcius': 19,
#  'date': '12/12/2023',
#  'hotspots': [{'confidence': 53,
#                'datetime': '2023-12-12 00:45:38',
#                'latitude': -37.903,
#                'longitude': 145.25,
#                'surface_temperature_celcius': 44}],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 240,
#  '_id': ObjectId('663d77f85178059695ff6186'),
#  'air_temperature_celcius': 28,
#  'date': '13/12/2023',
#  'hotspots': [{'confidence': 83,
#                'datetime': '2023-12-13 04:04:19',
#                'latitude': -38.231,
#                'longitude': 147.172,
#                'surface_temperature_celcius': 60}],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 49.9,
#  'station': 948702,
#  'windspeed_knots': 11.0}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('663d77f85178059695ff6187'),
#  'air_temperature_celcius': 17,
#  'date': '14/12/2023',
#  'hotspots': [{'confidence': 92,
#                'datetime': '2023-12-14 04:47:25',
#                'latitude': -37.95,
#                'longitude': 142.366,
#                'surface_temperature_celcius': 70}],
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('663d77f85178059695ff6188'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'hotspots': [{'confidence': 92,
#                'datetime': '2023-12-15 13:17:17',
#                'latitude': -37.627,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 42},
#               {'confidence': 78,
#                'datetime': '2023-12-15 13:17:17',
#                'latitude': -37.658,
#                'longitude': 149.339,
#                'surface_temperature_celcius': 36},
#               {'confidence': 51,
#                'datetime': '2023-12-15 13:17:17',
#                'latitude': -37.623,
#                'longitude': 149.323,
#                'surface_temperature_celcius': 38},
#               {'confidence': 65,
#                'datetime': '2023-12-15 01:16:23',
#                'latitude': -38.038,
#                'longitude': 142.986,
#                'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('663d77f85178059695ff6189'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'hotspots': [{'confidence': 94,
#                'datetime': '2023-12-16 15:38:39',
#                'latitude': -37.636,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 43},
#               {'confidence': 69,
#                'datetime': '2023-12-16 15:38:39',
#                'latitude': -37.624,
#                'longitude': 149.332,
#                'surface_temperature_celcius': 33},
#               {'confidence': 62,
#                'datetime': '2023-12-16 04:35:15',
#                'latitude': -37.82,
#                'longitude': 142.323,
#                'surface_temperature_celcius': 54},
#               {'confidence': 93,
#                'datetime': '2023-12-16 04:35:13',
#                'latitude': -37.875,
#                'longitude': 142.51,
#                'surface_temperature_celcius': 73},
#               {'confidence': 84,
#                'datetime': '2023-12-16 04:34:58',
#                'latitude': -37.608,
#                'longitude': 149.328,
#                'surface_temperature_celcius': 55},
#               {'confidence': 95,
#                'datetime': '2023-12-16 04:34:58',
#                'latitude': -37.613,
#                'longitude': 149.305,
#                'surface_temperature_celcius': 75},
#               {'confidence': 59,
#                'datetime': '2023-12-16 04:34:57',
#                'latitude': -37.644,
#                'longitude': 149.346,
#                'surface_temperature_celcius': 55},
#               {'confidence': 90,
#                'datetime': '2023-12-16 04:34:57',
#                'latitude': -37.624,
#                'longitude': 149.314,
#                'surface_temperature_celcius': 66},
#               {'confidence': 75,
#                'datetime': '2023-12-16 04:34:57',
#                'latitude': -37.661,
#                'longitude': 149.327,
#                'surface_temperature_celcius': 56},
#               {'confidence': 79,
#                'datetime': '2023-12-16 04:34:57',
#                'latitude': -37.649,
#                'longitude': 149.322,
#                'surface_temperature_celcius': 60},
#               {'confidence': 93,
#                'datetime': '2023-12-16 00:21:12',
#                'latitude': -38.057,
#                'longitude': 144.211,
#                'surface_temperature_celcius': 73},
#               {'confidence': 60,
#                'datetime': '2023-12-16 00:21:11',
#                'latitude': -38.046,
#                'longitude': 144.201,
#                'surface_temperature_celcius': 48},
#               {'confidence': 82,
#                'datetime': '2023-12-16 00:21:11',
#                'latitude': -38.048,
#                'longitude': 144.213,
#                'surface_temperature_celcius': 55},
#               {'confidence': 82,
#                'datetime': '2023-12-16 00:20:53',
#                'latitude': -37.651,
#                'longitude': 149.345,
#                'surface_temperature_celcius': 64},
#               {'confidence': 53,
#                'datetime': '2023-12-16 00:20:53',
#                'latitude': -37.63,
#                'longitude': 149.335,
#                'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('663d77f85178059695ff618a'),
#  'air_temperature_celcius': 21,
#  'date': '17/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 195,
#  '_id': ObjectId('663d77f85178059695ff618b'),
#  'air_temperature_celcius': 25,
#  'date': '18/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 60.9,
#  'station': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('663d77f85178059695ff618c'),
#  'air_temperature_celcius': 21,
#  'date': '19/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 22.9,
#  'precipitation': '0.67G',
#  'relative_humidity': 57.4,
#  'station': 948702,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 144,
#  '_id': ObjectId('663d77f85178059695ff618d'),
#  'air_temperature_celcius': 17,
#  'date': '20/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.00G',
#  'relative_humidity': 51.2,
#  'station': 948702,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('663d77f85178059695ff618e'),
#  'air_temperature_celcius': 17,
#  'date': '21/12/2023',
#  'hotspots': [{'confidence': 72,
#                'datetime': '2023-12-21 04:53:29',
#                'latitude': -38.075,
#                'longitude': 143.76,
#                'surface_temperature_celcius': 46}],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('663d77f85178059695ff618f'),
#  'air_temperature_celcius': 19,
#  'date': '22/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.8,
#  'station': 948702,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('663d77f85178059695ff6190'),
#  'air_temperature_celcius': 19,
#  'date': '23/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 53.9,
#  'station': 948702,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('663d77f85178059695ff6191'),
#  'air_temperature_celcius': 16,
#  'date': '24/12/2023',
#  'hotspots': [{'confidence': 65,
#                'datetime': '2023-12-24 13:12:01',
#                'latitude': -35.646,
#                'longitude': 142.282,
#                'surface_temperature_celcius': 32}],
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.0,
#  'station': 948702,
#  'windspeed_knots': 12.0}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('663d77f85178059695ff6192'),
#  'air_temperature_celcius': 17,
#  'date': '25/12/2023',
#  'hotspots': [{'confidence': 80,
#                'datetime': '2023-12-25 04:29:08',
#                'latitude': -37.708,
#                'longitude': 145.1,
#                'surface_temperature_celcius': 54}],
#  'max_wind_speed': 16.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 50.4,
#  'station': 948702,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('663d77f85178059695ff6193'),
#  'air_temperature_celcius': 22,
#  'date': '26/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.5,
#  'station': 948702,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('663d77f85178059695ff6194'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2023',
#  'hotspots': [{'confidence': 78,
#                'datetime': '2023-12-27 04:16:51',
#                'latitude': -37.966,
#                'longitude': 145.051,
#                'surface_temperature_celcius': 68},
#               {'confidence': 82,
#                'datetime': '2023-12-27 00:02:15',
#                'latitude': -35.541,
#                'longitude': 143.311,
#                'surface_temperature_celcius': 63},
#               {'confidence': 67,
#                'datetime': '2023-12-27 00:02:15',
#                'latitude': -35.554,
#                'longitude': 143.307,
#                'surface_temperature_celcius': 53},
#               {'confidence': 86,
#                'datetime': '2023-12-27 00:02:14',
#                'latitude': -35.543,
#                'longitude': 143.316,
#                'surface_temperature_celcius': 67}],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('663d77f85178059695ff6195'),
#  'air_temperature_celcius': 21,
#  'date': '28/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 61.1,
#  'station': 948702,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('663d77f85178059695ff6196'),
#  'air_temperature_celcius': 19,
#  'date': '29/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.63G',
#  'relative_humidity': 59.7,
#  'station': 948702,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('663d77f85178059695ff6197'),
#  'air_temperature_celcius': 16,
#  'date': '30/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 51.5,
#  'station': 948702,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('663d77f85178059695ff6198'),
#  'air_temperature_celcius': 18,
#  'date': '31/12/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00G',
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('663d77f85178059695ff6199'),
#  'air_temperature_celcius': 19,
#  'date': '1/1/2024',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.9,
#  'station': 948702,
#  'windspeed_knots': 8.1}

# %% [markdown]
# ## **Task 2.2**

# %%
from pprint import pprint

# %% [markdown]
# ##### **a) Climate data on 12th December 2023**

# %%
climate_12_dec = climate_col.find({"date": "12/12/2023"})  #filter query using find

#extract document from returned cursor object
for document in climate_12_dec:
    pprint(document)
# Out:
# {'GHI_w/m2': 156,
#  '_id': ObjectId('663d77f85178059695ff6185'),
#  'air_temperature_celcius': 19,
#  'date': '12/12/2023',
#  'hotspots': [{'confidence': 53,
#                'datetime': '2023-12-12 00:45:38',
#                'latitude': -37.903,
#                'longitude': 145.25,
#                'surface_temperature_celcius': 44}],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %% [markdown]
# ##### **b) Selected data for surface temperature (°C) between 65 °C and 100 °C**

# %%
#extract only required attributes from each matching hotspot document 

#to show hotspot attributes as distinct attributes rather than embedded inside a hotspot document, 
#the path to the attributes is given instead of a boolean value during projection
projected_fields = {
                     "_id": 0,
                     "latitude": "$hotspots.latitude",
                     "longitude": "$hotspots.longitude",
                     "surface_temperature_celcius": "$hotspots.surface_temperature_celcius",
                     "confidence": "$hotspots.confidence"
                    }


pipeline_stages = [{"$unwind": "$hotspots"},  #extract embedded hotspot documents
                   {"$match": {"hotspots.surface_temperature_celcius": {"$gte": 65, "$lte": 100}}},  #filter query on surface temperature
                   {"$project": projected_fields}  #use projection to retrieve selected attributes
                  ]

data = climate_col.aggregate(pipeline_stages)  #execute aggregation pipeline

for document in data:
    pprint(document)
# Out:
# {'confidence': 94,
#  'latitude': -37.2284,
#  'longitude': 147.9187,
#  'surface_temperature_celcius': 73}
# {'confidence': 97,
#  'latitude': -37.6572,
#  'longitude': 142.0703,
#  'surface_temperature_celcius': 80}
# {'confidence': 84,
#  'latitude': -37.0193,
#  'longitude': 148.1459,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.4229,
#  'longitude': 147.027,
#  'surface_temperature_celcius': 99}
# {'confidence': 80,
#  'latitude': -37.0055,
#  'longitude': 148.1582,
#  'surface_temperature_celcius': 68}
# {'confidence': 85,
#  'latitude': -37.4128,
#  'longitude': 147.0242,
#  'surface_temperature_celcius': 98}
# {'confidence': 90,
#  'latitude': -34.357,
#  'longitude': 141.5361,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -34.3539,
#  'longitude': 141.5547,
#  'surface_temperature_celcius': 72}
# {'confidence': 90,
#  'latitude': -36.9939,
#  'longitude': 148.2244,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.9959,
#  'longitude': 148.2118,
#  'surface_temperature_celcius': 75}
# {'confidence': 89,
#  'latitude': -34.3654,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -34.3554,
#  'longitude': 141.5413,
#  'surface_temperature_celcius': 79}
# {'confidence': 94,
#  'latitude': -34.3555,
#  'longitude': 141.5495,
#  'surface_temperature_celcius': 75}
# {'confidence': 94,
#  'latitude': -36.7152,
#  'longitude': 141.3853,
#  'surface_temperature_celcius': 74}
# {'confidence': 97,
#  'latitude': -37.0155,
#  'longitude': 148.1432,
#  'surface_temperature_celcius': 80}
# {'confidence': 96,
#  'latitude': -37.6622,
#  'longitude': 142.1001,
#  'surface_temperature_celcius': 79}
# {'confidence': 90,
#  'latitude': -37.4523,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 66}
# {'confidence': 98,
#  'latitude': -37.4261,
#  'longitude': 147.0323,
#  'surface_temperature_celcius': 83}
# {'confidence': 100,
#  'latitude': -37.3949,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 91}
# {'confidence': 92,
#  'latitude': -37.6625,
#  'longitude': 144.287,
#  'surface_temperature_celcius': 70}
# {'confidence': 82,
#  'latitude': -37.8973,
#  'longitude': 143.4754,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -37.7805,
#  'longitude': 143.5003,
#  'surface_temperature_celcius': 75}
# {'confidence': 95,
#  'latitude': -37.8774,
#  'longitude': 145.8213,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -37.8881,
#  'longitude': 145.8229,
#  'surface_temperature_celcius': 99}
# {'confidence': 71,
#  'latitude': -37.522,
#  'longitude': 143.3874,
#  'surface_temperature_celcius': 73}
# {'confidence': 91,
#  'latitude': -38.0674,
#  'longitude': 142.965,
#  'surface_temperature_celcius': 68}
# {'confidence': 92,
#  'latitude': -38.0715,
#  'longitude': 142.9591,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -38.0693,
#  'longitude': 142.9722,
#  'surface_temperature_celcius': 89}
# {'confidence': 92,
#  'latitude': -36.4557,
#  'longitude': 142.2434,
#  'surface_temperature_celcius': 71}
# {'confidence': 95,
#  'latitude': -36.8009,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 76}
# {'confidence': 93,
#  'latitude': -36.8099,
#  'longitude': 142.728,
#  'surface_temperature_celcius': 73}
# {'confidence': 94,
#  'latitude': -36.7806,
#  'longitude': 141.5597,
#  'surface_temperature_celcius': 74}
# {'confidence': 98,
#  'latitude': -34.3526,
#  'longitude': 141.6458,
#  'surface_temperature_celcius': 82}
# {'confidence': 97,
#  'latitude': -37.0924,
#  'longitude': 141.897,
#  'surface_temperature_celcius': 80}
# {'confidence': 97,
#  'latitude': -37.9452,
#  'longitude': 143.5834,
#  'surface_temperature_celcius': 80}
# {'confidence': 99,
#  'latitude': -34.351,
#  'longitude': 141.6567,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -37.5012,
#  'longitude': 142.5853,
#  'surface_temperature_celcius': 90}
# {'confidence': 97,
#  'latitude': -37.9247,
#  'longitude': 142.8999,
#  'surface_temperature_celcius': 81}
# {'confidence': 97,
#  'latitude': -35.0805,
#  'longitude': 142.4642,
#  'surface_temperature_celcius': 81}
# {'confidence': 87,
#  'latitude': -37.3735,
#  'longitude': 145.886,
#  'surface_temperature_celcius': 96}
# {'confidence': 93,
#  'latitude': -37.7465,
#  'longitude': 143.3806,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -37.8072,
#  'longitude': 145.9738,
#  'surface_temperature_celcius': 77}
# {'confidence': 96,
#  'latitude': -37.3704,
#  'longitude': 145.8942,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -37.297,
#  'longitude': 143.5753,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -37.2988,
#  'longitude': 143.5487,
#  'surface_temperature_celcius': 90}
# {'confidence': 100,
#  'latitude': -37.3025,
#  'longitude': 143.5714,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.383,
#  'longitude': 145.9089,
#  'surface_temperature_celcius': 89}
# {'confidence': 89,
#  'latitude': -37.7446,
#  'longitude': 143.4085,
#  'surface_temperature_celcius': 66}
# {'confidence': 98,
#  'latitude': -37.7509,
#  'longitude': 143.4023,
#  'surface_temperature_celcius': 82}
# {'confidence': 87,
#  'latitude': -37.7974,
#  'longitude': 145.9535,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -35.7657,
#  'longitude': 142.0906,
#  'surface_temperature_celcius': 66}
# {'confidence': 99,
#  'latitude': -37.7236,
#  'longitude': 143.3995,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -37.3046,
#  'longitude': 143.5448,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -36.4312,
#  'longitude': 141.2064,
#  'surface_temperature_celcius': 76}
# {'confidence': 89,
#  'latitude': -36.1556,
#  'longitude': 141.5904,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -35.7647,
#  'longitude': 142.0858,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -35.4033,
#  'longitude': 143.267,
#  'surface_temperature_celcius': 67}
# {'confidence': 64,
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
# {'confidence': 85,
#  'latitude': -36.111,
#  'longitude': 145.124,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.1615,
#  'longitude': 141.8728,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.1122,
#  'longitude': 142.1491,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.3735,
#  'longitude': 145.8384,
#  'surface_temperature_celcius': 95}
# {'confidence': 89,
#  'latitude': -35.4255,
#  'longitude': 143.6306,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -36.1955,
#  'longitude': 145.914,
#  'surface_temperature_celcius': 78}
# {'confidence': 85,
#  'latitude': -35.4533,
#  'longitude': 143.2029,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.5989,
#  'longitude': 141.9771,
#  'surface_temperature_celcius': 81}
# {'confidence': 66,
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
# {'confidence': 97,
#  'latitude': -36.1925,
#  'longitude': 145.93,
#  'surface_temperature_celcius': 79}
# {'confidence': 98,
#  'latitude': -36.095,
#  'longitude': 141.7699,
#  'surface_temperature_celcius': 82}
# {'confidence': 96,
#  'latitude': -36.6006,
#  'longitude': 141.9657,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -37.0769,
#  'longitude': 141.042,
#  'surface_temperature_celcius': 72}
# {'confidence': 79,
#  'latitude': -36.883,
#  'longitude': 142.1637,
#  'surface_temperature_celcius': 67}
# {'confidence': 87,
#  'latitude': -36.0973,
#  'longitude': 143.4279,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -36.1819,
#  'longitude': 145.9269,
#  'surface_temperature_celcius': 98}
# {'confidence': 87,
#  'latitude': -37.6387,
#  'longitude': 142.9032,
#  'surface_temperature_celcius': 88}
# {'confidence': 93,
#  'latitude': -37.6439,
#  'longitude': 142.913,
#  'surface_temperature_celcius': 83}
# {'confidence': 93,
#  'latitude': -37.3165,
#  'longitude': 147.4932,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -37.3158,
#  'longitude': 147.4986,
#  'surface_temperature_celcius': 76}
# {'confidence': 89,
#  'latitude': -37.4471,
#  'longitude': 147.6331,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -37.7835,
#  'longitude': 148.4138,
#  'surface_temperature_celcius': 66}
# {'confidence': 89,
#  'latitude': -37.4449,
#  'longitude': 147.6594,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -37.4323,
#  'longitude': 147.6583,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.4343,
#  'longitude': 147.6327,
#  'surface_temperature_celcius': 92}
# {'confidence': 84,
#  'latitude': -37.5816,
#  'longitude': 148.5862,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.6334,
#  'longitude': 142.2244,
#  'surface_temperature_celcius': 69}
# {'confidence': 76,
#  'latitude': -37.7966,
#  'longitude': 142.3196,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -35.805,
#  'longitude': 142.1326,
#  'surface_temperature_celcius': 95}
# {'confidence': 100,
#  'latitude': -37.8429,
#  'longitude': 143.8366,
#  'surface_temperature_celcius': 88}
# {'confidence': 77,
#  'latitude': -37.8062,
#  'longitude': 143.3598,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -36.9918,
#  'longitude': 141.8667,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -36.1104,
#  'longitude': 145.9829,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.782,
#  'longitude': 148.3844,
#  'surface_temperature_celcius': 99}
# {'confidence': 89,
#  'latitude': -36.9902,
#  'longitude': 141.879,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -37.745,
#  'longitude': 142.993,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.0157,
#  'longitude': 145.9414,
#  'surface_temperature_celcius': 70}
# {'confidence': 99,
#  'latitude': -37.777,
#  'longitude': 148.4128,
#  'surface_temperature_celcius': 85}
# {'confidence': 93,
#  'latitude': -37.5888,
#  'longitude': 148.5949,
#  'surface_temperature_celcius': 72}
# {'confidence': 89,
#  'latitude': -34.3943,
#  'longitude': 141.7567,
#  'surface_temperature_celcius': 65}
# {'confidence': 81,
#  'latitude': -36.0844,
#  'longitude': 141.4934,
#  'surface_temperature_celcius': 71}
# {'confidence': 91,
#  'latitude': -36.031,
#  'longitude': 145.6824,
#  'surface_temperature_celcius': 69}
# {'confidence': 86,
#  'latitude': -37.5814,
#  'longitude': 148.5777,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -37.5788,
#  'longitude': 148.592,
#  'surface_temperature_celcius': 67}
# {'confidence': 90,
#  'latitude': -36.6384,
#  'longitude': 142.4075,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -35.811,
#  'longitude': 142.1403,
#  'surface_temperature_celcius': 96}
# {'confidence': 100,
#  'latitude': -36.9034,
#  'longitude': 141.0013,
#  'surface_temperature_celcius': 95}
# {'confidence': 88,
#  'latitude': -37.7746,
#  'longitude': 148.3673,
#  'surface_temperature_celcius': 65}
# {'confidence': 83,
#  'latitude': -37.803,
#  'longitude': 142.3151,
#  'surface_temperature_celcius': 78}
# {'confidence': 96,
#  'latitude': -37.7542,
#  'longitude': 142.9949,
#  'surface_temperature_celcius': 77}
# {'confidence': 91,
#  'latitude': -37.3803,
#  'longitude': 145.611,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -37.7617,
#  'longitude': 143.081,
#  'surface_temperature_celcius': 81}
# {'confidence': 92,
#  'latitude': -37.8161,
#  'longitude': 142.9286,
#  'surface_temperature_celcius': 71}
# {'confidence': 90,
#  'latitude': -36.0387,
#  'longitude': 145.6787,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -36.6349,
#  'longitude': 142.2125,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -36.9018,
#  'longitude': 141.0146,
#  'surface_temperature_celcius': 100}
# {'confidence': 86,
#  'latitude': -36.6986,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -38.0052,
#  'longitude': 142.6179,
#  'surface_temperature_celcius': 89}
# {'confidence': 100,
#  'latitude': -37.2168,
#  'longitude': 147.4748,
#  'surface_temperature_celcius': 89}
# {'confidence': 96,
#  'latitude': -37.222,
#  'longitude': 147.4689,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -37.2063,
#  'longitude': 147.4713,
#  'surface_temperature_celcius': 70}
# {'confidence': 92,
#  'latitude': -37.2082,
#  'longitude': 147.4368,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -37.224,
#  'longitude': 147.4347,
#  'surface_temperature_celcius': 76}
# {'confidence': 67,
#  'latitude': -37.34,
#  'longitude': 149.3668,
#  'surface_temperature_celcius': 74}
# {'confidence': 99,
#  'latitude': -36.7287,
#  'longitude': 142.6017,
#  'surface_temperature_celcius': 85}
# {'confidence': 91,
#  'latitude': -35.2363,
#  'longitude': 143.0004,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -35.2378,
#  'longitude': 142.9864,
#  'surface_temperature_celcius': 94}
# {'confidence': 98,
#  'latitude': -35.2381,
#  'longitude': 142.994,
#  'surface_temperature_celcius': 83}
# {'confidence': 66,
#  'latitude': -37.3493,
#  'longitude': 149.3691,
#  'surface_temperature_celcius': 80}
# {'confidence': 90,
#  'latitude': -36.7165,
#  'longitude': 142.6155,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -37.5812,
#  'longitude': 142.7374,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -37.5949,
#  'longitude': 142.6857,
#  'surface_temperature_celcius': 98}
# {'confidence': 95,
#  'latitude': -37.8247,
#  'longitude': 143.6243,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.4028,
#  'longitude': 143.6932,
#  'surface_temperature_celcius': 75}
# {'confidence': 92,
#  'latitude': -37.4033,
#  'longitude': 143.6884,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.8249,
#  'longitude': 143.6174,
#  'surface_temperature_celcius': 98}
# {'confidence': 93,
#  'latitude': -36.6823,
#  'longitude': 142.5024,
#  'surface_temperature_celcius': 71}
# {'confidence': 93,
#  'latitude': -36.4489,
#  'longitude': 144.7685,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -36.9498,
#  'longitude': 142.2012,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -36.1941,
#  'longitude': 143.1604,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -36.4142,
#  'longitude': 143.1077,
#  'surface_temperature_celcius': 97}
# {'confidence': 92,
#  'latitude': -36.1924,
#  'longitude': 143.1716,
#  'surface_temperature_celcius': 70}
# {'confidence': 89,
#  'latitude': -36.0295,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.0761,
#  'longitude': 141.0574,
#  'surface_temperature_celcius': 89}
# {'confidence': 93,
#  'latitude': -35.0616,
#  'longitude': 141.4417,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -36.3999,
#  'longitude': 144.737,
#  'surface_temperature_celcius': 88}
# {'confidence': 91,
#  'latitude': -36.1748,
#  'longitude': 145.7582,
#  'surface_temperature_celcius': 69}
# {'confidence': 99,
#  'latitude': -36.0691,
#  'longitude': 145.7797,
#  'surface_temperature_celcius': 85}
# {'confidence': 90,
#  'latitude': -35.1949,
#  'longitude': 141.0622,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -36.91,
#  'longitude': 141.2705,
#  'surface_temperature_celcius': 96}
# {'confidence': 89,
#  'latitude': -35.8071,
#  'longitude': 142.7318,
#  'surface_temperature_celcius': 66}
# {'confidence': 97,
#  'latitude': -36.7787,
#  'longitude': 141.4449,
#  'surface_temperature_celcius': 80}
# {'confidence': 98,
#  'latitude': -36.2948,
#  'longitude': 141.3486,
#  'surface_temperature_celcius': 82}
# {'confidence': 89,
#  'latitude': -38.1561,
#  'longitude': 143.7846,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -37.8185,
#  'longitude': 142.5609,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -36.1771,
#  'longitude': 145.7451,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -38.027,
#  'longitude': 142.3844,
#  'surface_temperature_celcius': 95}
# {'confidence': 89,
#  'latitude': -35.7642,
#  'longitude': 143.3321,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -36.429,
#  'longitude': 141.5759,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.1346,
#  'longitude': 145.2196,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.0899,
#  'longitude': 141.0238,
#  'surface_temperature_celcius': 90}
# {'confidence': 95,
#  'latitude': -36.3823,
#  'longitude': 141.3146,
#  'surface_temperature_celcius': 77}
# {'confidence': 90,
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.5243,
#  'longitude': 142.0839,
#  'surface_temperature_celcius': 72}
# {'confidence': 98,
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'surface_temperature_celcius': 82}
# {'confidence': 90,
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.9364,
#  'longitude': 143.4996,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.3847,
#  'longitude': 142.8935,
#  'surface_temperature_celcius': 88}
# {'confidence': 100,
#  'latitude': -35.6374,
#  'longitude': 142.3787,
#  'surface_temperature_celcius': 95}
# {'confidence': 90,
#  'latitude': -36.8835,
#  'longitude': 142.2098,
#  'surface_temperature_celcius': 67}
# {'confidence': 100,
#  'latitude': -36.4125,
#  'longitude': 143.1189,
#  'surface_temperature_celcius': 92}
# {'confidence': 97,
#  'latitude': -37.0669,
#  'longitude': 141.0556,
#  'surface_temperature_celcius': 80}
# {'confidence': 92,
#  'latitude': -36.0714,
#  'longitude': 145.7665,
#  'surface_temperature_celcius': 71}
# {'confidence': 94,
#  'latitude': -36.2933,
#  'longitude': 141.36,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -37.4591,
#  'longitude': 144.9492,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -36.3487,
#  'longitude': 145.5315,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -36.5399,
#  'longitude': 144.678,
#  'surface_temperature_celcius': 66}
# {'confidence': 97,
#  'latitude': -36.8158,
#  'longitude': 142.6229,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.4518,
#  'longitude': 144.7752,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -36.7903,
#  'longitude': 141.618,
#  'surface_temperature_celcius': 67}
# {'confidence': 97,
#  'latitude': -36.1067,
#  'longitude': 143.7948,
#  'surface_temperature_celcius': 79}
# {'confidence': 89,
#  'latitude': -36.1441,
#  'longitude': 145.2221,
#  'surface_temperature_celcius': 65}
# {'confidence': 94,
#  'latitude': -36.4816,
#  'longitude': 141.6635,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -36.0837,
#  'longitude': 144.2448,
#  'surface_temperature_celcius': 87}
# {'confidence': 90,
#  'latitude': -36.782,
#  'longitude': 141.8851,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.5586,
#  'longitude': 144.0423,
#  'surface_temperature_celcius': 71}
# {'confidence': 90,
#  'latitude': -36.5568,
#  'longitude': 144.0538,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -36.4538,
#  'longitude': 144.763,
#  'surface_temperature_celcius': 81}
# {'confidence': 91,
#  'latitude': -36.4612,
#  'longitude': 144.7775,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.7089,
#  'longitude': 143.3518,
#  'surface_temperature_celcius': 93}
# {'confidence': 97,
#  'latitude': -36.601,
#  'longitude': 144.6378,
#  'surface_temperature_celcius': 80}
# {'confidence': 95,
#  'latitude': -36.8681,
#  'longitude': 143.5186,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.1999,
#  'longitude': 143.8231,
#  'surface_temperature_celcius': 90}
# {'confidence': 91,
#  'latitude': -37.6171,
#  'longitude': 142.9426,
#  'surface_temperature_celcius': 68}
# {'confidence': 84,
#  'latitude': -37.7587,
#  'longitude': 142.8521,
#  'surface_temperature_celcius': 80}
# {'confidence': 91,
#  'latitude': -37.4611,
#  'longitude': 144.9371,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -38.0254,
#  'longitude': 142.3959,
#  'surface_temperature_celcius': 99}
# {'confidence': 89,
#  'latitude': -37.88,
#  'longitude': 143.7233,
#  'surface_temperature_celcius': 65}
# {'confidence': 99,
#  'latitude': -37.8885,
#  'longitude': 143.9157,
#  'surface_temperature_celcius': 85}
# {'confidence': 95,
#  'latitude': -35.0706,
#  'longitude': 141.4435,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -38.0795,
#  'longitude': 143.2449,
#  'surface_temperature_celcius': 91}
# {'confidence': 100,
#  'latitude': -35.1857,
#  'longitude': 141.0604,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -35.6469,
#  'longitude': 142.376,
#  'surface_temperature_celcius': 93}
# {'confidence': 91,
#  'latitude': -35.6453,
#  'longitude': 142.387,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -36.4409,
#  'longitude': 141.6948,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -37.9174,
#  'longitude': 145.8678,
#  'surface_temperature_celcius': 93}
# {'confidence': 95,
#  'latitude': -37.9152,
#  'longitude': 145.8808,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.8906,
#  'longitude': 146.2035,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -35.8182,
#  'longitude': 143.8739,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -37.9246,
#  'longitude': 146.2464,
#  'surface_temperature_celcius': 96}
# {'confidence': 94,
#  'latitude': -36.3313,
#  'longitude': 141.0017,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.2857,
#  'longitude': 141.3467,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.0749,
#  'longitude': 143.4058,
#  'surface_temperature_celcius': 70}
# {'confidence': 91,
#  'latitude': -36.4449,
#  'longitude': 140.9836,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.3972,
#  'longitude': 141.6041,
#  'surface_temperature_celcius': 90}
# {'confidence': 90,
#  'latitude': -36.5532,
#  'longitude': 142.5349,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.1367,
#  'longitude': 145.2071,
#  'surface_temperature_celcius': 71}
# {'confidence': 96,
#  'latitude': -36.1518,
#  'longitude': 144.0233,
#  'surface_temperature_celcius': 79}
# {'confidence': 95,
#  'latitude': -36.1418,
#  'longitude': 144.0261,
#  'surface_temperature_celcius': 76}
# {'confidence': 75,
#  'latitude': -36.7499,
#  'longitude': 141.3006,
#  'surface_temperature_celcius': 99}
# {'confidence': 84,
#  'latitude': -36.7432,
#  'longitude': 141.3296,
#  'surface_temperature_celcius': 79}
# {'confidence': 84,
#  'latitude': -36.7531,
#  'longitude': 141.3253,
#  'surface_temperature_celcius': 78}
# {'confidence': 99,
#  'latitude': -36.7943,
#  'longitude': 143.9571,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -36.7957,
#  'longitude': 143.9652,
#  'surface_temperature_celcius': 87}
# {'confidence': 98,
#  'latitude': -36.9329,
#  'longitude': 143.7796,
#  'surface_temperature_celcius': 82}
# {'confidence': 99,
#  'latitude': -35.8276,
#  'longitude': 143.7549,
#  'surface_temperature_celcius': 85}
# {'confidence': 78,
#  'latitude': -35.9326,
#  'longitude': 141.958,
#  'surface_temperature_celcius': 66}
# {'confidence': 91,
#  'latitude': -36.6892,
#  'longitude': 145.2775,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -36.73,
#  'longitude': 143.935,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -36.8283,
#  'longitude': 143.4605,
#  'surface_temperature_celcius': 93}
# {'confidence': 97,
#  'latitude': -36.6527,
#  'longitude': 142.7392,
#  'surface_temperature_celcius': 81}
# {'confidence': 96,
#  'latitude': -36.1898,
#  'longitude': 145.0922,
#  'surface_temperature_celcius': 78}
# {'confidence': 96,
#  'latitude': -36.8298,
#  'longitude': 143.4483,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -36.6615,
#  'longitude': 144.6014,
#  'surface_temperature_celcius': 90}
# {'confidence': 93,
#  'latitude': -36.8238,
#  'longitude': 143.5724,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -36.1988,
#  'longitude': 145.0941,
#  'surface_temperature_celcius': 100}
# {'confidence': 91,
#  'latitude': -36.7651,
#  'longitude': 143.5801,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.5199,
#  'longitude': 144.7311,
#  'surface_temperature_celcius': 77}
# {'confidence': 91,
#  'latitude': -37.0782,
#  'longitude': 145.3625,
#  'surface_temperature_celcius': 68}
# {'confidence': 94,
#  'latitude': -36.3966,
#  'longitude': 141.406,
#  'surface_temperature_celcius': 74}
# {'confidence': 90,
#  'latitude': -37.1349,
#  'longitude': 141.9491,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -37.6397,
#  'longitude': 142.5968,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -37.6267,
#  'longitude': 142.9993,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.5871,
#  'longitude': 144.4958,
#  'surface_temperature_celcius': 72}
# {'confidence': 89,
#  'latitude': -36.2618,
#  'longitude': 141.8783,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -36.6828,
#  'longitude': 144.784,
#  'surface_temperature_celcius': 66}
# {'confidence': 89,
#  'latitude': -37.4843,
#  'longitude': 143.0592,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -37.7274,
#  'longitude': 142.9536,
#  'surface_temperature_celcius': 73}
# {'confidence': 91,
#  'latitude': -37.6964,
#  'longitude': 142.8583,
#  'surface_temperature_celcius': 69}
# {'confidence': 98,
#  'latitude': -38.0509,
#  'longitude': 143.9423,
#  'surface_temperature_celcius': 82}
# {'confidence': 92,
#  'latitude': -37.9284,
#  'longitude': 143.108,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.5701,
#  'longitude': 142.6497,
#  'surface_temperature_celcius': 94}
# {'confidence': 90,
#  'latitude': -36.7101,
#  'longitude': 142.3865,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -38.1693,
#  'longitude': 143.0466,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.7128,
#  'longitude': 142.3717,
#  'surface_temperature_celcius': 77}
# {'confidence': 97,
#  'latitude': -37.4885,
#  'longitude': 142.0658,
#  'surface_temperature_celcius': 81}
# {'confidence': 77,
#  'latitude': -36.7101,
#  'longitude': 142.981,
#  'surface_temperature_celcius': 68}
# {'confidence': 89,
#  'latitude': -37.0959,
#  'longitude': 143.8206,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.9594,
#  'longitude': 143.5638,
#  'surface_temperature_celcius': 87}
# {'confidence': 98,
#  'latitude': -36.5921,
#  'longitude': 144.4905,
#  'surface_temperature_celcius': 82}
# {'confidence': 96,
#  'latitude': -36.6787,
#  'longitude': 144.8042,
#  'surface_temperature_celcius': 79}
# {'confidence': 84,
#  'latitude': -38.0423,
#  'longitude': 146.4048,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -38.1224,
#  'longitude': 143.7553,
#  'surface_temperature_celcius': 73}
# {'confidence': 94,
#  'latitude': -38.0792,
#  'longitude': 143.7361,
#  'surface_temperature_celcius': 93}
# {'confidence': 93,
#  'latitude': -37.9157,
#  'longitude': 143.3544,
#  'surface_temperature_celcius': 72}
# {'confidence': 96,
#  'latitude': -37.7935,
#  'longitude': 143.1606,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -37.7756,
#  'longitude': 143.1388,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -37.7171,
#  'longitude': 142.9505,
#  'surface_temperature_celcius': 68}
# {'confidence': 94,
#  'latitude': -37.7236,
#  'longitude': 142.947,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -37.7002,
#  'longitude': 142.9562,
#  'surface_temperature_celcius': 89}
# {'confidence': 92,
#  'latitude': -37.6498,
#  'longitude': 142.5997,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.5728,
#  'longitude': 142.6348,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.4352,
#  'longitude': 143.1444,
#  'surface_temperature_celcius': 96}
# {'confidence': 92,
#  'latitude': -36.5828,
#  'longitude': 144.5775,
#  'surface_temperature_celcius': 70}
# {'confidence': 96,
#  'latitude': -36.5987,
#  'longitude': 144.4995,
#  'surface_temperature_celcius': 79}
# {'confidence': 98,
#  'latitude': -36.5262,
#  'longitude': 144.5737,
#  'surface_temperature_celcius': 84}
# {'confidence': 95,
#  'latitude': -36.6995,
#  'longitude': 142.978,
#  'surface_temperature_celcius': 76}
# {'confidence': 93,
#  'latitude': -36.8879,
#  'longitude': 141.6647,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -35.8768,
#  'longitude': 145.4627,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -36.4899,
#  'longitude': 142.2805,
#  'surface_temperature_celcius': 73}
# {'confidence': 93,
#  'latitude': -36.663,
#  'longitude': 141.3038,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -36.092,
#  'longitude': 141.7306,
#  'surface_temperature_celcius': 75}
# {'confidence': 89,
#  'latitude': -34.9023,
#  'longitude': 142.0557,
#  'surface_temperature_celcius': 65}
# {'confidence': 91,
#  'latitude': -36.2637,
#  'longitude': 145.3649,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -37.2609,
#  'longitude': 141.7999,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.91,
#  'longitude': 141.0704,
#  'surface_temperature_celcius': 73}
# {'confidence': 92,
#  'latitude': -36.2652,
#  'longitude': 145.3769,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -36.738,
#  'longitude': 142.1177,
#  'surface_temperature_celcius': 77}
# {'confidence': 89,
#  'latitude': -37.876,
#  'longitude': 143.7804,
#  'surface_temperature_celcius': 65}
# {'confidence': 88,
#  'latitude': -36.1546,
#  'longitude': 141.8146,
#  'surface_temperature_celcius': 74}
# {'confidence': 87,
#  'latitude': -37.9091,
#  'longitude': 143.5105,
#  'surface_temperature_celcius': 70}
# {'confidence': 80,
#  'latitude': -36.1559,
#  'longitude': 141.8102,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -37.9071,
#  'longitude': 143.538,
#  'surface_temperature_celcius': 88}
# {'confidence': 100,
#  'latitude': -37.3902,
#  'longitude': 148.2955,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.5027,
#  'longitude': 146.347,
#  'surface_temperature_celcius': 95}
# {'confidence': 100,
#  'latitude': -37.5043,
#  'longitude': 146.3299,
#  'surface_temperature_celcius': 93}
# {'confidence': 93,
#  'latitude': -36.1964,
#  'longitude': 144.5217,
#  'surface_temperature_celcius': 72}
# {'confidence': 93,
#  'latitude': -37.769,
#  'longitude': 147.94,
#  'surface_temperature_celcius': 72}
# {'confidence': 90,
#  'latitude': -36.1303,
#  'longitude': 146.3606,
#  'surface_temperature_celcius': 67}
# {'confidence': 98,
#  'latitude': -36.1345,
#  'longitude': 146.351,
#  'surface_temperature_celcius': 84}
# {'confidence': 99,
#  'latitude': -36.1586,
#  'longitude': 145.6666,
#  'surface_temperature_celcius': 85}
# {'confidence': 96,
#  'latitude': -36.5847,
#  'longitude': 145.1968,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -36.9111,
#  'longitude': 142.692,
#  'surface_temperature_celcius': 72}
# {'confidence': 99,
#  'latitude': -37.5115,
#  'longitude': 143.14,
#  'surface_temperature_celcius': 86}
# {'confidence': 86,
#  'latitude': -37.6775,
#  'longitude': 148.5131,
#  'surface_temperature_celcius': 78}
# {'confidence': 87,
#  'latitude': -36.3332,
#  'longitude': 145.8594,
#  'surface_temperature_celcius': 90}
# {'confidence': 70,
#  'latitude': -36.9303,
#  'longitude': 143.1034,
#  'surface_temperature_celcius': 72}
# {'confidence': 83,
#  'latitude': -36.3195,
#  'longitude': 146.0601,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.5839,
#  'longitude': 143.0588,
#  'surface_temperature_celcius': 99}
# {'confidence': 100,
#  'latitude': -36.5854,
#  'longitude': 143.0462,
#  'surface_temperature_celcius': 94}
# {'confidence': 95,
#  'latitude': -36.3014,
#  'longitude': 143.203,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -38.1917,
#  'longitude': 147.0745,
#  'surface_temperature_celcius': 94}
# {'confidence': 95,
#  'latitude': -38.1987,
#  'longitude': 147.0666,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -36.5454,
#  'longitude': 144.7402,
#  'surface_temperature_celcius': 96}
# {'confidence': 92,
#  'latitude': -36.7593,
#  'longitude': 142.895,
#  'surface_temperature_celcius': 69}
# {'confidence': 90,
#  'latitude': -36.3435,
#  'longitude': 141.5513,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -36.6942,
#  'longitude': 143.8021,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -36.3459,
#  'longitude': 141.5586,
#  'surface_temperature_celcius': 91}
# {'confidence': 93,
#  'latitude': -36.4046,
#  'longitude': 141.1534,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -36.0594,
#  'longitude': 141.5907,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -36.0576,
#  'longitude': 141.6122,
#  'surface_temperature_celcius': 94}
# {'confidence': 93,
#  'latitude': -36.388,
#  'longitude': 141.8309,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.094,
#  'longitude': 145.7646,
#  'surface_temperature_celcius': 67}
# {'confidence': 99,
#  'latitude': -36.5438,
#  'longitude': 144.7548,
#  'surface_temperature_celcius': 84}
# {'confidence': 95,
#  'latitude': -36.6537,
#  'longitude': 143.8781,
#  'surface_temperature_celcius': 76}
# {'confidence': 92,
#  'latitude': -36.663,
#  'longitude': 142.8567,
#  'surface_temperature_celcius': 71}
# {'confidence': 94,
#  'latitude': -37.6982,
#  'longitude': 143.0549,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.7187,
#  'longitude': 143.805,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -36.7742,
#  'longitude': 145.1991,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -36.5061,
#  'longitude': 144.5675,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.4035,
#  'longitude': 140.9935,
#  'surface_temperature_celcius': 95}
# {'confidence': 99,
#  'latitude': -36.4286,
#  'longitude': 141.1567,
#  'surface_temperature_celcius': 84}
# {'confidence': 91,
#  'latitude': -36.3635,
#  'longitude': 142.2809,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.664,
#  'longitude': 142.8802,
#  'surface_temperature_celcius': 87}
# {'confidence': 91,
#  'latitude': -36.6564,
#  'longitude': 142.8615,
#  'surface_temperature_celcius': 69}
# {'confidence': 93,
#  'latitude': -36.6657,
#  'longitude': 143.1675,
#  'surface_temperature_celcius': 72}
# {'confidence': 98,
#  'latitude': -36.8742,
#  'longitude': 142.7177,
#  'surface_temperature_celcius': 84}
# {'confidence': 91,
#  'latitude': -36.7751,
#  'longitude': 145.1696,
#  'surface_temperature_celcius': 68}
# {'confidence': 91,
#  'latitude': -36.3961,
#  'longitude': 140.9781,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -36.7708,
#  'longitude': 145.1908,
#  'surface_temperature_celcius': 98}
# {'confidence': 98,
#  'latitude': -37.758,
#  'longitude': 143.179,
#  'surface_temperature_celcius': 82}
# {'confidence': 94,
#  'latitude': -37.7609,
#  'longitude': 143.1633,
#  'surface_temperature_celcius': 74}
# {'confidence': 89,
#  'latitude': -36.5116,
#  'longitude': 144.562,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.803,
#  'longitude': 142.9261,
#  'surface_temperature_celcius': 70}
# {'confidence': 89,
#  'latitude': -36.4143,
#  'longitude': 143.272,
#  'surface_temperature_celcius': 65}
# {'confidence': 99,
#  'latitude': -36.7153,
#  'longitude': 143.8226,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -36.8791,
#  'longitude': 142.7261,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -36.7309,
#  'longitude': 142.3633,
#  'surface_temperature_celcius': 88}
# {'confidence': 92,
#  'latitude': -36.882,
#  'longitude': 142.7108,
#  'surface_temperature_celcius': 70}
# {'confidence': 93,
#  'latitude': -37.5135,
#  'longitude': 142.7238,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -36.2121,
#  'longitude': 144.6885,
#  'surface_temperature_celcius': 74}
# {'confidence': 97,
#  'latitude': -36.2206,
#  'longitude': 144.6856,
#  'surface_temperature_celcius': 80}
# {'confidence': 88,
#  'latitude': -38.0132,
#  'longitude': 146.5269,
#  'surface_temperature_celcius': 73}
# {'confidence': 87,
#  'latitude': -38.0148,
#  'longitude': 146.5413,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.8412,
#  'longitude': 147.2536,
#  'surface_temperature_celcius': 87}
# {'confidence': 96,
#  'latitude': -37.8429,
#  'longitude': 147.2691,
#  'surface_temperature_celcius': 78}
# {'confidence': 95,
#  'latitude': -36.6139,
#  'longitude': 143.501,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.9509,
#  'longitude': 143.9599,
#  'surface_temperature_celcius': 76}
# {'confidence': 97,
#  'latitude': -36.6224,
#  'longitude': 143.5092,
#  'surface_temperature_celcius': 80}
# {'confidence': 96,
#  'latitude': -38.0933,
#  'longitude': 143.9824,
#  'surface_temperature_celcius': 78}
# {'confidence': 91,
#  'latitude': -35.6138,
#  'longitude': 143.8666,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.0885,
#  'longitude': 145.0359,
#  'surface_temperature_celcius': 76}
# {'confidence': 96,
#  'latitude': -36.3193,
#  'longitude': 145.9162,
#  'surface_temperature_celcius': 78}
# {'confidence': 98,
#  'latitude': -36.0652,
#  'longitude': 146.0764,
#  'surface_temperature_celcius': 82}
# {'confidence': 100,
#  'latitude': -36.0682,
#  'longitude': 146.0602,
#  'surface_temperature_celcius': 90}
# {'confidence': 92,
#  'latitude': -37.7889,
#  'longitude': 143.1324,
#  'surface_temperature_celcius': 71}
# {'confidence': 93,
#  'latitude': -36.2306,
#  'longitude': 143.6408,
#  'surface_temperature_celcius': 72}
# {'confidence': 91,
#  'latitude': -36.4168,
#  'longitude': 141.6939,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -36.4211,
#  'longitude': 141.6875,
#  'surface_temperature_celcius': 81}
# {'confidence': 96,
#  'latitude': -36.8094,
#  'longitude': 142.8885,
#  'surface_temperature_celcius': 77}
# {'confidence': 84,
#  'latitude': -37.8323,
#  'longitude': 147.2232,
#  'surface_temperature_celcius': 68}
# {'confidence': 98,
#  'latitude': -38.2853,
#  'longitude': 145.9519,
#  'surface_temperature_celcius': 83}
# {'confidence': 98,
#  'latitude': -38.2375,
#  'longitude': 142.8363,
#  'surface_temperature_celcius': 82}
# {'confidence': 92,
#  'latitude': -37.4463,
#  'longitude': 142.7829,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -37.6854,
#  'longitude': 143.4543,
#  'surface_temperature_celcius': 76}
# {'confidence': 99,
#  'latitude': -38.0881,
#  'longitude': 143.9391,
#  'surface_temperature_celcius': 84}
# {'confidence': 96,
#  'latitude': -38.0866,
#  'longitude': 143.9534,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -38.2391,
#  'longitude': 142.82,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -38.5123,
#  'longitude': 146.4007,
#  'surface_temperature_celcius': 89}
# {'confidence': 96,
#  'latitude': -36.3438,
#  'longitude': 141.5832,
#  'surface_temperature_celcius': 78}
# {'confidence': 94,
#  'latitude': -37.4357,
#  'longitude': 142.7813,
#  'surface_temperature_celcius': 74}
# {'confidence': 99,
#  'latitude': -37.5867,
#  'longitude': 143.6256,
#  'surface_temperature_celcius': 85}
# {'confidence': 90,
#  'latitude': -36.2911,
#  'longitude': 141.1664,
#  'surface_temperature_celcius': 67}
# {'confidence': 96,
#  'latitude': -36.2842,
#  'longitude': 141.1741,
#  'surface_temperature_celcius': 79}
# {'confidence': 89,
#  'latitude': -36.7218,
#  'longitude': 141.6411,
#  'surface_temperature_celcius': 65}
# {'confidence': 84,
#  'latitude': -37.3656,
#  'longitude': 141.3903,
#  'surface_temperature_celcius': 78}
# {'confidence': 94,
#  'latitude': -36.4179,
#  'longitude': 144.2924,
#  'surface_temperature_celcius': 75}
# {'confidence': 92,
#  'latitude': -36.3207,
#  'longitude': 140.9737,
#  'surface_temperature_celcius': 70}
# {'confidence': 99,
#  'latitude': -36.2882,
#  'longitude': 141.1821,
#  'surface_temperature_celcius': 86}
# {'confidence': 91,
#  'latitude': -36.3153,
#  'longitude': 140.9789,
#  'surface_temperature_celcius': 69}
# {'confidence': 97,
#  'latitude': -36.4169,
#  'longitude': 144.2994,
#  'surface_temperature_celcius': 81}
# {'confidence': 93,
#  'latitude': -37.4671,
#  'longitude': 145.9962,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.3254,
#  'longitude': 144.3638,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.0816,
#  'longitude': 145.859,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -36.1532,
#  'longitude': 143.5527,
#  'surface_temperature_celcius': 90}
# {'confidence': 100,
#  'latitude': -36.0077,
#  'longitude': 141.7747,
#  'surface_temperature_celcius': 93}
# {'confidence': 94,
#  'latitude': -36.0828,
#  'longitude': 145.873,
#  'surface_temperature_celcius': 75}
# {'confidence': 91,
#  'latitude': -36.5541,
#  'longitude': 144.1321,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -35.6819,
#  'longitude': 143.5275,
#  'surface_temperature_celcius': 69}
# {'confidence': 90,
#  'latitude': -35.6871,
#  'longitude': 143.5235,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.1506,
#  'longitude': 143.5671,
#  'surface_temperature_celcius': 95}
# {'confidence': 93,
#  'latitude': -37.4984,
#  'longitude': 142.9739,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -37.253,
#  'longitude': 144.3681,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -36.9396,
#  'longitude': 143.1462,
#  'surface_temperature_celcius': 70}
# {'confidence': 96,
#  'latitude': -36.3387,
#  'longitude': 141.7542,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.3433,
#  'longitude': 143.4369,
#  'surface_temperature_celcius': 94}
# {'confidence': 100,
#  'latitude': -36.345,
#  'longitude': 143.4256,
#  'surface_temperature_celcius': 87}
# {'confidence': 90,
#  'latitude': -36.7032,
#  'longitude': 144.0992,
#  'surface_temperature_celcius': 66}
# {'confidence': 96,
#  'latitude': -36.3402,
#  'longitude': 141.7429,
#  'surface_temperature_celcius': 77}
# {'confidence': 89,
#  'latitude': -36.5661,
#  'longitude': 142.2956,
#  'surface_temperature_celcius': 65}
# {'confidence': 85,
#  'latitude': -36.5023,
#  'longitude': 143.6038,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.8616,
#  'longitude': 142.8025,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -38.0372,
#  'longitude': 146.0616,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -38.049,
#  'longitude': 146.0513,
#  'surface_temperature_celcius': 74}
# {'confidence': 89,
#  'latitude': -35.4666,
#  'longitude': 142.0749,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -36.0396,
#  'longitude': 141.7183,
#  'surface_temperature_celcius': 76}
# {'confidence': 94,
#  'latitude': -36.2775,
#  'longitude': 146.1026,
#  'surface_temperature_celcius': 74}
# {'confidence': 100,
#  'latitude': -38.0361,
#  'longitude': 146.0567,
#  'surface_temperature_celcius': 90}
# {'confidence': 91,
#  'latitude': -36.7746,
#  'longitude': 146.6642,
#  'surface_temperature_celcius': 68}
# {'confidence': 96,
#  'latitude': -36.8359,
#  'longitude': 146.6448,
#  'surface_temperature_celcius': 78}
# {'confidence': 98,
#  'latitude': -37.9085,
#  'longitude': 141.1038,
#  'surface_temperature_celcius': 82}
# {'confidence': 100,
#  'latitude': -38.4349,
#  'longitude': 146.3122,
#  'surface_temperature_celcius': 93}
# {'confidence': 89,
#  'latitude': -38.4792,
#  'longitude': 146.3081,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.9047,
#  'longitude': 141.0945,
#  'surface_temperature_celcius': 90}
# {'confidence': 91,
#  'latitude': -36.7685,
#  'longitude': 142.7134,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -36.7801,
#  'longitude': 142.7151,
#  'surface_temperature_celcius': 68}
# {'confidence': 96,
#  'latitude': -36.1002,
#  'longitude': 142.3405,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -36.4325,
#  'longitude': 144.3142,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -36.2693,
#  'longitude': 143.1768,
#  'surface_temperature_celcius': 85}
# {'confidence': 91,
#  'latitude': -36.3774,
#  'longitude': 143.7079,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.3756,
#  'longitude': 143.7243,
#  'surface_temperature_celcius': 88}
# {'confidence': 97,
#  'latitude': -36.369,
#  'longitude': 143.7132,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.3799,
#  'longitude': 143.7149,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -37.8644,
#  'longitude': 143.4263,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -38.3998,
#  'longitude': 147.064,
#  'surface_temperature_celcius': 65}
# {'confidence': 94,
#  'latitude': -37.4796,
#  'longitude': 141.9403,
#  'surface_temperature_celcius': 87}
# {'confidence': 58,
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
# {'confidence': 62,
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -37.396,
#  'longitude': 148.086,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.399,
#  'longitude': 148.081,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -37.401,
#  'longitude': 148.067,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'surface_temperature_celcius': 88}
# {'confidence': 68,
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'confidence': 64,
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'confidence': 86,
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'surface_temperature_celcius': 76}
# {'confidence': 73,
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'surface_temperature_celcius': 66}
# {'confidence': 61,
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -37.462,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 90}
# {'confidence': 88,
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'confidence': 90,
#  'latitude': -37.331,
#  'longitude': 143.122,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'surface_temperature_celcius': 93}
# {'confidence': 96,
#  'latitude': -37.475,
#  'longitude': 143.365,
#  'surface_temperature_celcius': 77}
# {'confidence': 97,
#  'latitude': -37.69,
#  'longitude': 143.605,
#  'surface_temperature_celcius': 80}
# {'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'surface_temperature_celcius': 71}
# {'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}

# %% [markdown]
# ##### **c) Selected data for 15th and 16th of December 2023**

# %%
#extract only required attributes from each climate document with embedded hotspot document 
projected_fields = {
                     "_id": 0,
                     "date": 1,
                     "air_temperature_celcius": 1,
                     "relative_humidity": 1,
                     "max_wind_speed": 1,
                     "surface_temperature_celcius": "$hotspots.surface_temperature_celcius"  #to show surface temperature as a distinct attribute rather than embedded inside a hotspot document
                    }

pipeline_stages = [{"$match": {"date": {"$in": ["15/12/2023", "16/12/2023"]}}},  #filter query based on given two dates
                   {"$project": projected_fields}  #use projection to retrieve selected attributes
                  ]

data = climate_col.aggregate(pipeline_stages)

for document in data:
    pprint(document)
# Out:
# {'air_temperature_celcius': 18,
#  'date': '15/12/2023',
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': [42, 36, 38, 40]}
# {'air_temperature_celcius': 18,
#  'date': '16/12/2023',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': [43,
#                                  33,
#                                  54,
#                                  73,
#                                  55,
#                                  75,
#                                  55,
#                                  66,
#                                  56,
#                                  60,
#                                  73,
#                                  48,
#                                  55,
#                                  64,
#                                  57]}

# %% [markdown]
# ##### **d) Selected data for confidence between 80 and 100**

# %%
#extract only required attributes from each climate document with embedded hotspot document 

#to show hotspot attributes as distinct attributes rather than embedded inside a hotspot document, 
#the path to the attributes is given instead of a boolean value during projection
projected_fields = {
                     "_id": 0,
                     "datetime": "$hotspots.datetime", 
                     "air_temperature_celcius": 1,
                     "surface_temperature_celcius": "$hotspots.surface_temperature_celcius",
                     "confidence": "$hotspots.confidence" 
                    }

pipeline_stages = [{"$unwind": "$hotspots"},  
                   {"$match": {"hotspots.confidence": {"$gte": 80, "$lte": 100}}},  
                   {"$project": projected_fields} 
                  ]

data = climate_col.aggregate(pipeline_stages)  #execute aggregation pipeline
 
for document in data:
    pprint(document)
# Out:
# {'air_temperature_celcius': 20,
#  'confidence': 87,
#  'datetime': '2023-03-06 05:06:30',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 20,
#  'confidence': 85,
#  'datetime': '2023-03-06 05:06:20',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 19,
#  'confidence': 88,
#  'datetime': '2023-03-07 04:16:10',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 23,
#  'confidence': 86,
#  'datetime': '2023-03-09 13:23:40',
#  'surface_temperature_celcius': 41}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-03-10 04:48:40',
#  'surface_temperature_celcius': 105}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-03-10 04:46:20',
#  'surface_temperature_celcius': 109}
# {'air_temperature_celcius': 19,
#  'confidence': 94,
#  'datetime': '2023-03-10 04:45:30',
#  'surface_temperature_celcius': 73}
# {'air_temperature_celcius': 19,
#  'confidence': 97,
#  'datetime': '2023-03-10 04:45:30',
#  'surface_temperature_celcius': 80}
# {'air_temperature_celcius': 19,
#  'confidence': 81,
#  'datetime': '2023-03-10 04:43:50',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 21,
#  'confidence': 94,
#  'datetime': '2023-03-12 04:33:50',
#  'surface_temperature_celcius': 105}
# {'air_temperature_celcius': 21,
#  'confidence': 84,
#  'datetime': '2023-03-12 04:29:50',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 21,
#  'confidence': 100,
#  'datetime': '2023-03-12 04:28:20',
#  'surface_temperature_celcius': 99}
# {'air_temperature_celcius': 21,
#  'confidence': 80,
#  'datetime': '2023-03-12 04:28:00',
#  'surface_temperature_celcius': 68}
# {'air_temperature_celcius': 21,
#  'confidence': 85,
#  'datetime': '2023-03-12 04:27:20',
#  'surface_temperature_celcius': 98}
# {'air_temperature_celcius': 25,
#  'confidence': 90,
#  'datetime': '2023-03-14 04:24:40',
#  'surface_temperature_celcius': 67}
# {'air_temperature_celcius': 25,
#  'confidence': 93,
#  'datetime': '2023-03-14 04:22:20',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 25,
#  'confidence': 90,
#  'datetime': '2023-03-14 04:20:50',
#  'surface_temperature_celcius': 68}
# {'air_temperature_celcius': 25,
#  'confidence': 95,
#  'datetime': '2023-03-14 04:16:30',
#  'surface_temperature_celcius': 75}
# {'air_temperature_celcius': 25,
#  'confidence': 89,
#  'datetime': '2023-03-14 04:16:20',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 25,
#  'confidence': 81,
#  'datetime': '2023-03-14 04:14:40',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 25,
#  'confidence': 96,
#  'datetime': '2023-03-14 04:14:30',
#  'surface_temperature_celcius': 79}
# {'air_temperature_celcius': 25,
#  'confidence': 94,
#  'datetime': '2023-03-14 04:14:30',
#  'surface_temperature_celcius': 75}
# {'air_temperature_celcius': 18,
#  'confidence': 94,
#  'datetime': '2023-03-17 04:48:20',
#  'surface_temperature_celcius': 74}
# {'air_temperature_celcius': 18,
#  'confidence': 84,
#  'datetime': '2023-03-17 04:45:10',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 18,
#  'confidence': 86,
#  'datetime': '2023-03-17 04:45:00',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 21,
#  'confidence': 100,
#  'datetime': '2023-03-18 03:50:50',
#  'surface_temperature_celcius': 121}
# {'air_temperature_celcius': 21,
#  'confidence': 97,
#  'datetime': '2023-03-18 03:50:40',
#  'surface_temperature_celcius': 80}
# {'air_temperature_celcius': 24,
#  'confidence': 85,
#  'datetime': '2023-03-19 04:39:50',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 24,
#  'confidence': 96,
#  'datetime': '2023-03-19 04:39:20',
#  'surface_temperature_celcius': 79}
# {'air_temperature_celcius': 24,
#  'confidence': 90,
#  'datetime': '2023-03-19 04:36:00',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 24,
#  'confidence': 98,
#  'datetime': '2023-03-19 04:33:00',
#  'surface_temperature_celcius': 83}
# {'air_temperature_celcius': 24,
#  'confidence': 100,
#  'datetime': '2023-03-19 04:32:50',
#  'surface_temperature_celcius': 91}
# {'air_temperature_celcius': 24,
#  'confidence': 84,
#  'datetime': '2023-03-19 04:32:50',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 24,
#  'confidence': 100,
#  'datetime': '2023-03-19 04:32:40',
#  'surface_temperature_celcius': 113}
# {'air_temperature_celcius': 24,
#  'confidence': 92,
#  'datetime': '2023-03-19 04:32:40',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 24,
#  'confidence': 100,
#  'datetime': '2023-03-19 04:32:40',
#  'surface_temperature_celcius': 106}
# {'air_temperature_celcius': 23,
#  'confidence': 82,
#  'datetime': '2023-03-25 03:59:50',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 23,
#  'confidence': 87,
#  'datetime': '2023-03-25 03:58:10',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 23,
#  'confidence': 95,
#  'datetime': '2023-03-25 03:58:10',
#  'surface_temperature_celcius': 75}
# {'air_temperature_celcius': 23,
#  'confidence': 85,
#  'datetime': '2023-03-25 03:57:10',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 23,
#  'confidence': 100,
#  'datetime': '2023-03-25 03:57:10',
#  'surface_temperature_celcius': 111}
# {'air_temperature_celcius': 23,
#  'confidence': 95,
#  'datetime': '2023-03-25 03:57:10',
#  'surface_temperature_celcius': 77}
# {'air_temperature_celcius': 23,
#  'confidence': 100,
#  'datetime': '2023-03-25 03:56:40',
#  'surface_temperature_celcius': 99}
# {'air_temperature_celcius': 23,
#  'confidence': 81,
#  'datetime': '2023-03-26 04:43:20',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 23,
#  'confidence': 80,
#  'datetime': '2023-03-26 04:40:50',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 23,
#  'confidence': 81,
#  'datetime': '2023-03-26 04:39:50',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 23,
#  'confidence': 91,
#  'datetime': '2023-03-26 04:39:10',
#  'surface_temperature_celcius': 68}
# {'air_temperature_celcius': 23,
#  'confidence': 92,
#  'datetime': '2023-03-26 04:39:10',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 23,
#  'confidence': 100,
#  'datetime': '2023-03-26 04:39:10',
#  'surface_temperature_celcius': 89}
# {'air_temperature_celcius': 23,
#  'confidence': 82,
#  'datetime': '2023-03-26 04:39:10',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 23,
#  'confidence': 87,
#  'datetime': '2023-03-26 04:39:10',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 23,
#  'confidence': 84,
#  'datetime': '2023-03-26 04:39:10',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 18,
#  'confidence': 88,
#  'datetime': '2023-03-28 04:38:00',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 18,
#  'confidence': 86,
#  'datetime': '2023-03-28 04:33:40',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 18,
#  'confidence': 92,
#  'datetime': '2023-03-28 04:33:30',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 18,
#  'confidence': 95,
#  'datetime': '2023-03-28 04:33:30',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 18,
#  'confidence': 93,
#  'datetime': '2023-03-28 04:32:20',
#  'surface_temperature_celcius': 73}
# {'air_temperature_celcius': 18,
#  'confidence': 83,
#  'datetime': '2023-03-28 04:30:50',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 18,
#  'confidence': 80,
#  'datetime': '2023-03-28 04:30:20',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 18,
#  'confidence': 94,
#  'datetime': '2023-03-28 04:30:10',
#  'surface_temperature_celcius': 74}
# {'air_temperature_celcius': 18,
#  'confidence': 98,
#  'datetime': '2023-03-28 04:30:10',
#  'surface_temperature_celcius': 82}
# {'air_temperature_celcius': 18,
#  'confidence': 81,
#  'datetime': '2023-03-28 04:30:10',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 18,
#  'confidence': 97,
#  'datetime': '2023-03-28 04:30:10',
#  'surface_temperature_celcius': 80}
# {'air_temperature_celcius': 18,
#  'confidence': 81,
#  'datetime': '2023-03-28 04:28:30',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 18,
#  'confidence': 88,
#  'datetime': '2023-03-28 04:28:30',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 18,
#  'confidence': 87,
#  'datetime': '2023-03-28 04:28:30',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 18,
#  'confidence': 97,
#  'datetime': '2023-03-28 04:27:40',
#  'surface_temperature_celcius': 80}
# {'air_temperature_celcius': 18,
#  'confidence': 100,
#  'datetime': '2023-03-28 04:27:20',
#  'surface_temperature_celcius': 107}
# {'air_temperature_celcius': 18,
#  'confidence': 100,
#  'datetime': '2023-03-28 04:27:10',
#  'surface_temperature_celcius': 108}
# {'air_temperature_celcius': 18,
#  'confidence': 82,
#  'datetime': '2023-03-28 04:27:00',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 18,
#  'confidence': 99,
#  'datetime': '2023-03-28 04:27:00',
#  'surface_temperature_celcius': 86}
# {'air_temperature_celcius': 18,
#  'confidence': 81,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 18,
#  'confidence': 80,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 18,
#  'confidence': 83,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 18,
#  'confidence': 100,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 90}
# {'air_temperature_celcius': 18,
#  'confidence': 87,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 18,
#  'confidence': 97,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 81}
# {'air_temperature_celcius': 18,
#  'confidence': 85,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 18,
#  'confidence': 88,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 18,
#  'confidence': 87,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 18,
#  'confidence': 84,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 18,
#  'confidence': 97,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 81}
# {'air_temperature_celcius': 18,
#  'confidence': 83,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 18,
#  'confidence': 85,
#  'datetime': '2023-03-28 04:26:50',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 14,
#  'confidence': 82,
#  'datetime': '2023-03-31 05:07:10',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 14,
#  'confidence': 87,
#  'datetime': '2023-03-31 05:01:20',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 14,
#  'confidence': 82,
#  'datetime': '2023-03-31 04:58:30',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 14,
#  'confidence': 80,
#  'datetime': '2023-03-31 04:58:00',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 14,
#  'confidence': 86,
#  'datetime': '2023-03-31 04:57:10',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 14,
#  'confidence': 81,
#  'datetime': '2023-03-31 00:36:30',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 15,
#  'confidence': 91,
#  'datetime': '2023-04-03 13:17:00',
#  'surface_temperature_celcius': 43}
# {'air_temperature_celcius': 15,
#  'confidence': 83,
#  'datetime': '2023-04-03 13:15:30',
#  'surface_temperature_celcius': 40}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-04-03 13:15:10',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 15,
#  'confidence': 96,
#  'datetime': '2023-04-03 13:15:10',
#  'surface_temperature_celcius': 45}
# {'air_temperature_celcius': 15,
#  'confidence': 87,
#  'datetime': '2023-04-03 03:59:10',
#  'surface_temperature_celcius': 96}
# {'air_temperature_celcius': 15,
#  'confidence': 93,
#  'datetime': '2023-04-03 03:57:50',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 15,
#  'confidence': 82,
#  'datetime': '2023-04-03 03:56:20',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 15,
#  'confidence': 88,
#  'datetime': '2023-04-03 03:55:10',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 15,
#  'confidence': 95,
#  'datetime': '2023-04-03 03:55:10',
#  'surface_temperature_celcius': 77}
# {'air_temperature_celcius': 15,
#  'confidence': 96,
#  'datetime': '2023-04-03 03:54:00',
#  'surface_temperature_celcius': 78}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-04-03 03:53:50',
#  'surface_temperature_celcius': 93}
# {'air_temperature_celcius': 15,
#  'confidence': 85,
#  'datetime': '2023-04-03 03:53:30',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 15,
#  'confidence': 84,
#  'datetime': '2023-04-03 03:52:30',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-04-03 03:52:30',
#  'surface_temperature_celcius': 90}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-04-03 03:52:20',
#  'surface_temperature_celcius': 115}
# {'air_temperature_celcius': 15,
#  'confidence': 86,
#  'datetime': '2023-04-03 03:52:10',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-04-03 03:52:10',
#  'surface_temperature_celcius': 98}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-04-03 03:52:10',
#  'surface_temperature_celcius': 89}
# {'air_temperature_celcius': 15,
#  'confidence': 85,
#  'datetime': '2023-04-03 03:52:10',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 15,
#  'confidence': 83,
#  'datetime': '2023-04-03 03:51:30',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 15,
#  'confidence': 89,
#  'datetime': '2023-04-03 03:51:30',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 15,
#  'confidence': 87,
#  'datetime': '2023-04-03 03:51:10',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 15,
#  'confidence': 81,
#  'datetime': '2023-04-03 03:51:00',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 15,
#  'confidence': 98,
#  'datetime': '2023-04-03 03:51:00',
#  'surface_temperature_celcius': 82}
# {'air_temperature_celcius': 15,
#  'confidence': 80,
#  'datetime': '2023-04-03 03:51:00',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-04-03 03:51:00',
#  'surface_temperature_celcius': 103}
# {'air_temperature_celcius': 15,
#  'confidence': 87,
#  'datetime': '2023-04-03 03:50:50',
#  'surface_temperature_celcius': 97}
# {'air_temperature_celcius': 15,
#  'confidence': 90,
#  'datetime': '2023-04-03 03:50:50',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 15,
#  'confidence': 85,
#  'datetime': '2023-04-03 03:50:40',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 15,
#  'confidence': 99,
#  'datetime': '2023-04-03 03:50:40',
#  'surface_temperature_celcius': 86}
# {'air_temperature_celcius': 15,
#  'confidence': 93,
#  'datetime': '2023-04-03 03:50:40',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 15,
#  'confidence': 95,
#  'datetime': '2023-04-03 03:50:40',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 15,
#  'confidence': 86,
#  'datetime': '2023-04-03 03:50:40',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 15,
#  'confidence': 89,
#  'datetime': '2023-04-03 03:50:40',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 15,
#  'confidence': 82,
#  'datetime': '2023-04-03 03:50:40',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 15,
#  'confidence': 89,
#  'datetime': '2023-04-03 03:50:40',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 15,
#  'confidence': 81,
#  'datetime': '2023-04-03 01:07:20',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 93,
#  'datetime': '2023-04-04 15:31:00',
#  'surface_temperature_celcius': 44}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 15:30:40',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 16,
#  'confidence': 88,
#  'datetime': '2023-04-04 04:41:50',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 16,
#  'confidence': 82,
#  'datetime': '2023-04-04 04:41:10',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 16,
#  'confidence': 88,
#  'datetime': '2023-04-04 04:41:00',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 16,
#  'confidence': 86,
#  'datetime': '2023-04-04 04:41:00',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:40:00',
#  'surface_temperature_celcius': 120}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-04 04:39:50',
#  'surface_temperature_celcius': 67}
# {'air_temperature_celcius': 16,
#  'confidence': 85,
#  'datetime': '2023-04-04 04:39:50',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-04 04:39:40',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-04 04:39:40',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:39:20',
#  'surface_temperature_celcius': 107}
# {'air_temperature_celcius': 16,
#  'confidence': 88,
#  'datetime': '2023-04-04 04:37:10',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 16,
#  'confidence': 88,
#  'datetime': '2023-04-04 04:36:10',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 16,
#  'confidence': 87,
#  'datetime': '2023-04-04 04:36:10',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-04 04:36:00',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:35:00',
#  'surface_temperature_celcius': 95}
# {'air_temperature_celcius': 16,
#  'confidence': 83,
#  'datetime': '2023-04-04 04:34:50',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 16,
#  'confidence': 89,
#  'datetime': '2023-04-04 04:34:20',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 16,
#  'confidence': 96,
#  'datetime': '2023-04-04 04:34:20',
#  'surface_temperature_celcius': 78}
# {'air_temperature_celcius': 16,
#  'confidence': 85,
#  'datetime': '2023-04-04 04:34:20',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 84,
#  'datetime': '2023-04-04 04:34:00',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 16,
#  'confidence': 92,
#  'datetime': '2023-04-04 04:33:50',
#  'surface_temperature_celcius': 81}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-04 04:33:40',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:33:30',
#  'surface_temperature_celcius': 113}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-04 04:33:30',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 16,
#  'confidence': 85,
#  'datetime': '2023-04-04 04:33:30',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 16,
#  'confidence': 82,
#  'datetime': '2023-04-04 04:33:10',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 16,
#  'confidence': 82,
#  'datetime': '2023-04-04 04:33:10',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 16,
#  'confidence': 97,
#  'datetime': '2023-04-04 04:33:00',
#  'surface_temperature_celcius': 79}
# {'air_temperature_celcius': 16,
#  'confidence': 86,
#  'datetime': '2023-04-04 04:33:00',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 16,
#  'confidence': 98,
#  'datetime': '2023-04-04 04:32:50',
#  'surface_temperature_celcius': 82}
# {'air_temperature_celcius': 16,
#  'confidence': 85,
#  'datetime': '2023-04-04 04:32:50',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 16,
#  'confidence': 84,
#  'datetime': '2023-04-04 04:32:50',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 16,
#  'confidence': 82,
#  'datetime': '2023-04-04 04:32:50',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:32:50',
#  'surface_temperature_celcius': 123}
# {'air_temperature_celcius': 16,
#  'confidence': 82,
#  'datetime': '2023-04-04 04:32:50',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:32:50',
#  'surface_temperature_celcius': 118}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-04 04:32:40',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 96,
#  'datetime': '2023-04-04 04:32:40',
#  'surface_temperature_celcius': 78}
# {'air_temperature_celcius': 16,
#  'confidence': 93,
#  'datetime': '2023-04-04 04:32:40',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:32:40',
#  'surface_temperature_celcius': 120}
# {'air_temperature_celcius': 16,
#  'confidence': 87,
#  'datetime': '2023-04-04 04:32:40',
#  'surface_temperature_celcius': 92}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:32:40',
#  'surface_temperature_celcius': 101}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-04 04:32:40',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-04 04:32:40',
#  'surface_temperature_celcius': 98}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-04 00:12:50',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-04-05 13:09:00',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 17,
#  'confidence': 81,
#  'datetime': '2023-04-05 13:09:00',
#  'surface_temperature_celcius': 39}
# {'air_temperature_celcius': 17,
#  'confidence': 93,
#  'datetime': '2023-04-05 13:08:40',
#  'surface_temperature_celcius': 44}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-04-05 13:08:40',
#  'surface_temperature_celcius': 47}
# {'air_temperature_celcius': 17,
#  'confidence': 82,
#  'datetime': '2023-04-05 13:07:00',
#  'surface_temperature_celcius': 40}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-04-05 13:04:20',
#  'surface_temperature_celcius': 49}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-04-05 13:03:20',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 17,
#  'confidence': 98,
#  'datetime': '2023-04-05 13:03:00',
#  'surface_temperature_celcius': 45}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-04-05 13:03:00',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 17,
#  'confidence': 81,
#  'datetime': '2023-04-05 13:03:00',
#  'surface_temperature_celcius': 39}
# {'air_temperature_celcius': 17,
#  'confidence': 88,
#  'datetime': '2023-04-05 13:02:40',
#  'surface_temperature_celcius': 42}
# {'air_temperature_celcius': 17,
#  'confidence': 80,
#  'datetime': '2023-04-05 13:02:40',
#  'surface_temperature_celcius': 39}
# {'air_temperature_celcius': 17,
#  'confidence': 87,
#  'datetime': '2023-04-05 05:16:50',
#  'surface_temperature_celcius': 88}
# {'air_temperature_celcius': 17,
#  'confidence': 93,
#  'datetime': '2023-04-05 05:15:30',
#  'surface_temperature_celcius': 83}
# {'air_temperature_celcius': 17,
#  'confidence': 93,
#  'datetime': '2023-04-05 03:40:50',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 17,
#  'confidence': 95,
#  'datetime': '2023-04-05 03:40:30',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 17,
#  'confidence': 81,
#  'datetime': '2023-04-05 03:40:20',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 17,
#  'confidence': 89,
#  'datetime': '2023-04-05 03:39:30',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 17,
#  'confidence': 82,
#  'datetime': '2023-04-05 03:39:30',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 17,
#  'confidence': 90,
#  'datetime': '2023-04-05 03:39:20',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 17,
#  'confidence': 83,
#  'datetime': '2023-04-05 03:39:20',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 17,
#  'confidence': 89,
#  'datetime': '2023-04-05 03:39:10',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 17,
#  'confidence': 83,
#  'datetime': '2023-04-05 03:39:10',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 17,
#  'confidence': 95,
#  'datetime': '2023-04-05 03:39:10',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-04-05 03:39:10',
#  'surface_temperature_celcius': 92}
# {'air_temperature_celcius': 17,
#  'confidence': 88,
#  'datetime': '2023-04-05 03:39:10',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 17,
#  'confidence': 89,
#  'datetime': '2023-04-05 03:39:10',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 19,
#  'confidence': 97,
#  'datetime': '2023-04-06 13:45:30',
#  'surface_temperature_celcius': 45}
# {'air_temperature_celcius': 19,
#  'confidence': 84,
#  'datetime': '2023-04-06 04:32:20',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 19,
#  'confidence': 92,
#  'datetime': '2023-04-06 04:31:10',
#  'surface_temperature_celcius': 69}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-06 04:27:50',
#  'surface_temperature_celcius': 95}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-06 04:27:50',
#  'surface_temperature_celcius': 88}
# {'air_temperature_celcius': 19,
#  'confidence': 81,
#  'datetime': '2023-04-06 04:27:10',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-06 04:27:00',
#  'surface_temperature_celcius': 97}
# {'air_temperature_celcius': 19,
#  'confidence': 86,
#  'datetime': '2023-04-06 04:27:00',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 19,
#  'confidence': 90,
#  'datetime': '2023-04-06 04:27:00',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-06 04:27:00',
#  'surface_temperature_celcius': 99}
# {'air_temperature_celcius': 19,
#  'confidence': 83,
#  'datetime': '2023-04-06 04:27:00',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 19,
#  'confidence': 83,
#  'datetime': '2023-04-06 04:24:40',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 19,
#  'confidence': 89,
#  'datetime': '2023-04-06 04:24:20',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 19,
#  'confidence': 89,
#  'datetime': '2023-04-06 04:24:20',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 19,
#  'confidence': 89,
#  'datetime': '2023-04-06 04:24:00',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 19,
#  'confidence': 92,
#  'datetime': '2023-04-06 04:23:50',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 19,
#  'confidence': 99,
#  'datetime': '2023-04-06 04:23:50',
#  'surface_temperature_celcius': 85}
# {'air_temperature_celcius': 19,
#  'confidence': 93,
#  'datetime': '2023-04-06 04:23:30',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 19,
#  'confidence': 89,
#  'datetime': '2023-04-06 04:23:10',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 19,
#  'confidence': 87,
#  'datetime': '2023-04-06 04:23:00',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 19,
#  'confidence': 85,
#  'datetime': '2023-04-06 04:22:40',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 19,
#  'confidence': 83,
#  'datetime': '2023-04-06 04:22:20',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 19,
#  'confidence': 81,
#  'datetime': '2023-04-06 04:22:20',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 19,
#  'confidence': 85,
#  'datetime': '2023-04-06 04:22:20',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-06 04:22:20',
#  'surface_temperature_celcius': 103}
# {'air_temperature_celcius': 19,
#  'confidence': 91,
#  'datetime': '2023-04-06 04:22:20',
#  'surface_temperature_celcius': 69}
# {'air_temperature_celcius': 19,
#  'confidence': 86,
#  'datetime': '2023-04-06 04:22:10',
#  'surface_temperature_celcius': 68}
# {'air_temperature_celcius': 19,
#  'confidence': 85,
#  'datetime': '2023-04-06 04:22:10',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 19,
#  'confidence': 90,
#  'datetime': '2023-04-06 04:22:10',
#  'surface_temperature_celcius': 67}
# {'air_temperature_celcius': 19,
#  'confidence': 90,
#  'datetime': '2023-04-06 04:21:30',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 19,
#  'confidence': 94,
#  'datetime': '2023-04-06 04:21:10',
#  'surface_temperature_celcius': 96}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-06 04:21:00',
#  'surface_temperature_celcius': 115}
# {'air_temperature_celcius': 19,
#  'confidence': 84,
#  'datetime': '2023-04-06 04:21:00',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-06 04:20:50',
#  'surface_temperature_celcius': 95}
# {'air_temperature_celcius': 19,
#  'confidence': 88,
#  'datetime': '2023-04-06 04:20:50',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 19,
#  'confidence': 83,
#  'datetime': '2023-04-06 04:20:50',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 19,
#  'confidence': 81,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 19,
#  'confidence': 83,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 78}
# {'air_temperature_celcius': 19,
#  'confidence': 96,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 77}
# {'air_temperature_celcius': 19,
#  'confidence': 91,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 68}
# {'air_temperature_celcius': 19,
#  'confidence': 97,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 81}
# {'air_temperature_celcius': 19,
#  'confidence': 82,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 19,
#  'confidence': 94,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 104}
# {'air_temperature_celcius': 19,
#  'confidence': 92,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 19,
#  'confidence': 87,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 19,
#  'confidence': 81,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 19,
#  'confidence': 80,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 19,
#  'confidence': 85,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 19,
#  'confidence': 90,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 67}
# {'air_temperature_celcius': 19,
#  'confidence': 87,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 19,
#  'confidence': 94,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 86}
# {'air_temperature_celcius': 19,
#  'confidence': 84,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 19,
#  'confidence': 87,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 100}
# {'air_temperature_celcius': 19,
#  'confidence': 86,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 19,
#  'confidence': 81,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 19,
#  'confidence': 94,
#  'datetime': '2023-04-06 04:20:40',
#  'surface_temperature_celcius': 89}
# {'air_temperature_celcius': 21,
#  'confidence': 85,
#  'datetime': '2023-04-07 12:56:50',
#  'surface_temperature_celcius': 41}
# {'air_temperature_celcius': 21,
#  'confidence': 80,
#  'datetime': '2023-04-07 12:56:30',
#  'surface_temperature_celcius': 39}
# {'air_temperature_celcius': 21,
#  'confidence': 94,
#  'datetime': '2023-04-07 12:56:30',
#  'surface_temperature_celcius': 49}
# {'air_temperature_celcius': 21,
#  'confidence': 86,
#  'datetime': '2023-04-07 12:53:40',
#  'surface_temperature_celcius': 41}
# {'air_temperature_celcius': 21,
#  'confidence': 86,
#  'datetime': '2023-04-07 12:52:10',
#  'surface_temperature_celcius': 41}
# {'air_temperature_celcius': 21,
#  'confidence': 97,
#  'datetime': '2023-04-07 12:51:20',
#  'surface_temperature_celcius': 45}
# {'air_temperature_celcius': 21,
#  'confidence': 100,
#  'datetime': '2023-04-07 12:51:00',
#  'surface_temperature_celcius': 49}
# {'air_temperature_celcius': 21,
#  'confidence': 92,
#  'datetime': '2023-04-07 12:50:50',
#  'surface_temperature_celcius': 43}
# {'air_temperature_celcius': 21,
#  'confidence': 89,
#  'datetime': '2023-04-07 12:50:40',
#  'surface_temperature_celcius': 42}
# {'air_temperature_celcius': 21,
#  'confidence': 80,
#  'datetime': '2023-04-07 05:09:50',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 21,
#  'confidence': 80,
#  'datetime': '2023-04-07 05:03:10',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 21,
#  'confidence': 81,
#  'datetime': '2023-04-07 05:03:10',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 21,
#  'confidence': 100,
#  'datetime': '2023-04-07 03:31:40',
#  'surface_temperature_celcius': 89}
# {'air_temperature_celcius': 21,
#  'confidence': 96,
#  'datetime': '2023-04-07 03:28:20',
#  'surface_temperature_celcius': 78}
# {'air_temperature_celcius': 21,
#  'confidence': 92,
#  'datetime': '2023-04-07 03:27:30',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 21,
#  'confidence': 92,
#  'datetime': '2023-04-07 03:27:20',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 21,
#  'confidence': 95,
#  'datetime': '2023-04-07 03:27:20',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 21,
#  'confidence': 100,
#  'datetime': '2023-04-07 03:27:10',
#  'surface_temperature_celcius': 106}
# {'air_temperature_celcius': 19,
#  'confidence': 99,
#  'datetime': '2023-04-08 04:14:00',
#  'surface_temperature_celcius': 85}
# {'air_temperature_celcius': 19,
#  'confidence': 91,
#  'datetime': '2023-04-08 04:12:50',
#  'surface_temperature_celcius': 69}
# {'air_temperature_celcius': 19,
#  'confidence': 100,
#  'datetime': '2023-04-08 04:12:20',
#  'surface_temperature_celcius': 94}
# {'air_temperature_celcius': 19,
#  'confidence': 80,
#  'datetime': '2023-04-08 04:12:00',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 19,
#  'confidence': 98,
#  'datetime': '2023-04-08 04:08:50',
#  'surface_temperature_celcius': 83}
# {'air_temperature_celcius': 19,
#  'confidence': 90,
#  'datetime': '2023-04-08 04:08:30',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 19,
#  'confidence': 80,
#  'datetime': '2023-04-08 04:08:30',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 19,
#  'confidence': 80,
#  'datetime': '2023-04-08 04:08:30',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 19,
#  'confidence': 80,
#  'datetime': '2023-04-08 04:08:30',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 14,
#  'confidence': 81,
#  'datetime': '2023-04-11 04:39:20',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 14,
#  'confidence': 84,
#  'datetime': '2023-04-11 04:39:00',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 14,
#  'confidence': 85,
#  'datetime': '2023-04-11 04:39:00',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 14,
#  'confidence': 93,
#  'datetime': '2023-04-12 13:15:10',
#  'surface_temperature_celcius': 43}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-04-12 05:28:10',
#  'surface_temperature_celcius': 106}
# {'air_temperature_celcius': 14,
#  'confidence': 84,
#  'datetime': '2023-04-12 05:28:00',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 14,
#  'confidence': 94,
#  'datetime': '2023-04-12 05:21:40',
#  'surface_temperature_celcius': 75}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-04-12 05:21:40',
#  'surface_temperature_celcius': 98}
# {'air_temperature_celcius': 14,
#  'confidence': 95,
#  'datetime': '2023-04-12 03:54:10',
#  'surface_temperature_celcius': 77}
# {'air_temperature_celcius': 14,
#  'confidence': 87,
#  'datetime': '2023-04-12 03:50:00',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 14,
#  'confidence': 95,
#  'datetime': '2023-04-12 03:50:00',
#  'surface_temperature_celcius': 75}
# {'air_temperature_celcius': 14,
#  'confidence': 86,
#  'datetime': '2023-04-12 03:50:00',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 14,
#  'confidence': 92,
#  'datetime': '2023-04-12 03:47:50',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 14,
#  'confidence': 84,
#  'datetime': '2023-04-12 03:47:50',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 14,
#  'confidence': 84,
#  'datetime': '2023-04-12 03:47:30',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-04-12 03:47:30',
#  'surface_temperature_celcius': 106}
# {'air_temperature_celcius': 14,
#  'confidence': 83,
#  'datetime': '2023-04-12 03:47:20',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 14,
#  'confidence': 84,
#  'datetime': '2023-04-12 03:47:20',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 14,
#  'confidence': 85,
#  'datetime': '2023-04-12 03:45:10',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-04-12 03:44:50',
#  'surface_temperature_celcius': 98}
# {'air_temperature_celcius': 14,
#  'confidence': 87,
#  'datetime': '2023-04-12 03:44:40',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 14,
#  'confidence': 93,
#  'datetime': '2023-04-12 03:44:40',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 14,
#  'confidence': 82,
#  'datetime': '2023-04-12 03:44:40',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 14,
#  'confidence': 93,
#  'datetime': '2023-04-12 03:44:40',
#  'surface_temperature_celcius': 73}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-04-12 03:44:40',
#  'surface_temperature_celcius': 111}
# {'air_temperature_celcius': 16,
#  'confidence': 96,
#  'datetime': '2023-04-13 04:38:00',
#  'surface_temperature_celcius': 78}
# {'air_temperature_celcius': 16,
#  'confidence': 93,
#  'datetime': '2023-04-13 04:38:00',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:38:00',
#  'surface_temperature_celcius': 97}
# {'air_temperature_celcius': 16,
#  'confidence': 86,
#  'datetime': '2023-04-13 04:36:50',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 16,
#  'confidence': 92,
#  'datetime': '2023-04-13 04:36:30',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 16,
#  'confidence': 89,
#  'datetime': '2023-04-13 04:36:20',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-13 04:36:20',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 16,
#  'confidence': 89,
#  'datetime': '2023-04-13 04:35:40',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 16,
#  'confidence': 85,
#  'datetime': '2023-04-13 04:35:40',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 16,
#  'confidence': 86,
#  'datetime': '2023-04-13 04:35:30',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:34:40',
#  'surface_temperature_celcius': 89}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-13 04:34:40',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 93,
#  'datetime': '2023-04-13 04:34:20',
#  'surface_temperature_celcius': 73}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:33:50',
#  'surface_temperature_celcius': 88}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-13 04:33:40',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 84,
#  'datetime': '2023-04-13 04:33:40',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 16,
#  'confidence': 91,
#  'datetime': '2023-04-13 04:33:30',
#  'surface_temperature_celcius': 69}
# {'air_temperature_celcius': 16,
#  'confidence': 99,
#  'datetime': '2023-04-13 04:33:30',
#  'surface_temperature_celcius': 85}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-13 04:33:30',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:33:20',
#  'surface_temperature_celcius': 96}
# {'air_temperature_celcius': 16,
#  'confidence': 89,
#  'datetime': '2023-04-13 04:33:20',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 97,
#  'datetime': '2023-04-13 04:33:10',
#  'surface_temperature_celcius': 80}
# {'air_temperature_celcius': 16,
#  'confidence': 88,
#  'datetime': '2023-04-13 04:33:00',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-13 04:33:00',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 82,
#  'datetime': '2023-04-13 04:33:00',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-13 04:32:20',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 98,
#  'datetime': '2023-04-13 04:31:00',
#  'surface_temperature_celcius': 82}
# {'air_temperature_celcius': 16,
#  'confidence': 89,
#  'datetime': '2023-04-13 04:30:50',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 16,
#  'confidence': 89,
#  'datetime': '2023-04-13 04:30:50',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-13 04:30:10',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 86,
#  'datetime': '2023-04-13 04:30:00',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-13 04:29:50',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-13 04:29:40',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-13 04:29:40',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 16,
#  'confidence': 88,
#  'datetime': '2023-04-13 04:29:40',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:29:40',
#  'surface_temperature_celcius': 93}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:29:20',
#  'surface_temperature_celcius': 95}
# {'air_temperature_celcius': 16,
#  'confidence': 89,
#  'datetime': '2023-04-13 04:28:50',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:28:30',
#  'surface_temperature_celcius': 114}
# {'air_temperature_celcius': 16,
#  'confidence': 84,
#  'datetime': '2023-04-13 04:28:30',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-13 04:28:20',
#  'surface_temperature_celcius': 67}
# {'air_temperature_celcius': 16,
#  'confidence': 92,
#  'datetime': '2023-04-13 04:28:20',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 120}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 90}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 102}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 16,
#  'confidence': 95,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 77}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 93,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 72}
# {'air_temperature_celcius': 16,
#  'confidence': 84,
#  'datetime': '2023-04-13 04:28:10',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 16,
#  'confidence': 98,
#  'datetime': '2023-04-13 04:27:40',
#  'surface_temperature_celcius': 82}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-13 04:27:40',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 92,
#  'datetime': '2023-04-13 04:27:30',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:27:30',
#  'surface_temperature_celcius': 88}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 113}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 86,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 95}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 67}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 92}
# {'air_temperature_celcius': 16,
#  'confidence': 88,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 16,
#  'confidence': 97,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 80}
# {'air_temperature_celcius': 16,
#  'confidence': 92,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 16,
#  'confidence': 81,
#  'datetime': '2023-04-13 04:27:20',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:27:00',
#  'surface_temperature_celcius': 101}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:26:50',
#  'surface_temperature_celcius': 107}
# {'air_temperature_celcius': 16,
#  'confidence': 94,
#  'datetime': '2023-04-13 04:26:50',
#  'surface_temperature_celcius': 75}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:26:50',
#  'surface_temperature_celcius': 115}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:26:50',
#  'surface_temperature_celcius': 89}
# {'air_temperature_celcius': 16,
#  'confidence': 91,
#  'datetime': '2023-04-13 04:26:50',
#  'surface_temperature_celcius': 68}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-13 04:26:50',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 16,
#  'confidence': 84,
#  'datetime': '2023-04-13 04:26:50',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 16,
#  'confidence': 85,
#  'datetime': '2023-04-13 04:26:50',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 16,
#  'confidence': 100,
#  'datetime': '2023-04-13 04:26:40',
#  'surface_temperature_celcius': 104}
# {'air_temperature_celcius': 16,
#  'confidence': 90,
#  'datetime': '2023-04-13 04:26:40',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 16,
#  'confidence': 80,
#  'datetime': '2023-04-13 04:26:40',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 16,
# ...
#  'confidence': 86,
#  'datetime': '2023-09-10 03:50:30',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 11,
#  'confidence': 81,
#  'datetime': '2023-09-10 03:50:10',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 14,
#  'confidence': 89,
#  'datetime': '2023-09-20 04:29:03',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-09-20 04:29:03',
#  'surface_temperature_celcius': 112}
# {'air_temperature_celcius': 14,
#  'confidence': 88,
#  'datetime': '2023-09-20 04:28:45',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 17,
#  'confidence': 86,
#  'datetime': '2023-09-23 23:50:44',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-09-23 12:47:12',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-09-23 12:47:12',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-09-23 12:47:12',
#  'surface_temperature_celcius': 48}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-09-23 12:47:12',
#  'surface_temperature_celcius': 52}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-09-23 12:47:12',
#  'surface_temperature_celcius': 50}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-09-23 12:47:12',
#  'surface_temperature_celcius': 84}
# {'air_temperature_celcius': 17,
#  'confidence': 100,
#  'datetime': '2023-09-23 12:47:12',
#  'surface_temperature_celcius': 79}
# {'air_temperature_celcius': 17,
#  'confidence': 88,
#  'datetime': '2023-09-23 04:59:13',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 17,
#  'confidence': 87,
#  'datetime': '2023-09-23 04:59:11',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 17,
#  'confidence': 80,
#  'datetime': '2023-09-23 04:59:11',
#  'surface_temperature_celcius': 50}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-09-24 15:07:47',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 14,
#  'confidence': 90,
#  'datetime': '2023-09-24 15:07:47',
#  'surface_temperature_celcius': 41}
# {'air_temperature_celcius': 14,
#  'confidence': 99,
#  'datetime': '2023-09-24 15:07:47',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 14,
#  'confidence': 94,
#  'datetime': '2023-09-24 15:07:45',
#  'surface_temperature_celcius': 43}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-09-24 15:07:45',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-09-24 13:30:10',
#  'surface_temperature_celcius': 47}
# {'air_temperature_celcius': 14,
#  'confidence': 82,
#  'datetime': '2023-09-24 13:30:09',
#  'surface_temperature_celcius': 38}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-09-24 13:30:09',
#  'surface_temperature_celcius': 48}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-09-24 13:30:09',
#  'surface_temperature_celcius': 48}
# {'air_temperature_celcius': 14,
#  'confidence': 84,
#  'datetime': '2023-09-24 13:30:07',
#  'surface_temperature_celcius': 50}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-09-24 04:04:19',
#  'surface_temperature_celcius': 88}
# {'air_temperature_celcius': 14,
#  'confidence': 86,
#  'datetime': '2023-09-24 04:04:18',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 14,
#  'confidence': 84,
#  'datetime': '2023-09-24 04:04:04',
#  'surface_temperature_celcius': 52}
# {'air_temperature_celcius': 15,
#  'confidence': 83,
#  'datetime': '2023-09-27 04:35:36',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 15,
#  'confidence': 86,
#  'datetime': '2023-09-27 04:35:36',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 14,
#  'confidence': 82,
#  'datetime': '2023-09-29 04:22:31',
#  'surface_temperature_celcius': 49}
# {'air_temperature_celcius': 12,
#  'confidence': 100,
#  'datetime': '2023-10-01 15:13:56',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 12,
#  'confidence': 84,
#  'datetime': '2023-10-01 04:10:28',
#  'surface_temperature_celcius': 52}
# {'air_temperature_celcius': 12,
#  'confidence': 89,
#  'datetime': '2023-10-01 04:10:28',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 11,
#  'confidence': 83,
#  'datetime': '2023-10-02 04:53:10',
#  'surface_temperature_celcius': 50}
# {'air_temperature_celcius': 11,
#  'confidence': 85,
#  'datetime': '2023-10-02 04:53:09',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 13,
#  'confidence': 92,
#  'datetime': '2023-10-03 13:23:43',
#  'surface_temperature_celcius': 42}
# {'air_temperature_celcius': 13,
#  'confidence': 90,
#  'datetime': '2023-10-03 03:58:15',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 13,
#  'confidence': 81,
#  'datetime': '2023-10-03 03:58:15',
#  'surface_temperature_celcius': 48}
# {'air_temperature_celcius': 13,
#  'confidence': 82,
#  'datetime': '2023-10-03 03:58:15',
#  'surface_temperature_celcius': 49}
# {'air_temperature_celcius': 13,
#  'confidence': 84,
#  'datetime': '2023-10-03 03:58:15',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 13,
#  'confidence': 90,
#  'datetime': '2023-10-03 03:58:15',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 13,
#  'confidence': 100,
#  'datetime': '2023-10-03 03:58:14',
#  'surface_temperature_celcius': 90}
# {'air_temperature_celcius': 13,
#  'confidence': 88,
#  'datetime': '2023-10-03 03:58:14',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 13,
#  'confidence': 87,
#  'datetime': '2023-10-03 03:58:14',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 19,
#  'confidence': 80,
#  'datetime': '2023-10-04 04:41:02',
#  'surface_temperature_celcius': 46}
# {'air_temperature_celcius': 19,
#  'confidence': 80,
#  'datetime': '2023-10-04 04:41:00',
#  'surface_temperature_celcius': 46}
# {'air_temperature_celcius': 19,
#  'confidence': 85,
#  'datetime': '2023-10-04 04:41:00',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 19,
#  'confidence': 88,
#  'datetime': '2023-10-04 04:41:00',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 17,
#  'confidence': 91,
#  'datetime': '2023-10-07 12:59:33',
#  'surface_temperature_celcius': 42}
# {'air_temperature_celcius': 13,
#  'confidence': 96,
#  'datetime': '2023-10-10 04:04:19',
#  'surface_temperature_celcius': 77}
# {'air_temperature_celcius': 13,
#  'confidence': 100,
#  'datetime': '2023-10-15 04:23:01',
#  'surface_temperature_celcius': 87}
# {'air_temperature_celcius': 13,
#  'confidence': 99,
#  'datetime': '2023-10-15 04:23:01',
#  'surface_temperature_celcius': 85}
# {'air_temperature_celcius': 22,
#  'confidence': 94,
#  'datetime': '2023-10-17 13:36:12',
#  'surface_temperature_celcius': 43}
# {'air_temperature_celcius': 22,
#  'confidence': 91,
#  'datetime': '2023-10-17 04:10:45',
#  'surface_temperature_celcius': 68}
# {'air_temperature_celcius': 22,
#  'confidence': 82,
#  'datetime': '2023-10-17 04:10:32',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 26,
#  'confidence': 84,
#  'datetime': '2023-10-18 00:39:02',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 26,
#  'confidence': 82,
#  'datetime': '2023-10-18 00:39:02',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 13,
#  'confidence': 80,
#  'datetime': '2023-10-20 04:41:19',
#  'surface_temperature_celcius': 46}
# {'air_temperature_celcius': 13,
#  'confidence': 82,
#  'datetime': '2023-10-20 04:41:19',
#  'surface_temperature_celcius': 50}
# {'air_temperature_celcius': 12,
#  'confidence': 88,
#  'datetime': '2023-10-21 01:09:55',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 12,
#  'confidence': 92,
#  'datetime': '2023-10-21 01:09:54',
#  'surface_temperature_celcius': 67}
# {'air_temperature_celcius': 13,
#  'confidence': 100,
#  'datetime': '2023-10-26 13:30:31',
#  'surface_temperature_celcius': 48}
# {'air_temperature_celcius': 13,
#  'confidence': 100,
#  'datetime': '2023-10-26 13:30:31',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 22,
#  'confidence': 86,
#  'datetime': '2023-10-27 04:47:31',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 15,
#  'confidence': 81,
#  'datetime': '2023-10-28 03:52:17',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 13,
#  'confidence': 83,
#  'datetime': '2023-11-05 04:41:34',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 13,
#  'confidence': 90,
#  'datetime': '2023-11-05 04:41:19',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 13,
#  'confidence': 89,
#  'datetime': '2023-11-05 04:41:19',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 14,
#  'confidence': 85,
#  'datetime': '2023-11-09 04:16:48',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 14,
#  'confidence': 100,
#  'datetime': '2023-11-09 04:16:48',
#  'surface_temperature_celcius': 93}
# {'air_temperature_celcius': 14,
#  'confidence': 96,
#  'datetime': '2023-11-09 04:16:48',
#  'surface_temperature_celcius': 77}
# {'air_temperature_celcius': 14,
#  'confidence': 87,
#  'datetime': '2023-11-09 04:16:44',
#  'surface_temperature_celcius': 62}
# {'air_temperature_celcius': 14,
#  'confidence': 97,
#  'datetime': '2023-11-09 04:16:44',
#  'surface_temperature_celcius': 80}
# {'air_temperature_celcius': 18,
#  'confidence': 80,
#  'datetime': '2023-11-11 13:30:08',
#  'surface_temperature_celcius': 37}
# {'air_temperature_celcius': 18,
#  'confidence': 100,
#  'datetime': '2023-11-11 13:30:08',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 18,
#  'confidence': 86,
#  'datetime': '2023-11-11 04:04:25',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 18,
#  'confidence': 89,
#  'datetime': '2023-11-12 00:33:15',
#  'surface_temperature_celcius': 69}
# {'air_temperature_celcius': 24,
#  'confidence': 87,
#  'datetime': '2023-11-13 03:52:15',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 24,
#  'confidence': 81,
#  'datetime': '2023-11-13 03:52:14',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 28,
#  'confidence': 87,
#  'datetime': '2023-11-14 04:35:04',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 24,
#  'confidence': 85,
#  'datetime': '2023-11-21 00:27:21',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 23,
#  'confidence': 84,
#  'datetime': '2023-11-22 03:46:00',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 23,
#  'confidence': 88,
#  'datetime': '2023-11-22 03:46:00',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 24,
#  'confidence': 84,
#  'datetime': '2023-11-23 04:28:59',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 24,
#  'confidence': 93,
#  'datetime': '2023-11-23 04:28:59',
#  'surface_temperature_celcius': 73}
# {'air_temperature_celcius': 28,
#  'confidence': 100,
#  'datetime': '2023-11-29 13:17:24',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 28,
#  'confidence': 100,
#  'datetime': '2023-11-29 03:52:10',
#  'surface_temperature_celcius': 87}
# {'air_temperature_celcius': 28,
#  'confidence': 97,
#  'datetime': '2023-11-29 03:52:10',
#  'surface_temperature_celcius': 80}
# {'air_temperature_celcius': 28,
#  'confidence': 99,
#  'datetime': '2023-11-29 03:52:10',
#  'surface_temperature_celcius': 84}
# {'air_temperature_celcius': 26,
#  'confidence': 100,
#  'datetime': '2023-11-30 15:38:36',
#  'surface_temperature_celcius': 53}
# {'air_temperature_celcius': 26,
#  'confidence': 100,
#  'datetime': '2023-11-30 15:38:35',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 26,
#  'confidence': 100,
#  'datetime': '2023-11-30 15:38:35',
#  'surface_temperature_celcius': 49}
# {'air_temperature_celcius': 26,
#  'confidence': 84,
#  'datetime': '2023-11-30 12:22:15',
#  'surface_temperature_celcius': 38}
# {'air_temperature_celcius': 26,
#  'confidence': 81,
#  'datetime': '2023-11-30 12:22:15',
#  'surface_temperature_celcius': 42}
# {'air_temperature_celcius': 26,
#  'confidence': 100,
#  'datetime': '2023-11-30 12:22:15',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 26,
#  'confidence': 100,
#  'datetime': '2023-11-30 12:22:15',
#  'surface_temperature_celcius': 65}
# {'air_temperature_celcius': 26,
#  'confidence': 100,
#  'datetime': '2023-11-30 12:22:14',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 26,
#  'confidence': 84,
#  'datetime': '2023-11-30 04:35:00',
#  'surface_temperature_celcius': 59}
# {'air_temperature_celcius': 26,
#  'confidence': 98,
#  'datetime': '2023-11-30 04:34:57',
#  'surface_temperature_celcius': 83}
# {'air_temperature_celcius': 26,
#  'confidence': 81,
#  'datetime': '2023-11-30 04:34:57',
#  'surface_temperature_celcius': 57}
# {'air_temperature_celcius': 26,
#  'confidence': 84,
#  'datetime': '2023-11-30 04:34:57',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 26,
#  'confidence': 99,
#  'datetime': '2023-11-30 04:34:57',
#  'surface_temperature_celcius': 86}
# {'air_temperature_celcius': 26,
#  'confidence': 83,
#  'datetime': '2023-11-30 00:20:53',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 26,
#  'confidence': 87,
#  'datetime': '2023-11-30 00:20:53',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 26,
#  'confidence': 95,
#  'datetime': '2023-11-30 00:20:53',
#  'surface_temperature_celcius': 76}
# {'air_temperature_celcius': 26,
#  'confidence': 81,
#  'datetime': '2023-11-30 00:20:53',
#  'surface_temperature_celcius': 56}
# {'air_temperature_celcius': 26,
#  'confidence': 81,
#  'datetime': '2023-11-30 00:20:53',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-12-08 13:11:44',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-12-08 13:11:44',
#  'surface_temperature_celcius': 71}
# {'air_temperature_celcius': 15,
#  'confidence': 100,
#  'datetime': '2023-12-08 13:11:43',
#  'surface_temperature_celcius': 52}
# {'air_temperature_celcius': 17,
#  'confidence': 87,
#  'datetime': '2023-12-09 00:14:34',
#  'surface_temperature_celcius': 61}
# {'air_temperature_celcius': 17,
#  'confidence': 81,
#  'datetime': '2023-12-09 00:14:34',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 17,
#  'confidence': 84,
#  'datetime': '2023-12-09 00:14:33',
#  'surface_temperature_celcius': 58}
# {'air_temperature_celcius': 17,
#  'confidence': 86,
#  'datetime': '2023-12-09 00:14:33',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 28,
#  'confidence': 83,
#  'datetime': '2023-12-13 04:04:19',
#  'surface_temperature_celcius': 60}
# {'air_temperature_celcius': 17,
#  'confidence': 92,
#  'datetime': '2023-12-14 04:47:25',
#  'surface_temperature_celcius': 70}
# {'air_temperature_celcius': 18,
#  'confidence': 92,
#  'datetime': '2023-12-15 13:17:17',
#  'surface_temperature_celcius': 42}
# {'air_temperature_celcius': 18,
#  'confidence': 94,
#  'datetime': '2023-12-16 15:38:39',
#  'surface_temperature_celcius': 43}
# {'air_temperature_celcius': 18,
#  'confidence': 93,
#  'datetime': '2023-12-16 04:35:13',
#  'surface_temperature_celcius': 73}
# {'air_temperature_celcius': 18,
#  'confidence': 84,
#  'datetime': '2023-12-16 04:34:58',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 18,
#  'confidence': 95,
#  'datetime': '2023-12-16 04:34:58',
#  'surface_temperature_celcius': 75}
# {'air_temperature_celcius': 18,
#  'confidence': 90,
#  'datetime': '2023-12-16 04:34:57',
#  'surface_temperature_celcius': 66}
# {'air_temperature_celcius': 18,
#  'confidence': 93,
#  'datetime': '2023-12-16 00:21:12',
#  'surface_temperature_celcius': 73}
# {'air_temperature_celcius': 18,
#  'confidence': 82,
#  'datetime': '2023-12-16 00:21:11',
#  'surface_temperature_celcius': 55}
# {'air_temperature_celcius': 18,
#  'confidence': 82,
#  'datetime': '2023-12-16 00:20:53',
#  'surface_temperature_celcius': 64}
# {'air_temperature_celcius': 17,
#  'confidence': 80,
#  'datetime': '2023-12-25 04:29:08',
#  'surface_temperature_celcius': 54}
# {'air_temperature_celcius': 28,
#  'confidence': 82,
#  'datetime': '2023-12-27 00:02:15',
#  'surface_temperature_celcius': 63}
# {'air_temperature_celcius': 28,
#  'confidence': 86,
#  'datetime': '2023-12-27 00:02:14',
#  'surface_temperature_celcius': 67}

# %% [markdown]
# ##### **e) Top 10 records with the highest surface temperature (°C)**

# %%
pipeline_stages = [{"$unwind": "$hotspots"},  #unwind to be able to order all documents individually
                   {"$sort": {"hotspots.surface_temperature_celcius": -1}},  #sort in descending order based on surface temp
                   {"$limit": 10} #output only top 10 records
                  ]

data = climate_col.aggregate(pipeline_stages)  #execute aggregation pipeline

for document in data:
    pprint(document)
# Out:
# {'GHI_w/m2': 122,
#  '_id': ObjectId('663d77f75178059695ff6097'),
#  'air_temperature_celcius': 15,
#  'date': '18/4/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-04-18 04:52:00',
#               'latitude': -38.1665,
#               'longitude': 143.062,
#               'surface_temperature_celcius': 124},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('663d77f75178059695ff6089'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-04-04 04:32:50',
#               'latitude': -36.343,
#               'longitude': 142.1986,
#               'surface_temperature_celcius': 123},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 121,
#  '_id': ObjectId('663d77f75178059695ff60a4'),
#  'air_temperature_celcius': 14,
#  'date': '1/5/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-05-01 04:14:20',
#               'latitude': -36.9318,
#               'longitude': 143.0907,
#               'surface_temperature_celcius': 122},
#  'max_wind_speed': 20.0,
#  'precipitation': '0.12G',
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('663d77f75178059695ff6078'),
#  'air_temperature_celcius': 21,
#  'date': '18/3/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-03-18 03:50:50',
#               'latitude': -37.017,
#               'longitude': 148.1297,
#               'surface_temperature_celcius': 121},
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('663d77f75178059695ff6089'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-04-04 04:32:40',
#               'latitude': -36.3521,
#               'longitude': 142.2008,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 132,
#  '_id': ObjectId('663d77f75178059695ff6092'),
#  'air_temperature_celcius': 16,
#  'date': '13/4/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-04-13 04:28:10',
#               'latitude': -37.0745,
#               'longitude': 141.0692,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 81,
#  '_id': ObjectId('663d77f75178059695ff60b0'),
#  'air_temperature_celcius': 9,
#  'date': '13/5/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-05-13 04:40:20',
#               'latitude': -34.9938,
#               'longitude': 141.876,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 8.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('663d77f75178059695ff6097'),
#  'air_temperature_celcius': 15,
#  'date': '18/4/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-04-18 04:44:50',
#               'latitude': -37.8326,
#               'longitude': 143.4999,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('663d77f75178059695ff6089'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-04-04 04:40:00',
#               'latitude': -36.1057,
#               'longitude': 141.7608,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('663d77f75178059695ff60a7'),
#  'air_temperature_celcius': 10,
#  'date': '4/5/2023',
#  'hotspots': {'confidence': 100,
#               'datetime': '2023-05-04 04:44:50',
#               'latitude': -36.4057,
#               'longitude': 140.9806,
#               'surface_temperature_celcius': 119},
#  'max_wind_speed': 7.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}

# %% [markdown]
# ##### **f) Number of fires each day**

# %%
#project only date and number of fires
projected_fields = {
                     "_id": 0,
                     "date": 1, 
                     "number_of_fires": {
                         "$size": "$hotspots"  #number of fires each day = size of each hotspots list
                     }
                    }

pipeline_stages = [{"$project": projected_fields}]

data = climate_col.aggregate(pipeline_stages)  #execute aggregation pipeline

for document in data:
    pprint(document)
# Out:
# {'date': '31/12/2022', 'number_of_fires': 0}
# {'date': '2/1/2023', 'number_of_fires': 0}
# {'date': '3/1/2023', 'number_of_fires': 0}
# {'date': '4/1/2023', 'number_of_fires': 0}
# {'date': '5/1/2023', 'number_of_fires': 0}
# {'date': '6/1/2023', 'number_of_fires': 0}
# {'date': '7/1/2023', 'number_of_fires': 0}
# {'date': '8/1/2023', 'number_of_fires': 0}
# {'date': '9/1/2023', 'number_of_fires': 0}
# {'date': '10/1/2023', 'number_of_fires': 0}
# {'date': '11/1/2023', 'number_of_fires': 0}
# {'date': '12/1/2023', 'number_of_fires': 0}
# {'date': '13/1/2023', 'number_of_fires': 0}
# {'date': '14/1/2023', 'number_of_fires': 0}
# {'date': '15/1/2023', 'number_of_fires': 0}
# {'date': '16/1/2023', 'number_of_fires': 0}
# {'date': '17/1/2023', 'number_of_fires': 0}
# {'date': '18/1/2023', 'number_of_fires': 0}
# {'date': '19/1/2023', 'number_of_fires': 0}
# {'date': '20/1/2023', 'number_of_fires': 0}
# {'date': '21/1/2023', 'number_of_fires': 0}
# {'date': '22/1/2023', 'number_of_fires': 0}
# {'date': '23/1/2023', 'number_of_fires': 0}
# {'date': '24/1/2023', 'number_of_fires': 0}
# {'date': '25/1/2023', 'number_of_fires': 0}
# {'date': '26/1/2023', 'number_of_fires': 0}
# {'date': '27/1/2023', 'number_of_fires': 0}
# {'date': '28/1/2023', 'number_of_fires': 0}
# {'date': '29/1/2023', 'number_of_fires': 0}
# {'date': '30/1/2023', 'number_of_fires': 0}
# {'date': '31/1/2023', 'number_of_fires': 0}
# {'date': '1/2/2023', 'number_of_fires': 0}
# {'date': '2/2/2023', 'number_of_fires': 0}
# {'date': '3/2/2023', 'number_of_fires': 0}
# {'date': '4/2/2023', 'number_of_fires': 0}
# {'date': '5/2/2023', 'number_of_fires': 0}
# {'date': '6/2/2023', 'number_of_fires': 0}
# {'date': '7/2/2023', 'number_of_fires': 0}
# {'date': '8/2/2023', 'number_of_fires': 0}
# {'date': '9/2/2023', 'number_of_fires': 0}
# {'date': '10/2/2023', 'number_of_fires': 0}
# {'date': '11/2/2023', 'number_of_fires': 0}
# {'date': '12/2/2023', 'number_of_fires': 0}
# {'date': '13/2/2023', 'number_of_fires': 0}
# {'date': '14/2/2023', 'number_of_fires': 0}
# {'date': '15/2/2023', 'number_of_fires': 0}
# {'date': '16/2/2023', 'number_of_fires': 0}
# {'date': '17/2/2023', 'number_of_fires': 0}
# {'date': '18/2/2023', 'number_of_fires': 0}
# {'date': '19/2/2023', 'number_of_fires': 0}
# {'date': '20/2/2023', 'number_of_fires': 0}
# {'date': '21/2/2023', 'number_of_fires': 0}
# {'date': '22/2/2023', 'number_of_fires': 0}
# {'date': '23/2/2023', 'number_of_fires': 0}
# {'date': '24/2/2023', 'number_of_fires': 0}
# {'date': '25/2/2023', 'number_of_fires': 0}
# {'date': '26/2/2023', 'number_of_fires': 0}
# {'date': '27/2/2023', 'number_of_fires': 0}
# {'date': '28/2/2023', 'number_of_fires': 0}
# {'date': '1/3/2023', 'number_of_fires': 0}
# {'date': '2/3/2023', 'number_of_fires': 0}
# {'date': '3/3/2023', 'number_of_fires': 0}
# {'date': '4/3/2023', 'number_of_fires': 0}
# {'date': '5/3/2023', 'number_of_fires': 0}
# {'date': '6/3/2023', 'number_of_fires': 2}
# {'date': '7/3/2023', 'number_of_fires': 1}
# {'date': '8/3/2023', 'number_of_fires': 2}
# {'date': '9/3/2023', 'number_of_fires': 3}
# {'date': '10/3/2023', 'number_of_fires': 8}
# {'date': '11/3/2023', 'number_of_fires': 0}
# {'date': '12/3/2023', 'number_of_fires': 5}
# {'date': '13/3/2023', 'number_of_fires': 2}
# {'date': '14/3/2023', 'number_of_fires': 10}
# {'date': '15/3/2023', 'number_of_fires': 7}
# {'date': '16/3/2023', 'number_of_fires': 0}
# {'date': '17/3/2023', 'number_of_fires': 6}
# {'date': '18/3/2023', 'number_of_fires': 3}
# {'date': '19/3/2023', 'number_of_fires': 21}
# {'date': '20/3/2023', 'number_of_fires': 0}
# {'date': '21/3/2023', 'number_of_fires': 0}
# {'date': '22/3/2023', 'number_of_fires': 0}
# {'date': '23/3/2023', 'number_of_fires': 0}
# {'date': '24/3/2023', 'number_of_fires': 2}
# {'date': '25/3/2023', 'number_of_fires': 13}
# {'date': '26/3/2023', 'number_of_fires': 17}
# {'date': '27/3/2023', 'number_of_fires': 0}
# {'date': '28/3/2023', 'number_of_fires': 54}
# {'date': '29/3/2023', 'number_of_fires': 1}
# {'date': '30/3/2023', 'number_of_fires': 0}
# {'date': '31/3/2023', 'number_of_fires': 22}
# {'date': '1/4/2023', 'number_of_fires': 7}
# {'date': '2/4/2023', 'number_of_fires': 5}
# {'date': '3/4/2023', 'number_of_fires': 72}
# {'date': '4/4/2023', 'number_of_fires': 89}
# {'date': '5/4/2023', 'number_of_fires': 49}
# {'date': '6/4/2023', 'number_of_fires': 118}
# {'date': '7/4/2023', 'number_of_fires': 39}
# {'date': '8/4/2023', 'number_of_fires': 20}
# {'date': '9/4/2023', 'number_of_fires': 0}
# {'date': '10/4/2023', 'number_of_fires': 0}
# {'date': '11/4/2023', 'number_of_fires': 24}
# {'date': '12/4/2023', 'number_of_fires': 69}
# {'date': '13/4/2023', 'number_of_fires': 357}
# {'date': '14/4/2023', 'number_of_fires': 18}
# {'date': '15/4/2023', 'number_of_fires': 69}
# {'date': '16/4/2023', 'number_of_fires': 18}
# {'date': '17/4/2023', 'number_of_fires': 38}
# {'date': '18/4/2023', 'number_of_fires': 325}
# {'date': '19/4/2023', 'number_of_fires': 50}
# {'date': '20/4/2023', 'number_of_fires': 31}
# {'date': '21/4/2023', 'number_of_fires': 0}
# {'date': '22/4/2023', 'number_of_fires': 2}
# {'date': '23/4/2023', 'number_of_fires': 19}
# {'date': '24/4/2023', 'number_of_fires': 8}
# {'date': '25/4/2023', 'number_of_fires': 3}
# {'date': '26/4/2023', 'number_of_fires': 1}
# {'date': '27/4/2023', 'number_of_fires': 0}
# {'date': '28/4/2023', 'number_of_fires': 0}
# {'date': '29/4/2023', 'number_of_fires': 3}
# {'date': '30/4/2023', 'number_of_fires': 0}
# {'date': '1/5/2023', 'number_of_fires': 20}
# {'date': '2/5/2023', 'number_of_fires': 10}
# {'date': '3/5/2023', 'number_of_fires': 64}
# {'date': '4/5/2023', 'number_of_fires': 135}
# {'date': '5/5/2023', 'number_of_fires': 31}
# {'date': '6/5/2023', 'number_of_fires': 17}
# {'date': '7/5/2023', 'number_of_fires': 3}
# {'date': '8/5/2023', 'number_of_fires': 24}
# {'date': '9/5/2023', 'number_of_fires': 13}
# {'date': '10/5/2023', 'number_of_fires': 114}
# {'date': '11/5/2023', 'number_of_fires': 19}
# {'date': '12/5/2023', 'number_of_fires': 10}
# {'date': '13/5/2023', 'number_of_fires': 54}
# {'date': '14/5/2023', 'number_of_fires': 1}
# {'date': '15/5/2023', 'number_of_fires': 102}
# {'date': '16/5/2023', 'number_of_fires': 3}
# {'date': '17/5/2023', 'number_of_fires': 1}
# {'date': '18/5/2023', 'number_of_fires': 7}
# {'date': '19/5/2023', 'number_of_fires': 0}
# {'date': '20/5/2023', 'number_of_fires': 0}
# {'date': '21/5/2023', 'number_of_fires': 0}
# {'date': '22/5/2023', 'number_of_fires': 33}
# {'date': '23/5/2023', 'number_of_fires': 5}
# {'date': '24/5/2023', 'number_of_fires': 3}
# {'date': '25/5/2023', 'number_of_fires': 0}
# {'date': '26/5/2023', 'number_of_fires': 4}
# {'date': '27/5/2023', 'number_of_fires': 0}
# {'date': '28/5/2023', 'number_of_fires': 0}
# {'date': '29/5/2023', 'number_of_fires': 0}
# {'date': '30/5/2023', 'number_of_fires': 0}
# {'date': '31/5/2023', 'number_of_fires': 0}
# {'date': '1/6/2023', 'number_of_fires': 2}
# {'date': '2/6/2023', 'number_of_fires': 11}
# {'date': '3/6/2023', 'number_of_fires': 2}
# {'date': '4/6/2023', 'number_of_fires': 9}
# {'date': '5/6/2023', 'number_of_fires': 0}
# {'date': '6/6/2023', 'number_of_fires': 0}
# {'date': '7/6/2023', 'number_of_fires': 14}
# {'date': '8/6/2023', 'number_of_fires': 0}
# {'date': '9/6/2023', 'number_of_fires': 3}
# {'date': '10/6/2023', 'number_of_fires': 0}
# {'date': '11/6/2023', 'number_of_fires': 2}
# {'date': '12/6/2023', 'number_of_fires': 0}
# {'date': '13/6/2023', 'number_of_fires': 1}
# {'date': '14/6/2023', 'number_of_fires': 4}
# {'date': '15/6/2023', 'number_of_fires': 0}
# {'date': '16/6/2023', 'number_of_fires': 2}
# {'date': '17/6/2023', 'number_of_fires': 0}
# {'date': '18/6/2023', 'number_of_fires': 2}
# {'date': '19/6/2023', 'number_of_fires': 0}
# {'date': '20/6/2023', 'number_of_fires': 6}
# {'date': '21/6/2023', 'number_of_fires': 0}
# {'date': '22/6/2023', 'number_of_fires': 1}
# {'date': '23/6/2023', 'number_of_fires': 0}
# {'date': '24/6/2023', 'number_of_fires': 0}
# {'date': '25/6/2023', 'number_of_fires': 0}
# {'date': '26/6/2023', 'number_of_fires': 0}
# {'date': '27/6/2023', 'number_of_fires': 0}
# {'date': '28/6/2023', 'number_of_fires': 0}
# {'date': '29/6/2023', 'number_of_fires': 0}
# {'date': '30/6/2023', 'number_of_fires': 6}
# {'date': '1/7/2023', 'number_of_fires': 4}
# {'date': '2/7/2023', 'number_of_fires': 8}
# {'date': '3/7/2023', 'number_of_fires': 0}
# {'date': '4/7/2023', 'number_of_fires': 1}
# {'date': '5/7/2023', 'number_of_fires': 1}
# {'date': '6/7/2023', 'number_of_fires': 3}
# {'date': '7/7/2023', 'number_of_fires': 0}
# {'date': '8/7/2023', 'number_of_fires': 0}
# {'date': '9/7/2023', 'number_of_fires': 0}
# {'date': '10/7/2023', 'number_of_fires': 0}
# {'date': '11/7/2023', 'number_of_fires': 0}
# {'date': '12/7/2023', 'number_of_fires': 0}
# {'date': '13/7/2023', 'number_of_fires': 0}
# {'date': '14/7/2023', 'number_of_fires': 2}
# {'date': '15/7/2023', 'number_of_fires': 0}
# {'date': '16/7/2023', 'number_of_fires': 0}
# {'date': '17/7/2023', 'number_of_fires': 0}
# {'date': '18/7/2023', 'number_of_fires': 0}
# {'date': '19/7/2023', 'number_of_fires': 0}
# {'date': '20/7/2023', 'number_of_fires': 0}
# {'date': '21/7/2023', 'number_of_fires': 0}
# {'date': '22/7/2023', 'number_of_fires': 0}
# {'date': '23/7/2023', 'number_of_fires': 0}
# {'date': '24/7/2023', 'number_of_fires': 0}
# {'date': '25/7/2023', 'number_of_fires': 0}
# {'date': '26/7/2023', 'number_of_fires': 0}
# {'date': '27/7/2023', 'number_of_fires': 0}
# {'date': '28/7/2023', 'number_of_fires': 0}
# {'date': '29/7/2023', 'number_of_fires': 2}
# {'date': '30/7/2023', 'number_of_fires': 0}
# {'date': '31/7/2023', 'number_of_fires': 2}
# {'date': '1/8/2023', 'number_of_fires': 2}
# {'date': '2/8/2023', 'number_of_fires': 2}
# {'date': '3/8/2023', 'number_of_fires': 0}
# {'date': '4/8/2023', 'number_of_fires': 0}
# {'date': '5/8/2023', 'number_of_fires': 1}
# {'date': '6/8/2023', 'number_of_fires': 0}
# {'date': '7/8/2023', 'number_of_fires': 0}
# {'date': '8/8/2023', 'number_of_fires': 0}
# {'date': '9/8/2023', 'number_of_fires': 0}
# {'date': '10/8/2023', 'number_of_fires': 1}
# {'date': '11/8/2023', 'number_of_fires': 0}
# {'date': '12/8/2023', 'number_of_fires': 0}
# {'date': '13/8/2023', 'number_of_fires': 9}
# {'date': '14/8/2023', 'number_of_fires': 5}
# {'date': '15/8/2023', 'number_of_fires': 0}
# {'date': '16/8/2023', 'number_of_fires': 0}
# {'date': '17/8/2023', 'number_of_fires': 0}
# {'date': '18/8/2023', 'number_of_fires': 0}
# {'date': '19/8/2023', 'number_of_fires': 0}
# {'date': '20/8/2023', 'number_of_fires': 0}
# {'date': '21/8/2023', 'number_of_fires': 0}
# {'date': '22/8/2023', 'number_of_fires': 0}
# {'date': '23/8/2023', 'number_of_fires': 0}
# {'date': '24/8/2023', 'number_of_fires': 0}
# {'date': '25/8/2023', 'number_of_fires': 0}
# {'date': '26/8/2023', 'number_of_fires': 0}
# {'date': '27/8/2023', 'number_of_fires': 0}
# {'date': '28/8/2023', 'number_of_fires': 0}
# {'date': '29/8/2023', 'number_of_fires': 0}
# {'date': '30/8/2023', 'number_of_fires': 0}
# {'date': '31/8/2023', 'number_of_fires': 0}
# {'date': '1/9/2023', 'number_of_fires': 0}
# {'date': '2/9/2023', 'number_of_fires': 0}
# {'date': '3/9/2023', 'number_of_fires': 0}
# {'date': '4/9/2023', 'number_of_fires': 0}
# {'date': '5/9/2023', 'number_of_fires': 0}
# {'date': '6/9/2023', 'number_of_fires': 0}
# {'date': '7/9/2023', 'number_of_fires': 0}
# {'date': '8/9/2023', 'number_of_fires': 0}
# {'date': '9/9/2023', 'number_of_fires': 0}
# {'date': '10/9/2023', 'number_of_fires': 4}
# {'date': '11/9/2023', 'number_of_fires': 0}
# {'date': '12/9/2023', 'number_of_fires': 0}
# {'date': '13/9/2023', 'number_of_fires': 0}
# {'date': '14/9/2023', 'number_of_fires': 0}
# {'date': '15/9/2023', 'number_of_fires': 0}
# {'date': '16/9/2023', 'number_of_fires': 0}
# {'date': '17/9/2023', 'number_of_fires': 0}
# {'date': '18/9/2023', 'number_of_fires': 0}
# {'date': '19/9/2023', 'number_of_fires': 0}
# {'date': '20/9/2023', 'number_of_fires': 5}
# {'date': '21/9/2023', 'number_of_fires': 2}
# {'date': '22/9/2023', 'number_of_fires': 1}
# {'date': '23/9/2023', 'number_of_fires': 23}
# {'date': '24/9/2023', 'number_of_fires': 28}
# {'date': '25/9/2023', 'number_of_fires': 0}
# {'date': '26/9/2023', 'number_of_fires': 1}
# {'date': '27/9/2023', 'number_of_fires': 7}
# {'date': '28/9/2023', 'number_of_fires': 0}
# {'date': '29/9/2023', 'number_of_fires': 2}
# {'date': '30/9/2023', 'number_of_fires': 0}
# {'date': '1/10/2023', 'number_of_fires': 8}
# {'date': '2/10/2023', 'number_of_fires': 7}
# {'date': '3/10/2023', 'number_of_fires': 18}
# {'date': '4/10/2023', 'number_of_fires': 5}
# {'date': '5/10/2023', 'number_of_fires': 0}
# {'date': '6/10/2023', 'number_of_fires': 2}
# {'date': '7/10/2023', 'number_of_fires': 1}
# {'date': '8/10/2023', 'number_of_fires': 1}
# {'date': '9/10/2023', 'number_of_fires': 1}
# {'date': '10/10/2023', 'number_of_fires': 3}
# {'date': '11/10/2023', 'number_of_fires': 0}
# {'date': '12/10/2023', 'number_of_fires': 0}
# {'date': '13/10/2023', 'number_of_fires': 0}
# {'date': '14/10/2023', 'number_of_fires': 0}
# {'date': '15/10/2023', 'number_of_fires': 3}
# {'date': '16/10/2023', 'number_of_fires': 1}
# {'date': '17/10/2023', 'number_of_fires': 5}
# {'date': '18/10/2023', 'number_of_fires': 6}
# {'date': '19/10/2023', 'number_of_fires': 0}
# {'date': '20/10/2023', 'number_of_fires': 3}
# {'date': '21/10/2023', 'number_of_fires': 4}
# {'date': '22/10/2023', 'number_of_fires': 0}
# {'date': '23/10/2023', 'number_of_fires': 1}
# {'date': '24/10/2023', 'number_of_fires': 0}
# {'date': '25/10/2023', 'number_of_fires': 0}
# {'date': '26/10/2023', 'number_of_fires': 5}
# {'date': '27/10/2023', 'number_of_fires': 5}
# {'date': '28/10/2023', 'number_of_fires': 1}
# {'date': '29/10/2023', 'number_of_fires': 0}
# {'date': '30/10/2023', 'number_of_fires': 0}
# {'date': '31/10/2023', 'number_of_fires': 0}
# {'date': '1/11/2023', 'number_of_fires': 0}
# {'date': '2/11/2023', 'number_of_fires': 0}
# {'date': '3/11/2023', 'number_of_fires': 0}
# {'date': '4/11/2023', 'number_of_fires': 0}
# {'date': '5/11/2023', 'number_of_fires': 4}
# {'date': '6/11/2023', 'number_of_fires': 0}
# {'date': '7/11/2023', 'number_of_fires': 0}
# {'date': '8/11/2023', 'number_of_fires': 2}
# {'date': '9/11/2023', 'number_of_fires': 10}
# {'date': '10/11/2023', 'number_of_fires': 0}
# {'date': '11/11/2023', 'number_of_fires': 4}
# {'date': '12/11/2023', 'number_of_fires': 5}
# {'date': '13/11/2023', 'number_of_fires': 5}
# {'date': '14/11/2023', 'number_of_fires': 3}
# {'date': '15/11/2023', 'number_of_fires': 0}
# {'date': '16/11/2023', 'number_of_fires': 0}
# {'date': '17/11/2023', 'number_of_fires': 0}
# {'date': '18/11/2023', 'number_of_fires': 0}
# {'date': '19/11/2023', 'number_of_fires': 0}
# {'date': '20/11/2023', 'number_of_fires': 0}
# {'date': '21/11/2023', 'number_of_fires': 1}
# {'date': '22/11/2023', 'number_of_fires': 2}
# {'date': '23/11/2023', 'number_of_fires': 5}
# {'date': '24/11/2023', 'number_of_fires': 0}
# {'date': '25/11/2023', 'number_of_fires': 0}
# {'date': '26/11/2023', 'number_of_fires': 0}
# {'date': '27/11/2023', 'number_of_fires': 0}
# {'date': '28/11/2023', 'number_of_fires': 1}
# {'date': '29/11/2023', 'number_of_fires': 8}
# {'date': '30/11/2023', 'number_of_fires': 31}
# {'date': '1/12/2023', 'number_of_fires': 0}
# {'date': '2/12/2023', 'number_of_fires': 0}
# {'date': '3/12/2023', 'number_of_fires': 0}
# {'date': '4/12/2023', 'number_of_fires': 0}
# {'date': '5/12/2023', 'number_of_fires': 0}
# {'date': '6/12/2023', 'number_of_fires': 0}
# {'date': '7/12/2023', 'number_of_fires': 0}
# {'date': '8/12/2023', 'number_of_fires': 5}
# {'date': '9/12/2023', 'number_of_fires': 4}
# {'date': '10/12/2023', 'number_of_fires': 2}
# {'date': '11/12/2023', 'number_of_fires': 0}
# {'date': '12/12/2023', 'number_of_fires': 1}
# {'date': '13/12/2023', 'number_of_fires': 1}
# {'date': '14/12/2023', 'number_of_fires': 1}
# {'date': '15/12/2023', 'number_of_fires': 4}
# {'date': '16/12/2023', 'number_of_fires': 15}
# {'date': '17/12/2023', 'number_of_fires': 0}
# {'date': '18/12/2023', 'number_of_fires': 0}
# {'date': '19/12/2023', 'number_of_fires': 0}
# {'date': '20/12/2023', 'number_of_fires': 0}
# {'date': '21/12/2023', 'number_of_fires': 1}
# {'date': '22/12/2023', 'number_of_fires': 0}
# {'date': '23/12/2023', 'number_of_fires': 0}
# {'date': '24/12/2023', 'number_of_fires': 1}
# {'date': '25/12/2023', 'number_of_fires': 1}
# {'date': '26/12/2023', 'number_of_fires': 0}
# {'date': '27/12/2023', 'number_of_fires': 4}
# {'date': '28/12/2023', 'number_of_fires': 0}
# {'date': '29/12/2023', 'number_of_fires': 0}
# {'date': '30/12/2023', 'number_of_fires': 0}
# {'date': '31/12/2023', 'number_of_fires': 0}
# {'date': '1/1/2024', 'number_of_fires': 0}

# %% [markdown]
# ##### **g) Records of fires with confidence below 70**

# %%
#extract only embedded hotspot attributes from each climate document

#to show hotspot attributes as distinct attributes rather than embedded inside a hotspot document, 
#the path to the attributes is given instead of a boolean value during projection
projected_fields = {
                     "_id": 0,
                     "latitude": "$hotspots.latitude",
                     "longitude": "$hotspots.longitude",
                     "datetime": "$hotspots.datetime",
                     "confidence": "$hotspots.confidence",
                     "surface_temperature_celcius": "$hotspots.surface_temperature_celcius",
                    }

pipeline_stages = [{"$unwind": "$hotspots"},  #hotspots = fire records
                   {"$match": {"hotspots.confidence": {"$lt": 70}}},  #filter for confidence < 70
                   {"$project": projected_fields} 
                  ]

data = climate_col.aggregate(pipeline_stages)  #execute aggregation pipeline
 
for document in data:
    pprint(document)
# Out:
# {'confidence': 68,
#  'datetime': '2023-03-08 04:51:00',
#  'latitude': -37.7885,
#  'longitude': 141.9352,
#  'surface_temperature_celcius': 55}
# {'confidence': 54,
#  'datetime': '2023-03-09 03:57:00',
#  'latitude': -37.7171,
#  'longitude': 147.5866,
#  'surface_temperature_celcius': 44}
# {'confidence': 55,
#  'datetime': '2023-03-10 04:43:00',
#  'latitude': -36.2544,
#  'longitude': 148.0353,
#  'surface_temperature_celcius': 42}
# {'confidence': 54,
#  'datetime': '2023-03-10 04:42:30',
#  'latitude': -37.2197,
#  'longitude': 147.9621,
#  'surface_temperature_celcius': 43}
# {'confidence': 56,
#  'datetime': '2023-03-13 23:58:50',
#  'latitude': -37.0286,
#  'longitude': 148.155,
#  'surface_temperature_celcius': 42}
# {'confidence': 52,
#  'datetime': '2023-03-13 12:57:00',
#  'latitude': -37.0316,
#  'longitude': 148.1519,
#  'surface_temperature_celcius': 35}
# {'confidence': 52,
#  'datetime': '2023-03-15 00:42:50',
#  'latitude': -37.4075,
#  'longitude': 147.0233,
#  'surface_temperature_celcius': 43}
# {'confidence': 66,
#  'datetime': '2023-03-15 00:42:50',
#  'latitude': -37.0228,
#  'longitude': 148.1281,
#  'surface_temperature_celcius': 43}
# {'confidence': 51,
#  'datetime': '2023-03-15 00:42:40',
#  'latitude': -37.002,
#  'longitude': 148.2055,
#  'surface_temperature_celcius': 44}
# {'confidence': 64,
#  'datetime': '2023-03-18 13:16:50',
#  'latitude': -37.4313,
#  'longitude': 147.0343,
#  'surface_temperature_celcius': 37}
# {'confidence': 58,
#  'datetime': '2023-03-19 04:39:20',
#  'latitude': -37.9164,
#  'longitude': 143.4866,
#  'surface_temperature_celcius': 54}
# {'confidence': 63,
#  'datetime': '2023-03-19 04:39:20',
#  'latitude': -37.9257,
#  'longitude': 143.4891,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'datetime': '2023-03-19 04:36:00',
#  'latitude': -37.3982,
#  'longitude': 147.0001,
#  'surface_temperature_celcius': 58}
# {'confidence': 59,
#  'datetime': '2023-03-19 04:35:00',
#  'latitude': -37.4023,
#  'longitude': 147.0394,
#  'surface_temperature_celcius': 56}
# {'confidence': 60,
#  'datetime': '2023-03-19 04:33:50',
#  'latitude': -37.4336,
#  'longitude': 147.0534,
#  'surface_temperature_celcius': 51}
# {'confidence': 61,
#  'datetime': '2023-03-19 04:33:30',
#  'latitude': -37.4003,
#  'longitude': 147.0448,
#  'surface_temperature_celcius': 55}
# {'confidence': 53,
#  'datetime': '2023-03-19 04:33:30',
#  'latitude': -37.9184,
#  'longitude': 143.4745,
#  'surface_temperature_celcius': 55}
# {'confidence': 61,
#  'datetime': '2023-03-19 04:33:10',
#  'latitude': -37.3911,
#  'longitude': 147.037,
#  'surface_temperature_celcius': 50}
# {'confidence': 66,
#  'datetime': '2023-03-19 04:32:50',
#  'latitude': -37.9277,
#  'longitude': 143.477,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'datetime': '2023-03-19 00:12:50',
#  'latitude': -37.3942,
#  'longitude': 147.0455,
#  'surface_temperature_celcius': 44}
# {'confidence': 65,
#  'datetime': '2023-03-24 04:58:00',
#  'latitude': -37.1603,
#  'longitude': 142.8088,
#  'surface_temperature_celcius': 50}
# {'confidence': 55,
#  'datetime': '2023-03-24 04:56:10',
#  'latitude': -37.1684,
#  'longitude': 142.8183,
#  'surface_temperature_celcius': 48}
# {'confidence': 62,
#  'datetime': '2023-03-25 04:03:10',
#  'latitude': -37.8992,
#  'longitude': 143.4534,
#  'surface_temperature_celcius': 54}
# {'confidence': 57,
#  'datetime': '2023-03-25 03:56:40',
#  'latitude': -37.9022,
#  'longitude': 143.4607,
#  'surface_temperature_celcius': 57}
# {'confidence': 68,
#  'datetime': '2023-03-26 04:41:10',
#  'latitude': -38.1131,
#  'longitude': 143.7173,
#  'surface_temperature_celcius': 44}
# {'confidence': 60,
#  'datetime': '2023-03-26 04:39:10',
#  'latitude': -37.8469,
#  'longitude': 143.5343,
#  'surface_temperature_celcius': 50}
# {'confidence': 67,
#  'datetime': '2023-03-26 04:39:10',
#  'latitude': -37.1956,
#  'longitude': 141.0252,
#  'surface_temperature_celcius': 44}
# {'confidence': 53,
#  'datetime': '2023-03-28 04:29:30',
#  'latitude': -37.6195,
#  'longitude': 143.4212,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'datetime': '2023-03-28 04:26:50',
#  'latitude': -37.6376,
#  'longitude': 143.4255,
#  'surface_temperature_celcius': 48}
# {'confidence': 69,
#  'datetime': '2023-03-28 04:26:50',
#  'latitude': -36.4422,
#  'longitude': 141.4172,
#  'surface_temperature_celcius': 46}
# {'confidence': 55,
#  'datetime': '2023-03-28 04:26:50',
#  'latitude': -34.342,
#  'longitude': 141.6548,
#  'surface_temperature_celcius': 54}
# {'confidence': 69,
#  'datetime': '2023-03-29 00:48:40',
#  'latitude': -34.2648,
#  'longitude': 141.6325,
#  'surface_temperature_celcius': 51}
# {'confidence': 68,
#  'datetime': '2023-03-31 04:57:50',
#  'latitude': -36.1649,
#  'longitude': 145.9352,
#  'surface_temperature_celcius': 44}
# {'confidence': 68,
#  'datetime': '2023-03-31 04:57:40',
#  'latitude': -36.0436,
#  'longitude': 145.7964,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'datetime': '2023-03-31 04:57:10',
#  'latitude': -36.7134,
#  'longitude': 145.2151,
#  'surface_temperature_celcius': 38}
# {'confidence': 61,
#  'datetime': '2023-03-31 04:57:10',
#  'latitude': -36.7028,
#  'longitude': 145.2519,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'datetime': '2023-03-31 04:57:10',
#  'latitude': -37.561,
#  'longitude': 143.242,
#  'surface_temperature_celcius': 38}
# {'confidence': 56,
#  'datetime': '2023-03-31 04:57:10',
#  'latitude': -37.982,
#  'longitude': 143.6422,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'datetime': '2023-03-31 00:36:30',
#  'latitude': -34.2568,
#  'longitude': 141.64,
#  'surface_temperature_celcius': 42}
# {'confidence': 58,
#  'datetime': '2023-04-01 04:02:40',
#  'latitude': -36.2044,
#  'longitude': 145.7706,
#  'surface_temperature_celcius': 51}
# {'confidence': 57,
#  'datetime': '2023-04-01 04:02:40',
#  'latitude': -36.5245,
#  'longitude': 143.1556,
#  'surface_temperature_celcius': 43}
# {'confidence': 50,
#  'datetime': '2023-04-01 04:02:40',
#  'latitude': -36.1002,
#  'longitude': 147.6494,
#  'surface_temperature_celcius': 39}
# {'confidence': 60,
#  'datetime': '2023-04-02 04:53:30',
#  'latitude': -36.3872,
#  'longitude': 145.3858,
#  'surface_temperature_celcius': 40}
# {'confidence': 63,
#  'datetime': '2023-04-02 04:45:10',
#  'latitude': -36.494,
#  'longitude': 145.4522,
#  'surface_temperature_celcius': 41}
# {'confidence': 60,
#  'datetime': '2023-04-02 00:24:50',
#  'latitude': -37.324,
#  'longitude': 146.1647,
#  'surface_temperature_celcius': 46}
# {'confidence': 69,
#  'datetime': '2023-04-03 03:53:50',
#  'latitude': -37.8668,
#  'longitude': 143.0472,
#  'surface_temperature_celcius': 44}
# {'confidence': 68,
#  'datetime': '2023-04-03 03:53:40',
#  'latitude': -37.7602,
#  'longitude': 143.382,
#  'surface_temperature_celcius': 44}
# {'confidence': 66,
#  'datetime': '2023-04-03 03:53:30',
#  'latitude': -37.7885,
#  'longitude': 142.9509,
#  'surface_temperature_celcius': 43}
# {'confidence': 66,
#  'datetime': '2023-04-03 03:52:10',
#  'latitude': -37.8717,
#  'longitude': 143.2566,
#  'surface_temperature_celcius': 43}
# {'confidence': 67,
#  'datetime': '2023-04-03 03:51:10',
#  'latitude': -37.8011,
#  'longitude': 144.7343,
#  'surface_temperature_celcius': 44}
# {'confidence': 67,
#  'datetime': '2023-04-03 03:50:50',
#  'latitude': -37.0241,
#  'longitude': 141.5163,
#  'surface_temperature_celcius': 43}
# {'confidence': 66,
#  'datetime': '2023-04-03 03:50:50',
#  'latitude': -37.2912,
#  'longitude': 143.543,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'datetime': '2023-04-03 03:50:50',
#  'latitude': -37.313,
#  'longitude': 146.1561,
#  'surface_temperature_celcius': 46}
# {'confidence': 56,
#  'datetime': '2023-04-03 03:50:50',
#  'latitude': -38.0226,
#  'longitude': 143.6739,
#  'surface_temperature_celcius': 39}
# {'confidence': 56,
#  'datetime': '2023-04-03 03:50:40',
#  'latitude': -37.8089,
#  'longitude': 145.9555,
#  'surface_temperature_celcius': 41}
# {'confidence': 62,
#  'datetime': '2023-04-03 03:50:40',
#  'latitude': -37.9009,
#  'longitude': 143.6217,
#  'surface_temperature_celcius': 45}
# {'confidence': 69,
#  'datetime': '2023-04-03 03:50:40',
#  'latitude': -37.7836,
#  'longitude': 142.9437,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'datetime': '2023-04-03 03:50:40',
#  'latitude': -37.0484,
#  'longitude': 141.6245,
#  'surface_temperature_celcius': 42}
# {'confidence': 68,
#  'datetime': '2023-04-03 03:50:40',
#  'latitude': -36.911,
#  'longitude': 142.1445,
#  'surface_temperature_celcius': 47}
# {'confidence': 67,
#  'datetime': '2023-04-03 01:11:00',
#  'latitude': -34.2536,
#  'longitude': 141.6199,
#  'surface_temperature_celcius': 46}
# {'confidence': 57,
#  'datetime': '2023-04-03 01:07:00',
#  'latitude': -34.2614,
#  'longitude': 141.6412,
#  'surface_temperature_celcius': 43}
# {'confidence': 63,
#  'datetime': '2023-04-04 15:30:40',
#  'latitude': -36.0933,
#  'longitude': 141.7154,
#  'surface_temperature_celcius': 35}
# {'confidence': 64,
#  'datetime': '2023-04-04 04:39:50',
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
# {'confidence': 61,
#  'datetime': '2023-04-04 04:39:40',
#  'latitude': -36.937,
#  'longitude': 142.1176,
#  'surface_temperature_celcius': 50}
# {'confidence': 50,
#  'datetime': '2023-04-04 04:38:10',
#  'latitude': -36.6951,
#  'longitude': 145.424,
#  'surface_temperature_celcius': 43}
# {'confidence': 67,
#  'datetime': '2023-04-04 04:36:30',
#  'latitude': -37.6714,
#  'longitude': 144.2154,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'datetime': '2023-04-04 04:36:30',
#  'latitude': -38.0494,
#  'longitude': 143.9141,
#  'surface_temperature_celcius': 58}
# {'confidence': 54,
#  'datetime': '2023-04-04 04:34:20',
#  'latitude': -38.4879,
#  'longitude': 143.9971,
#  'surface_temperature_celcius': 40}
# {'confidence': 63,
#  'datetime': '2023-04-04 04:33:30',
#  'latitude': -37.1744,
#  'longitude': 143.9256,
#  'surface_temperature_celcius': 43}
# {'confidence': 69,
#  'datetime': '2023-04-04 04:33:30',
#  'latitude': -36.4918,
#  'longitude': 142.2465,
#  'surface_temperature_celcius': 54}
# {'confidence': 66,
#  'datetime': '2023-04-04 04:33:10',
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
# {'confidence': 53,
#  'datetime': '2023-04-04 04:33:10',
#  'latitude': -36.1439,
#  'longitude': 145.832,
#  'surface_temperature_celcius': 50}
# {'confidence': 54,
#  'datetime': '2023-04-04 04:32:50',
#  'latitude': -36.7009,
#  'longitude': 141.541,
#  'surface_temperature_celcius': 49}
# {'confidence': 55,
#  'datetime': '2023-04-04 04:32:40',
#  'latitude': -36.4611,
#  'longitude': 143.146,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'datetime': '2023-04-04 04:32:40',
#  'latitude': -36.3539,
#  'longitude': 142.1894,
#  'surface_temperature_celcius': 53}
# {'confidence': 66,
#  'datetime': '2023-04-04 04:32:40',
#  'latitude': -37.0081,
#  'longitude': 141.7654,
#  'surface_temperature_celcius': 62}
# {'confidence': 64,
#  'datetime': '2023-04-04 04:32:40',
#  'latitude': -36.2889,
#  'longitude': 141.7692,
#  'surface_temperature_celcius': 51}
# {'confidence': 67,
#  'datetime': '2023-04-04 04:32:40',
#  'latitude': -36.6228,
#  'longitude': 142.428,
#  'surface_temperature_celcius': 43}
# {'confidence': 60,
#  'datetime': '2023-04-04 04:32:40',
#  'latitude': -38.1177,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 40}
# {'confidence': 61,
#  'datetime': '2023-04-05 13:10:10',
#  'latitude': -38.3499,
#  'longitude': 147.033,
#  'surface_temperature_celcius': 35}
# {'confidence': 66,
#  'datetime': '2023-04-05 13:02:40',
#  'latitude': -37.6435,
#  'longitude': 146.1417,
#  'surface_temperature_celcius': 36}
# {'confidence': 66,
#  'datetime': '2023-04-05 05:15:40',
#  'latitude': -37.7522,
#  'longitude': 142.3183,
#  'surface_temperature_celcius': 50}
# {'confidence': 66,
#  'datetime': '2023-04-05 05:15:30',
#  'latitude': -36.9396,
#  'longitude': 141.9303,
#  'surface_temperature_celcius': 45}
# {'confidence': 65,
#  'datetime': '2023-04-05 03:45:10',
#  'latitude': -37.78,
#  'longitude': 141.8091,
#  'surface_temperature_celcius': 42}
# {'confidence': 68,
#  'datetime': '2023-04-05 03:44:40',
#  'latitude': -37.7767,
#  'longitude': 141.8127,
#  'surface_temperature_celcius': 44}
# {'confidence': 65,
#  'datetime': '2023-04-05 03:44:30',
#  'latitude': -38.1756,
#  'longitude': 143.9829,
#  'surface_temperature_celcius': 53}
# {'confidence': 50,
#  'datetime': '2023-04-05 03:40:30',
#  'latitude': -38.3553,
#  'longitude': 147.0231,
#  'surface_temperature_celcius': 38}
# {'confidence': 64,
#  'datetime': '2023-04-05 03:40:30',
#  'latitude': -36.934,
#  'longitude': 142.5759,
#  'surface_temperature_celcius': 47}
# {'confidence': 59,
#  'datetime': '2023-04-05 03:39:10',
#  'latitude': -38.0383,
#  'longitude': 144.4307,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'datetime': '2023-04-05 03:39:10',
#  'latitude': -36.9354,
#  'longitude': 142.5807,
#  'surface_temperature_celcius': 45}
# {'confidence': 68,
#  'datetime': '2023-04-05 03:39:10',
#  'latitude': -36.9405,
#  'longitude': 142.8627,
#  'surface_temperature_celcius': 44}
# {'confidence': 69,
#  'datetime': '2023-04-05 03:39:10',
#  'latitude': -37.6339,
#  'longitude': 143.4108,
#  'surface_temperature_celcius': 46}
# {'confidence': 66,
#  'datetime': '2023-04-06 04:25:40',
#  'latitude': -37.7069,
#  'longitude': 142.1573,
#  'surface_temperature_celcius': 53}
# {'confidence': 50,
#  'datetime': '2023-04-06 04:25:40',
#  'latitude': -36.0834,
#  'longitude': 146.5364,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'datetime': '2023-04-06 04:23:50',
#  'latitude': -36.3557,
#  'longitude': 141.3268,
#  'surface_temperature_celcius': 52}
# {'confidence': 62,
#  'datetime': '2023-04-06 04:23:50',
#  'latitude': -37.6104,
#  'longitude': 147.8367,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'datetime': '2023-04-06 04:23:50',
#  'latitude': -37.9229,
#  'longitude': 143.647,
#  'surface_temperature_celcius': 63}
# {'confidence': 62,
#  'datetime': '2023-04-06 04:23:50',
#  'latitude': -37.5052,
#  'longitude': 142.8636,
#  'surface_temperature_celcius': 54}
# {'confidence': 51,
#  'datetime': '2023-04-06 04:22:20',
#  'latitude': -37.8177,
#  'longitude': 142.9168,
#  'surface_temperature_celcius': 50}
# {'confidence': 65,
#  'datetime': '2023-04-06 04:21:20',
#  'latitude': -37.5842,
#  'longitude': 148.5717,
#  'surface_temperature_celcius': 49}
# {'confidence': 64,
#  'datetime': '2023-04-06 04:21:00',
#  'latitude': -38.0089,
#  'longitude': 143.8976,
#  'surface_temperature_celcius': 45}
# {'confidence': 58,
#  'datetime': '2023-04-06 04:21:00',
#  'latitude': -37.3072,
#  'longitude': 147.5003,
#  'surface_temperature_celcius': 46}
# {'confidence': 50,
#  'datetime': '2023-04-06 04:20:50',
#  'latitude': -37.3556,
#  'longitude': 146.1085,
#  'surface_temperature_celcius': 47}
# {'confidence': 59,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -37.6806,
#  'longitude': 143.2676,
#  'surface_temperature_celcius': 51}
# {'confidence': 58,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -37.7212,
#  'longitude': 145.9754,
#  'surface_temperature_celcius': 52}
# {'confidence': 59,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -38.3343,
#  'longitude': 143.8644,
#  'surface_temperature_celcius': 43}
# {'confidence': 64,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -35.723,
#  'longitude': 142.063,
#  'surface_temperature_celcius': 54}
# {'confidence': 50,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -35.1383,
#  'longitude': 141.8172,
#  'surface_temperature_celcius': 53}
# {'confidence': 52,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -36.4133,
#  'longitude': 141.0286,
#  'surface_temperature_celcius': 47}
# {'confidence': 66,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -36.6492,
#  'longitude': 142.3976,
#  'surface_temperature_celcius': 60}
# {'confidence': 69,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -36.0765,
#  'longitude': 146.4896,
#  'surface_temperature_celcius': 46}
# {'confidence': 57,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -36.0799,
#  'longitude': 146.529,
#  'surface_temperature_celcius': 44}
# {'confidence': 60,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -36.8632,
#  'longitude': 142.5802,
#  'surface_temperature_celcius': 60}
# {'confidence': 59,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -37.1929,
#  'longitude': 143.8132,
#  'surface_temperature_celcius': 45}
# {'confidence': 68,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -37.1992,
#  'longitude': 146.2301,
#  'surface_temperature_celcius': 60}
# {'confidence': 63,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -37.5914,
#  'longitude': 148.5807,
#  'surface_temperature_celcius': 61}
# {'confidence': 64,
#  'datetime': '2023-04-06 04:20:40',
#  'latitude': -37.7496,
#  'longitude': 148.3898,
#  'surface_temperature_celcius': 46}
# {'confidence': 67,
#  'datetime': '2023-04-06 00:03:50',
#  'latitude': -35.4625,
#  'longitude': 143.1486,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'datetime': '2023-04-06 00:01:40',
#  'latitude': -38.0942,
#  'longitude': 146.9603,
#  'surface_temperature_celcius': 39}
# {'confidence': 61,
#  'datetime': '2023-04-07 12:53:40',
#  'latitude': -35.6961,
#  'longitude': 143.1935,
#  'surface_temperature_celcius': 35}
# {'confidence': 65,
#  'datetime': '2023-04-07 12:52:10',
#  'latitude': -37.3314,
#  'longitude': 149.1283,
#  'surface_temperature_celcius': 35}
# {'confidence': 51,
#  'datetime': '2023-04-07 12:51:20',
#  'latitude': -37.3359,
#  'longitude': 149.3816,
#  'surface_temperature_celcius': 48}
# {'confidence': 66,
#  'datetime': '2023-04-07 12:51:00',
#  'latitude': -37.3526,
#  'longitude': 149.3972,
#  'surface_temperature_celcius': 43}
# {'confidence': 68,
#  'datetime': '2023-04-07 12:50:40',
#  'latitude': -37.3344,
#  'longitude': 149.3933,
#  'surface_temperature_celcius': 47}
# {'confidence': 61,
#  'datetime': '2023-04-07 12:50:40',
#  'latitude': -37.3511,
#  'longitude': 149.4088,
#  'surface_temperature_celcius': 46}
# {'confidence': 66,
#  'datetime': '2023-04-07 12:50:40',
#  'latitude': -36.7508,
#  'longitude': 147.1254,
#  'surface_temperature_celcius': 39}
# {'confidence': 63,
#  'datetime': '2023-04-07 05:03:10',
#  'latitude': -36.1031,
#  'longitude': 143.0782,
#  'surface_temperature_celcius': 45}
# {'confidence': 66,
#  'datetime': '2023-04-07 05:03:10',
#  'latitude': -36.1025,
#  'longitude': 143.0825,
#  'surface_temperature_celcius': 43}
# {'confidence': 67,
#  'datetime': '2023-04-07 05:03:10',
#  'latitude': -36.7314,
#  'longitude': 141.8698,
#  'surface_temperature_celcius': 44}
# {'confidence': 64,
#  'datetime': '2023-04-07 03:31:40',
#  'latitude': -37.7931,
#  'longitude': 148.385,
#  'surface_temperature_celcius': 58}
# {'confidence': 60,
#  'datetime': '2023-04-07 03:27:50',
#  'latitude': -37.7974,
#  'longitude': 148.5498,
#  'surface_temperature_celcius': 53}
# {'confidence': 67,
#  'datetime': '2023-04-08 04:15:20',
#  'latitude': -37.34,
#  'longitude': 149.3668,
#  'surface_temperature_celcius': 74}
# {'confidence': 62,
#  'datetime': '2023-04-08 04:14:40',
#  'latitude': -37.8567,
#  'longitude': 147.1576,
#  'surface_temperature_celcius': 48}
# {'confidence': 56,
#  'datetime': '2023-04-08 04:12:20',
#  'latitude': -37.4368,
#  'longitude': 149.1191,
#  'surface_temperature_celcius': 52}
# {'confidence': 58,
#  'datetime': '2023-04-08 04:11:40',
#  'latitude': -37.9408,
#  'longitude': 146.0611,
#  'surface_temperature_celcius': 47}
# {'confidence': 59,
#  'datetime': '2023-04-08 04:09:20',
#  'latitude': -37.6994,
#  'longitude': 146.2162,
#  'surface_temperature_celcius': 40}
# {'confidence': 63,
#  'datetime': '2023-04-08 04:08:50',
#  'latitude': -36.7199,
#  'longitude': 142.5844,
#  'surface_temperature_celcius': 56}
# {'confidence': 66,
#  'datetime': '2023-04-08 04:08:40',
#  'latitude': -37.3493,
#  'longitude': 149.3691,
#  'surface_temperature_celcius': 80}
# {'confidence': 61,
#  'datetime': '2023-04-08 04:08:40',
#  'latitude': -37.6447,
#  'longitude': 148.6039,
#  'surface_temperature_celcius': 50}
# {'confidence': 67,
#  'datetime': '2023-04-11 04:50:20',
#  'latitude': -36.2282,
#  'longitude': 145.9074,
#  'surface_temperature_celcius': 43}
# {'confidence': 53,
#  'datetime': '2023-04-11 04:42:10',
#  'latitude': -36.3499,
#  'longitude': 146.1402,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'datetime': '2023-04-11 04:40:30',
#  'latitude': -36.4439,
#  'longitude': 145.8846,
#  'surface_temperature_celcius': 39}
# {'confidence': 57,
#  'datetime': '2023-04-11 04:39:40',
#  'latitude': -36.0818,
#  'longitude': 146.5461,
#  'surface_temperature_celcius': 44}
# {'confidence': 50,
#  'datetime': '2023-04-11 04:38:50',
#  'latitude': -36.343,
#  'longitude': 143.3479,
#  'surface_temperature_celcius': 40}
# {'confidence': 67,
#  'datetime': '2023-04-11 04:38:50',
#  'latitude': -36.1751,
#  'longitude': 142.7831,
#  'surface_temperature_celcius': 43}
# {'confidence': 55,
#  'datetime': '2023-04-11 04:38:50',
#  'latitude': -36.4606,
#  'longitude': 141.0562,
#  'surface_temperature_celcius': 39}
# {'confidence': 66,
#  'datetime': '2023-04-11 04:38:50',
#  'latitude': -36.0156,
#  'longitude': 143.2188,
#  'surface_temperature_celcius': 43}
# {'confidence': 62,
#  'datetime': '2023-04-11 04:38:50',
#  'latitude': -36.1398,
#  'longitude': 141.7793,
#  'surface_temperature_celcius': 47}
# {'confidence': 68,
#  'datetime': '2023-04-11 04:38:50',
#  'latitude': -35.2068,
#  'longitude': 143.2912,
#  'surface_temperature_celcius': 44}
# {'confidence': 63,
#  'datetime': '2023-04-11 04:38:50',
#  'latitude': -36.3579,
#  'longitude': 146.1268,
#  'surface_temperature_celcius': 42}
# {'confidence': 60,
#  'datetime': '2023-04-11 04:38:50',
#  'latitude': -36.0787,
#  'longitude': 146.5728,
#  'surface_temperature_celcius': 40}
# {'confidence': 62,
#  'datetime': '2023-04-11 00:20:30',
#  'latitude': -37.9796,
#  'longitude': 146.8024,
#  'surface_temperature_celcius': 41}
# {'confidence': 67,
#  'datetime': '2023-04-12 13:13:10',
#  'latitude': -35.4309,
#  'longitude': 142.3626,
#  'surface_temperature_celcius': 36}
# {'confidence': 57,
#  'datetime': '2023-04-12 13:09:20',
#  'latitude': -35.4407,
#  'longitude': 142.3644,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'datetime': '2023-04-12 05:28:00',
#  'latitude': -37.4755,
#  'longitude': 142.6339,
#  'surface_temperature_celcius': 43}
# {'confidence': 54,
#  'datetime': '2023-04-12 05:26:50',
#  'latitude': -36.7453,
#  'longitude': 141.4578,
#  'surface_temperature_celcius': 39}
# {'confidence': 50,
#  'datetime': '2023-04-12 05:25:00',
#  'latitude': -36.7038,
#  'longitude': 141.0498,
#  'surface_temperature_celcius': 39}
# {'confidence': 60,
#  'datetime': '2023-04-12 05:21:50',
#  'latitude': -37.7578,
#  'longitude': 142.227,
#  'surface_temperature_celcius': 40}
# {'confidence': 67,
#  'datetime': '2023-04-12 05:21:40',
#  'latitude': -36.8083,
#  'longitude': 142.0219,
#  'surface_temperature_celcius': 44}
# {'confidence': 61,
#  'datetime': '2023-04-12 05:21:40',
#  'latitude': -36.714,
#  'longitude': 141.1485,
#  'surface_temperature_celcius': 41}
# {'confidence': 68,
#  'datetime': '2023-04-12 03:51:00',
#  'latitude': -36.6385,
#  'longitude': 142.5297,
#  'surface_temperature_celcius': 44}
# {'confidence': 59,
#  'datetime': '2023-04-12 03:50:10',
#  'latitude': -36.9179,
#  'longitude': 141.3095,
#  'surface_temperature_celcius': 40}
# {'confidence': 65,
#  'datetime': '2023-04-12 03:46:50',
#  'latitude': -37.3654,
#  'longitude': 143.8156,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'datetime': '2023-04-12 03:46:20',
#  'latitude': -36.6188,
#  'longitude': 144.0402,
#  'surface_temperature_celcius': 44}
# {'confidence': 69,
#  'datetime': '2023-04-12 03:46:00',
#  'latitude': -37.4047,
#  'longitude': 143.6615,
#  'surface_temperature_celcius': 45}
# {'confidence': 65,
#  'datetime': '2023-04-12 03:46:00',
#  'latitude': -36.2367,
#  'longitude': 141.3998,
#  'surface_temperature_celcius': 42}
# {'confidence': 62,
#  'datetime': '2023-04-12 03:45:10',
#  'latitude': -36.5234,
#  'longitude': 144.6939,
#  'surface_temperature_celcius': 41}
# {'confidence': 60,
#  'datetime': '2023-04-12 03:45:00',
#  'latitude': -36.6803,
#  'longitude': 141.0957,
#  'surface_temperature_celcius': 44}
# {'confidence': 65,
#  'datetime': '2023-04-12 03:44:50',
#  'latitude': -36.7866,
#  'longitude': 142.1989,
#  'surface_temperature_celcius': 42}
# {'confidence': 65,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -36.6292,
#  'longitude': 143.8862,
#  'surface_temperature_celcius': 43}
# {'confidence': 68,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -35.7937,
#  'longitude': 143.195,
#  'surface_temperature_celcius': 44}
# {'confidence': 57,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -36.9142,
#  'longitude': 141.3013,
#  'surface_temperature_celcius': 40}
# {'confidence': 68,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -36.6306,
#  'longitude': 143.8908,
#  'surface_temperature_celcius': 44}
# {'confidence': 59,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -37.3586,
#  'longitude': 142.9087,
#  'surface_temperature_celcius': 40}
# {'confidence': 60,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -36.9524,
#  'longitude': 143.7501,
#  'surface_temperature_celcius': 40}
# {'confidence': 50,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -37.0643,
#  'longitude': 141.8567,
#  'surface_temperature_celcius': 40}
# {'confidence': 64,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -36.2403,
#  'longitude': 141.4047,
#  'surface_temperature_celcius': 42}
# {'confidence': 56,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -36.6776,
#  'longitude': 141.0877,
#  'surface_temperature_celcius': 44}
# {'confidence': 64,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -37.7929,
#  'longitude': 143.1197,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -37.7972,
#  'longitude': 143.1153,
#  'surface_temperature_celcius': 42}
# {'confidence': 59,
#  'datetime': '2023-04-12 03:44:40',
#  'latitude': -37.3656,
#  'longitude': 143.8206,
#  'surface_temperature_celcius': 40}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:36:30',
#  'latitude': -37.8865,
#  'longitude': 143.3048,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:36:20',
#  'latitude': -37.5687,
#  'longitude': 143.2121,
#  'surface_temperature_celcius': 41}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:34:50',
#  'latitude': -37.7359,
#  'longitude': 143.0108,
#  'surface_temperature_celcius': 44}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:33:50',
#  'latitude': -37.1009,
#  'longitude': 141.9666,
#  'surface_temperature_celcius': 45}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:33:50',
#  'latitude': -36.9211,
#  'longitude': 143.6017,
#  'surface_temperature_celcius': 44}
# {'confidence': 64,
#  'datetime': '2023-04-13 04:33:30',
#  'latitude': -38.211,
#  'longitude': 143.9122,
#  'surface_temperature_celcius': 42}
# {'confidence': 59,
#  'datetime': '2023-04-13 04:33:30',
#  'latitude': -37.7576,
#  'longitude': 142.465,
#  'surface_temperature_celcius': 40}
# {'confidence': 57,
#  'datetime': '2023-04-13 04:33:20',
#  'latitude': -38.0505,
#  'longitude': 142.4791,
#  'surface_temperature_celcius': 40}
# {'confidence': 52,
#  'datetime': '2023-04-13 04:33:10',
#  'latitude': -37.7851,
#  'longitude': 141.4593,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:33:10',
#  'latitude': -37.9075,
#  'longitude': 142.6403,
#  'surface_temperature_celcius': 41}
# {'confidence': 50,
#  'datetime': '2023-04-13 04:33:10',
#  'latitude': -37.8345,
#  'longitude': 142.447,
#  'surface_temperature_celcius': 38}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:31:30',
#  'latitude': -36.8573,
#  'longitude': 143.5278,
#  'surface_temperature_celcius': 45}
# {'confidence': 63,
#  'datetime': '2023-04-13 04:29:50',
#  'latitude': -37.0207,
#  'longitude': 141.4778,
#  'surface_temperature_celcius': 41}
# {'confidence': 59,
#  'datetime': '2023-04-13 04:29:40',
#  'latitude': -37.6857,
#  'longitude': 142.8532,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:29:40',
#  'latitude': -37.2709,
#  'longitude': 143.9659,
#  'surface_temperature_celcius': 45}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:29:40',
#  'latitude': -37.5632,
#  'longitude': 142.2864,
#  'surface_temperature_celcius': 45}
# {'confidence': 65,
#  'datetime': '2023-04-13 04:29:30',
#  'latitude': -36.3305,
#  'longitude': 146.049,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:29:20',
#  'latitude': -38.0132,
#  'longitude': 143.2528,
#  'surface_temperature_celcius': 44}
# {'confidence': 57,
#  'datetime': '2023-04-13 04:28:30',
#  'latitude': -38.0643,
#  'longitude': 143.6616,
#  'surface_temperature_celcius': 43}
# {'confidence': 67,
#  'datetime': '2023-04-13 04:28:30',
#  'latitude': -37.9898,
#  'longitude': 143.8507,
#  'surface_temperature_celcius': 43}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:28:10',
#  'latitude': -37.0667,
#  'longitude': 143.0582,
#  'surface_temperature_celcius': 44}
# {'confidence': 60,
#  'datetime': '2023-04-13 04:27:40',
#  'latitude': -37.7836,
#  'longitude': 141.4711,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:27:30',
#  'latitude': -36.778,
#  'longitude': 145.1635,
#  'surface_temperature_celcius': 45}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:27:20',
#  'latitude': -37.6008,
#  'longitude': 143.0558,
#  'surface_temperature_celcius': 44}
# {'confidence': 63,
#  'datetime': '2023-04-13 04:26:50',
#  'latitude': -37.2757,
#  'longitude': 143.8126,
#  'surface_temperature_celcius': 42}
# {'confidence': 58,
#  'datetime': '2023-04-13 04:26:40',
#  'latitude': -38.26,
#  'longitude': 143.9602,
#  'surface_temperature_celcius': 40}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:26:40',
#  'latitude': -37.9916,
#  'longitude': 143.8392,
#  'surface_temperature_celcius': 44}
# {'confidence': 61,
#  'datetime': '2023-04-13 04:26:40',
#  'latitude': -37.7635,
#  'longitude': 142.8181,
#  'surface_temperature_celcius': 41}
# {'confidence': 53,
#  'datetime': '2023-04-13 04:26:40',
#  'latitude': -37.7982,
#  'longitude': 142.2386,
#  'surface_temperature_celcius': 41}
# {'confidence': 66,
#  'datetime': '2023-04-13 04:26:40',
#  'latitude': -37.4391,
#  'longitude': 143.0293,
#  'surface_temperature_celcius': 43}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:26:40',
#  'latitude': -37.6161,
#  'longitude': 141.2781,
#  'surface_temperature_celcius': 45}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.6777,
#  'longitude': 141.37,
#  'surface_temperature_celcius': 49}
# {'confidence': 61,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.6701,
#  'longitude': 141.3566,
#  'surface_temperature_celcius': 50}
# {'confidence': 67,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.4373,
#  'longitude': 143.6328,
#  'surface_temperature_celcius': 43}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.4392,
#  'longitude': 144.2111,
#  'surface_temperature_celcius': 44}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.3275,
#  'longitude': 145.5876,
#  'surface_temperature_celcius': 44}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.9875,
#  'longitude': 141.9298,
#  'surface_temperature_celcius': 44}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.7754,
#  'longitude': 143.5261,
#  'surface_temperature_celcius': 44}
# {'confidence': 61,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.2054,
#  'longitude': 141.1083,
#  'surface_temperature_celcius': 41}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.1089,
#  'longitude': 141.8394,
#  'surface_temperature_celcius': 42}
# {'confidence': 66,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.7804,
#  'longitude': 145.1698,
#  'surface_temperature_celcius': 45}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.1949,
#  'longitude': 142.675,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.4784,
#  'longitude': 143.015,
#  'surface_temperature_celcius': 47}
# {'confidence': 66,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.5358,
#  'longitude': 143.0572,
#  'surface_temperature_celcius': 43}
# {'confidence': 59,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.5077,
#  'longitude': 143.2495,
#  'surface_temperature_celcius': 40}
# {'confidence': 57,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.5389,
#  'longitude': 143.1632,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.7037,
#  'longitude': 142.3299,
#  'surface_temperature_celcius': 41}
# {'confidence': 59,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.5837,
#  'longitude': 144.1565,
#  'surface_temperature_celcius': 40}
# {'confidence': 61,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.9158,
#  'longitude': 141.9147,
#  'surface_temperature_celcius': 41}
# {'confidence': 61,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.9143,
#  'longitude': 141.9264,
#  'surface_temperature_celcius': 41}
# {'confidence': 67,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.7862,
#  'longitude': 142.9823,
#  'surface_temperature_celcius': 43}
# {'confidence': 61,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.7416,
#  'longitude': 143.2885,
#  'surface_temperature_celcius': 41}
# {'confidence': 69,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.8131,
#  'longitude': 143.1175,
#  'surface_temperature_celcius': 45}
# {'confidence': 63,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.8759,
#  'longitude': 143.3141,
#  'surface_temperature_celcius': 45}
# {'confidence': 51,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.9359,
#  'longitude': 143.3468,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.9309,
#  'longitude': 143.381,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -34.5442,
#  'longitude': 141.7211,
#  'surface_temperature_celcius': 52}
# {'confidence': 53,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -37.9422,
#  'longitude': 143.6199,
#  'surface_temperature_celcius': 39}
# {'confidence': 63,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -35.2791,
#  'longitude': 142.5659,
#  'surface_temperature_celcius': 49}
# {'confidence': 68,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -38.219,
#  'longitude': 143.7352,
#  'surface_temperature_celcius': 44}
# {'confidence': 57,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -38.2093,
#  'longitude': 143.9237,
#  'surface_temperature_celcius': 40}
# {'confidence': 54,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -35.7608,
#  'longitude': 143.3545,
#  'surface_temperature_celcius': 47}
# {'confidence': 62,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -38.2583,
#  'longitude': 143.9717,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'datetime': '2023-04-13 04:26:30',
#  'latitude': -36.6843,
#  'longitude': 141.5899,
#  'surface_temperature_celcius': 43}
# {'confidence': 64,
#  'datetime': '2023-04-13 00:14:50',
#  'latitude': -35.2465,
#  'longitude': 143.4426,
#  'surface_temperature_celcius': 42}
# {'confidence': 58,
#  'datetime': '2023-04-13 00:08:50',
#  'latitude': -35.2432,
#  'longitude': 143.4496,
#  'surface_temperature_celcius': 44}
# {'confidence': 65,
#  'datetime': '2023-04-13 00:07:00',
#  'latitude': -34.5396,
#  'longitude': 141.7292,
#  'surface_temperature_celcius': 43}
# {'confidence': 63,
#  'datetime': '2023-04-13 00:07:00',
#  'latitude': -34.532,
#  'longitude': 141.7257,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'datetime': '2023-04-14 05:09:10',
#  'latitude': -36.3414,
#  'longitude': 141.0295,
#  'surface_temperature_celcius': 42}
# {'confidence': 65,
#  'datetime': '2023-04-14 00:49:30',
#  'latitude': -36.0902,
#  'longitude': 143.8394,
#  'surface_temperature_celcius': 42}
# {'confidence': 66,
#  'datetime': '2023-04-15 04:24:00',
#  'latitude': -36.5049,
#  'longitude': 143.775,
#  'surface_temperature_celcius': 43}
# {'confidence': 67,
#  'datetime': '2023-04-15 04:20:40',
#  'latitude': -36.8254,
#  'longitude': 143.5602,
#  'surface_temperature_celcius': 47}
# {'confidence': 69,
#  'datetime': '2023-04-15 04:20:40',
#  'latitude': -36.6589,
#  'longitude': 141.2755,
#  'surface_temperature_celcius': 48}
# {'confidence': 68,
#  'datetime': '2023-04-15 04:20:40',
#  'latitude': -37.0038,
#  'longitude': 142.1629,
#  'surface_temperature_celcius': 44}
# {'confidence': 66,
#  'datetime': '2023-04-15 04:17:40',
#  'latitude': -36.1586,
#  'longitude': 146.3329,
#  'surface_temperature_celcius': 43}
# {'confidence': 66,
#  'datetime': '2023-04-15 04:17:30',
#  'latitude': -36.8004,
#  'longitude': 142.4415,
#  'surface_temperature_celcius': 52}
# {'confidence': 64,
#  'datetime': '2023-04-15 04:17:30',
#  'latitude': -36.8377,
#  'longitude': 143.4624,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'datetime': '2023-04-15 04:16:00',
#  'latitude': -36.798,
#  'longitude': 142.4482,
#  'surface_temperature_celcius': 44}
# {'confidence': 65,
#  'datetime': '2023-04-15 04:15:40',
#  'latitude': -36.6833,
#  'longitude': 142.8296,
#  'surface_temperature_celcius': 42}
# {'confidence': 68,
#  'datetime': '2023-04-15 04:15:30',
#  'latitude': -36.1401,
#  'longitude': 146.0217,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'datetime': '2023-04-15 04:15:10',
#  'latitude': -36.3489,
#  'longitude': 145.3342,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'datetime': '2023-04-15 04:14:20',
#  'latitude': -36.6599,
#  'longitude': 144.6129,
#  'surface_temperature_celcius': 44}
# {'confidence': 59,
#  'datetime': '2023-04-15 04:14:20',
#  'latitude': -37.1228,
#  'longitude': 141.7389,
#  'surface_temperature_celcius': 41}
# {'confidence': 67,
#  'datetime': '2023-04-15 04:14:20',
#  'latitude': -36.7315,
#  'longitude': 143.9232,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'datetime': '2023-04-15 04:14:20',
#  'latitude': -37.8937,
#  'longitude': 147.1785,
#  'surface_temperature_celcius': 38}
# {'confidence': 63,
#  'datetime': '2023-04-15 04:14:20',
#  'latitude': -36.1937,
#  'longitude': 143.5674,
#  'surface_temperature_celcius': 41}
# {'confidence': 55,
#  'datetime': '2023-04-16 04:58:30',
#  'latitude': -37.2904,
#  'longitude': 143.9209,
#  'surface_temperature_celcius': 39}
# {'confidence': 58,
#  'datetime': '2023-04-16 04:57:40',
#  'latitude': -37.0459,
#  'longitude': 142.7207,
#  'surface_temperature_celcius': 40}
# {'confidence': 50,
#  'datetime': '2023-04-16 04:57:20',
#  'latitude': -36.7194,
#  'longitude': 143.5593,
#  'surface_temperature_celcius': 38}
# {'confidence': 63,
#  'datetime': '2023-04-16 04:56:50',
#  'latitude': -36.2938,
#  'longitude': 145.6237,
#  'surface_temperature_celcius': 42}
# {'confidence': 66,
#  'datetime': '2023-04-16 04:56:50',
#  'latitude': -36.7354,
#  'longitude': 141.7577,
#  'surface_temperature_celcius': 43}
# {'confidence': 65,
#  'datetime': '2023-04-16 04:56:50',
#  'latitude': -36.3588,
#  'longitude': 141.5272,
#  'surface_temperature_celcius': 42}
# {'confidence': 52,
#  'datetime': '2023-04-16 00:42:40',
#  'latitude': -37.3723,
#  'longitude': 143.8406,
#  'surface_temperature_celcius': 42}
# {'confidence': 55,
#  'datetime': '2023-04-16 00:36:40',
#  'latitude': -36.7001,
#  'longitude': 141.7567,
#  'surface_temperature_celcius': 39}
# {'confidence': 63,
#  'datetime': '2023-04-17 04:12:10',
#  'latitude': -37.0669,
#  'longitude': 145.3677,
#  'surface_temperature_celcius': 42}
# {'confidence': 62,
#  'datetime': '2023-04-17 04:05:20',
#  'latitude': -34.8295,
#  'longitude': 143.179,
#  'surface_temperature_celcius': 53}
# {'confidence': 62,
#  'datetime': '2023-04-17 04:05:20',
#  'latitude': -36.7721,
#  'longitude': 142.4219,
#  'surface_temperature_celcius': 46}
# {'confidence': 67,
#  'datetime': '2023-04-17 04:05:10',
#  'latitude': -36.3269,
#  'longitude': 144.0871,
#  'surface_temperature_celcius': 43}
# {'confidence': 61,
#  'datetime': '2023-04-17 04:03:10',
#  'latitude': -36.8975,
#  'longitude': 141.0971,
#  'surface_temperature_celcius': 43}
# {'confidence': 56,
#  'datetime': '2023-04-17 04:03:10',
#  'latitude': -37.0685,
#  'longitude': 145.354,
#  'surface_temperature_celcius': 39}
# {'confidence': 58,
#  'datetime': '2023-04-17 04:02:30',
#  'latitude': -36.4437,
#  'longitude': 141.5916,
#  'surface_temperature_celcius': 45}
# {'confidence': 53,
#  'datetime': '2023-04-17 04:02:20',
#  'latitude': -37.7504,
#  'longitude': 142.1373,
#  'surface_temperature_celcius': 39}
# {'confidence': 63,
#  'datetime': '2023-04-17 04:02:20',
#  'latitude': -36.5233,
#  'longitude': 146.7436,
#  'surface_temperature_celcius': 42}
# {'confidence': 55,
#  'datetime': '2023-04-17 04:02:20',
#  'latitude': -37.9378,
#  'longitude': 142.541,
#  'surface_temperature_celcius': 39}
# {'confidence': 58,
#  'datetime': '2023-04-17 04:02:20',
#  'latitude': -36.0434,
#  'longitude': 143.1899,
#  'surface_temperature_celcius': 40}
# {'confidence': 68,
#  'datetime': '2023-04-17 04:02:20',
#  'latitude': -37.1396,
#  'longitude': 141.9328,
#  'surface_temperature_celcius': 44}
# {'confidence': 65,
#  'datetime': '2023-04-17 01:22:10',
#  'latitude': -36.4333,
#  'longitude': 141.5977,
#  'surface_temperature_celcius': 43}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:57:10',
#  'latitude': -36.9654,
#  'longitude': 140.981,
#  'surface_temperature_celcius': 44}
# {'confidence': 68,
#  'datetime': '2023-04-18 04:56:30',
#  'latitude': -38.0631,
#  'longitude': 143.6433,
#  'surface_temperature_celcius': 46}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:54:40',
#  'latitude': -37.4022,
#  'longitude': 143.2016,
#  'surface_temperature_celcius': 45}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:54:40',
#  'latitude': -36.4469,
#  'longitude': 142.4565,
#  'surface_temperature_celcius': 45}
# {'confidence': 58,
#  'datetime': '2023-04-18 04:54:20',
#  'latitude': -37.7893,
#  'longitude': 142.7953,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:54:00',
#  'latitude': -37.0135,
#  'longitude': 143.5822,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'datetime': '2023-04-18 04:53:20',
#  'latitude': -37.4983,
#  'longitude': 145.55,
#  'surface_temperature_celcius': 48}
# {'confidence': 66,
#  'datetime': '2023-04-18 04:51:50',
#  'latitude': -36.7422,
#  'longitude': 141.8511,
#  'surface_temperature_celcius': 48}
# {'confidence': 55,
#  'datetime': '2023-04-18 04:51:40',
#  'latitude': -37.579,
#  'longitude': 144.1483,
#  'surface_temperature_celcius': 39}
# {'confidence': 63,
#  'datetime': '2023-04-18 04:51:30',
#  'latitude': -36.807,
#  'longitude': 144.3933,
#  'surface_temperature_celcius': 41}
# {'confidence': 68,
#  'datetime': '2023-04-18 04:51:30',
#  'latitude': -34.9057,
#  'longitude': 142.0623,
#  'surface_temperature_celcius': 51}
# {'confidence': 66,
#  'datetime': '2023-04-18 04:51:30',
#  'latitude': -37.9881,
#  'longitude': 143.5436,
#  'surface_temperature_celcius': 43}
# {'confidence': 68,
#  'datetime': '2023-04-18 04:51:20',
#  'latitude': -37.136,
#  'longitude': 141.7239,
#  'surface_temperature_celcius': 44}
# {'confidence': 59,
#  'datetime': '2023-04-18 04:49:00',
#  'latitude': -35.7866,
#  'longitude': 143.4796,
#  'surface_temperature_celcius': 46}
# {'confidence': 57,
#  'datetime': '2023-04-18 04:49:00',
#  'latitude': -36.925,
#  'longitude': 143.9798,
#  'surface_temperature_celcius': 41}
# {'confidence': 59,
#  'datetime': '2023-04-18 04:48:30',
#  'latitude': -37.9049,
#  'longitude': 142.8528,
#  'surface_temperature_celcius': 47}
# {'confidence': 65,
#  'datetime': '2023-04-18 04:48:30',
#  'latitude': -36.1581,
#  'longitude': 142.7434,
#  'surface_temperature_celcius': 43}
# {'confidence': 59,
#  'datetime': '2023-04-18 04:48:10',
#  'latitude': -37.6868,
#  'longitude': 142.3949,
#  'surface_temperature_celcius': 40}
# {'confidence': 52,
#  'datetime': '2023-04-18 04:48:10',
#  'latitude': -36.1021,
#  'longitude': 146.6853,
#  'surface_temperature_celcius': 42}
# {'confidence': 65,
#  'datetime': '2023-04-18 04:47:40',
#  'latitude': -37.6674,
#  'longitude': 142.2687,
#  'surface_temperature_celcius': 42}
# {'confidence': 62,
#  'datetime': '2023-04-18 04:47:20',
#  'latitude': -37.7181,
#  'longitude': 141.6962,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'datetime': '2023-04-18 04:46:50',
#  'latitude': -37.7785,
#  'longitude': 143.1232,
#  'surface_temperature_celcius': 43}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:46:50',
#  'latitude': -37.4322,
#  'longitude': 143.1602,
#  'surface_temperature_celcius': 45}
# {'confidence': 63,
#  'datetime': '2023-04-18 04:46:40',
#  'latitude': -36.526,
#  'longitude': 144.7931,
#  'surface_temperature_celcius': 42}
# {'confidence': 62,
#  'datetime': '2023-04-18 04:46:30',
#  'latitude': -37.9538,
#  'longitude': 143.1487,
#  'surface_temperature_celcius': 41}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:46:30',
#  'latitude': -36.6704,
#  'longitude': 141.3197,
#  'surface_temperature_celcius': 45}
# {'confidence': 57,
#  'datetime': '2023-04-18 04:46:10',
#  'latitude': -37.4903,
#  'longitude': 143.5786,
#  'surface_temperature_celcius': 40}
# {'confidence': 64,
#  'datetime': '2023-04-18 04:45:50',
#  'latitude': -38.0574,
#  'longitude': 143.6523,
#  'surface_temperature_celcius': 42}
# {'confidence': 61,
#  'datetime': '2023-04-18 04:45:40',
#  'latitude': -36.9908,
#  'longitude': 141.2448,
#  'surface_temperature_celcius': 41}
# {'confidence': 63,
#  'datetime': '2023-04-18 04:45:40',
#  'latitude': -36.4428,
#  'longitude': 145.5639,
#  'surface_temperature_celcius': 43}
# {'confidence': 67,
#  'datetime': '2023-04-18 04:45:40',
#  'latitude': -38.1159,
#  'longitude': 143.7887,
#  'surface_temperature_celcius': 61}
# {'confidence': 54,
#  'datetime': '2023-04-18 04:45:40',
#  'latitude': -37.8084,
#  'longitude': 143.1985,
#  'surface_temperature_celcius': 46}
# {'confidence': 56,
#  'datetime': '2023-04-18 04:45:10',
#  'latitude': -36.4147,
#  'longitude': 141.0669,
#  'surface_temperature_celcius': 39}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:45:10',
#  'latitude': -38.1748,
#  'longitude': 143.0552,
#  'surface_temperature_celcius': 44}
# {'confidence': 65,
#  'datetime': '2023-04-18 04:45:00',
#  'latitude': -38.0525,
#  'longitude': 143.64,
#  'surface_temperature_celcius': 43}
# {'confidence': 64,
#  'datetime': '2023-04-18 04:45:00',
#  'latitude': -36.6026,
#  'longitude': 144.48,
#  'surface_temperature_celcius': 42}
# {'confidence': 67,
#  'datetime': '2023-04-18 04:45:00',
#  'latitude': -36.1112,
#  'longitude': 146.5388,
#  'surface_temperature_celcius': 43}
# {'confidence': 62,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -36.9171,
#  'longitude': 143.4749,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9373,
#  'longitude': 146.0744,
#  'surface_temperature_celcius': 39}
# {'confidence': 67,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.1758,
#  'longitude': 144.489,
#  'surface_temperature_celcius': 50}
# {'confidence': 56,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.2234,
#  'longitude': 143.9549,
#  'surface_temperature_celcius': 39}
# {'confidence': 56,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.1539,
#  'longitude': 144.1343,
#  'surface_temperature_celcius': 44}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.0898,
#  'longitude': 143.7394,
#  'surface_temperature_celcius': 47}
# {'confidence': 67,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.036,
#  'longitude': 143.9012,
#  'surface_temperature_celcius': 45}
# {'confidence': 66,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.0392,
#  'longitude': 143.8842,
#  'surface_temperature_celcius': 45}
# {'confidence': 68,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.1719,
#  'longitude': 143.0705,
#  'surface_temperature_celcius': 44}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.0907,
#  'longitude': 143.2362,
#  'surface_temperature_celcius': 45}
# {'confidence': 62,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.0278,
#  'longitude': 143.4528,
#  'surface_temperature_celcius': 43}
# {'confidence': 64,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9913,
#  'longitude': 143.5272,
#  'surface_temperature_celcius': 42}
# {'confidence': 67,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9424,
#  'longitude': 143.722,
#  'surface_temperature_celcius': 43}
# {'confidence': 61,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9775,
#  'longitude': 143.5868,
#  'surface_temperature_celcius': 41}
# {'confidence': 66,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9388,
#  'longitude': 143.7329,
#  'surface_temperature_celcius': 43}
# {'confidence': 59,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9718,
#  'longitude': 143.2609,
#  'surface_temperature_celcius': 40}
# {'confidence': 63,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9176,
#  'longitude': 143.43,
#  'surface_temperature_celcius': 41}
# {'confidence': 69,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9318,
#  'longitude': 143.2083,
#  'surface_temperature_celcius': 44}
# {'confidence': 64,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -38.0372,
#  'longitude': 142.6306,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.8643,
#  'longitude': 143.5099,
#  'surface_temperature_celcius': 42}
# {'confidence': 68,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.9255,
#  'longitude': 143.1236,
#  'surface_temperature_celcius': 44}
# {'confidence': 63,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.8857,
#  'longitude': 143.2777,
#  'surface_temperature_celcius': 41}
# {'confidence': 52,
#  'datetime': '2023-04-18 04:44:50',
#  'latitude': -37.8375,
#  'longitude': 143.4153,
#  'surface_temperature_celcius': 39}
# {'confidence': 57,
# ...
#  'longitude': 143.2419,
#  'surface_temperature_celcius': 40}
# {'confidence': 54,
#  'datetime': '2023-06-04 04:02:10',
#  'latitude': -36.4422,
#  'longitude': 141.427,
#  'surface_temperature_celcius': 39}
# {'confidence': 59,
#  'datetime': '2023-06-04 04:02:10',
#  'latitude': -36.251,
#  'longitude': 142.5651,
#  'surface_temperature_celcius': 40}
# {'confidence': 55,
#  'datetime': '2023-06-07 04:36:00',
#  'latitude': -36.1858,
#  'longitude': 143.885,
#  'surface_temperature_celcius': 39}
# {'confidence': 68,
#  'datetime': '2023-06-07 04:35:40',
#  'latitude': -36.2111,
#  'longitude': 141.505,
#  'surface_temperature_celcius': 44}
# {'confidence': 53,
#  'datetime': '2023-06-07 04:35:30',
#  'latitude': -36.5794,
#  'longitude': 142.5959,
#  'surface_temperature_celcius': 39}
# {'confidence': 61,
#  'datetime': '2023-06-07 04:32:10',
#  'latitude': -36.2229,
#  'longitude': 143.4245,
#  'surface_temperature_celcius': 41}
# {'confidence': 52,
#  'datetime': '2023-06-07 04:32:10',
#  'latitude': -36.0279,
#  'longitude': 146.0244,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'datetime': '2023-06-11 04:09:40',
#  'latitude': -37.6767,
#  'longitude': 142.9892,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'datetime': '2023-06-11 04:08:00',
#  'latitude': -37.6662,
#  'longitude': 142.9874,
#  'surface_temperature_celcius': 42}
# {'confidence': 62,
#  'datetime': '2023-06-13 04:02:00',
#  'latitude': -36.0201,
#  'longitude': 143.7775,
#  'surface_temperature_celcius': 41}
# {'confidence': 61,
#  'datetime': '2023-06-14 04:44:10',
#  'latitude': -36.2669,
#  'longitude': 143.1906,
#  'surface_temperature_celcius': 45}
# {'confidence': 55,
#  'datetime': '2023-06-14 04:40:10',
#  'latitude': -36.3769,
#  'longitude': 144.7505,
#  'surface_temperature_celcius': 39}
# {'confidence': 69,
#  'datetime': '2023-06-14 04:38:30',
#  'latitude': -36.059,
#  'longitude': 143.7718,
#  'surface_temperature_celcius': 44}
# {'confidence': 66,
#  'datetime': '2023-06-16 04:34:30',
#  'latitude': -37.3583,
#  'longitude': 143.0203,
#  'surface_temperature_celcius': 43}
# {'confidence': 64,
#  'datetime': '2023-06-16 04:26:10',
#  'latitude': -36.7084,
#  'longitude': 142.7354,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'datetime': '2023-06-18 04:14:00',
#  'latitude': -37.8387,
#  'longitude': 144.6301,
#  'surface_temperature_celcius': 39}
# {'confidence': 53,
#  'datetime': '2023-07-01 13:11:41',
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'surface_temperature_celcius': 29}
# {'confidence': 53,
#  'datetime': '2023-07-01 13:11:41',
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'surface_temperature_celcius': 29}
# {'confidence': 61,
#  'datetime': '2023-07-01 03:46:08',
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'surface_temperature_celcius': 32}
# {'confidence': 61,
#  'datetime': '2023-07-01 03:46:08',
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'datetime': '2023-07-02 04:29:10',
#  'latitude': -37.067,
#  'longitude': 141.379,
#  'surface_temperature_celcius': 36}
# {'confidence': 69,
#  'datetime': '2023-07-02 04:29:10',
#  'latitude': -37.067,
#  'longitude': 141.379,
#  'surface_temperature_celcius': 36}
# {'confidence': 50,
#  'datetime': '2023-07-02 04:28:42',
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'surface_temperature_celcius': 28}
# {'confidence': 50,
#  'datetime': '2023-07-02 04:28:42',
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'surface_temperature_celcius': 28}
# {'confidence': 57,
#  'datetime': '2023-07-04 04:14:00',
#  'latitude': -37.8067,
#  'longitude': 141.7598,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'datetime': '2023-07-05 23:44:00',
#  'latitude': -38.4031,
#  'longitude': 147.0701,
#  'surface_temperature_celcius': 45}
# {'confidence': 66,
#  'datetime': '2023-07-06 04:02:00',
#  'latitude': -37.8757,
#  'longitude': 143.428,
#  'surface_temperature_celcius': 43}
# {'confidence': 63,
#  'datetime': '2023-07-14 04:58:10',
#  'latitude': -38.5194,
#  'longitude': 143.4522,
#  'surface_temperature_celcius': 42}
# {'confidence': 61,
#  'datetime': '2023-07-14 04:50:20',
#  'latitude': -38.5233,
#  'longitude': 143.433,
#  'surface_temperature_celcius': 41}
# {'confidence': 54,
#  'datetime': '2023-08-02 03:45:00',
#  'latitude': -37.491,
#  'longitude': 141.936,
#  'surface_temperature_celcius': 40}
# {'confidence': 59,
#  'datetime': '2023-08-05 04:20:10',
#  'latitude': -37.8519,
#  'longitude': 147.2555,
#  'surface_temperature_celcius': 40}
# {'confidence': 54,
#  'datetime': '2023-08-13 05:13:30',
#  'latitude': -34.848,
#  'longitude': 141.5002,
#  'surface_temperature_celcius': 41}
# {'confidence': 63,
#  'datetime': '2023-08-13 05:05:00',
#  'latitude': -34.8425,
#  'longitude': 141.4933,
#  'surface_temperature_celcius': 42}
# {'confidence': 63,
#  'datetime': '2023-08-13 05:03:10',
#  'latitude': -34.793,
#  'longitude': 141.5898,
#  'surface_temperature_celcius': 42}
# {'confidence': 56,
#  'datetime': '2023-08-14 04:15:40',
#  'latitude': -37.4421,
#  'longitude': 148.259,
#  'surface_temperature_celcius': 39}
# {'confidence': 61,
#  'datetime': '2023-08-14 04:11:00',
#  'latitude': -38.0173,
#  'longitude': 144.0571,
#  'surface_temperature_celcius': 41}
# {'confidence': 67,
#  'datetime': '2023-08-14 04:10:20',
#  'latitude': -37.4754,
#  'longitude': 148.161,
#  'surface_temperature_celcius': 43}
# {'confidence': 61,
#  'datetime': '2023-08-14 04:09:30',
#  'latitude': -37.443,
#  'longitude': 147.3064,
#  'surface_temperature_celcius': 41}
# {'confidence': 58,
#  'datetime': '2023-08-14 04:07:50',
#  'latitude': -37.7836,
#  'longitude': 143.9688,
#  'surface_temperature_celcius': 40}
# {'confidence': 56,
#  'datetime': '2023-09-23 23:50:43',
#  'latitude': -37.559,
#  'longitude': 148.037,
#  'surface_temperature_celcius': 41}
# {'confidence': 58,
#  'datetime': '2023-09-23 23:50:40',
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
# {'confidence': 62,
#  'datetime': '2023-09-23 23:50:40',
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'confidence': 50,
#  'datetime': '2023-09-23 04:59:18',
#  'latitude': -36.984,
#  'longitude': 148.25,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'datetime': '2023-09-23 04:59:13',
#  'latitude': -37.347,
#  'longitude': 148.019,
#  'surface_temperature_celcius': 36}
# {'confidence': 56,
#  'datetime': '2023-09-23 03:21:28',
#  'latitude': -36.995,
#  'longitude': 148.268,
#  'surface_temperature_celcius': 37}
# {'confidence': 63,
#  'datetime': '2023-09-23 03:21:19',
#  'latitude': -37.554,
#  'longitude': 148.073,
#  'surface_temperature_celcius': 37}
# {'confidence': 59,
#  'datetime': '2023-09-24 13:30:09',
#  'latitude': -37.375,
#  'longitude': 148.063,
#  'surface_temperature_celcius': 35}
# {'confidence': 58,
#  'datetime': '2023-09-24 04:04:19',
#  'latitude': -37.397,
#  'longitude': 148.121,
#  'surface_temperature_celcius': 58}
# {'confidence': 68,
#  'datetime': '2023-09-24 04:04:18',
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'confidence': 68,
#  'datetime': '2023-09-24 04:04:18',
#  'latitude': -37.465,
#  'longitude': 148.153,
#  'surface_temperature_celcius': 63}
# {'confidence': 64,
#  'datetime': '2023-09-24 04:04:18',
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'confidence': 61,
#  'datetime': '2023-09-24 04:04:17',
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'confidence': 56,
#  'datetime': '2023-09-24 04:04:04',
#  'latitude': -38.495,
#  'longitude': 146.944,
#  'surface_temperature_celcius': 53}
# {'confidence': 64,
#  'datetime': '2023-09-26 03:52:14',
#  'latitude': -37.087,
#  'longitude': 145.37,
#  'surface_temperature_celcius': 33}
# {'confidence': 65,
#  'datetime': '2023-09-27 04:35:18',
#  'latitude': -36.398,
#  'longitude': 145.286,
#  'surface_temperature_celcius': 39}
# {'confidence': 62,
#  'datetime': '2023-10-01 15:13:56',
#  'latitude': -37.463,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 34}
# {'confidence': 64,
#  'datetime': '2023-10-01 04:10:28',
#  'latitude': -37.46,
#  'longitude': 148.113,
#  'surface_temperature_celcius': 52}
# {'confidence': 50,
#  'datetime': '2023-10-02 23:44:31',
#  'latitude': -37.466,
#  'longitude': 148.1,
#  'surface_temperature_celcius': 29}
# {'confidence': 59,
#  'datetime': '2023-10-02 04:53:10',
#  'latitude': -37.475,
#  'longitude': 148.134,
#  'surface_temperature_celcius': 40}
# {'confidence': 68,
#  'datetime': '2023-10-02 00:39:34',
#  'latitude': -37.456,
#  'longitude': 148.11,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'datetime': '2023-10-03 15:01:44',
#  'latitude': -37.461,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 33}
# {'confidence': 68,
#  'datetime': '2023-10-03 03:58:28',
#  'latitude': -37.236,
#  'longitude': 141.176,
#  'surface_temperature_celcius': 37}
# {'confidence': 59,
#  'datetime': '2023-10-03 03:58:28',
#  'latitude': -37.227,
#  'longitude': 141.151,
#  'surface_temperature_celcius': 35}
# {'confidence': 54,
#  'datetime': '2023-10-03 01:22:44',
#  'latitude': -37.227,
#  'longitude': 141.146,
#  'surface_temperature_celcius': 31}
# {'confidence': 50,
#  'datetime': '2023-10-04 04:41:36',
#  'latitude': -36.418,
#  'longitude': 141.596,
#  'surface_temperature_celcius': 41}
# {'confidence': 62,
#  'datetime': '2023-10-16 23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'confidence': 58,
#  'datetime': '2023-10-17 04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'confidence': 65,
#  'datetime': '2023-10-20 00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'confidence': 65,
#  'datetime': '2023-10-21 01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'confidence': 67,
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'datetime': '2023-10-26 04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'confidence': 62,
#  'datetime': '2023-10-27 04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'confidence': 60,
#  'datetime': '2023-11-08 05:12:08',
#  'latitude': -36.538,
#  'longitude': 141.129,
#  'surface_temperature_celcius': 43}
# {'confidence': 68,
#  'datetime': '2023-11-09 04:16:56',
#  'latitude': -36.759,
#  'longitude': 145.179,
#  'surface_temperature_celcius': 52}
# {'confidence': 62,
#  'datetime': '2023-11-09 04:16:56',
#  'latitude': -36.758,
#  'longitude': 145.19,
#  'surface_temperature_celcius': 51}
# {'confidence': 63,
#  'datetime': '2023-11-09 04:16:46',
#  'latitude': -37.719,
#  'longitude': 142.154,
#  'surface_temperature_celcius': 41}
# {'confidence': 51,
#  'datetime': '2023-11-11 15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'confidence': 63,
#  'datetime': '2023-11-12 04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'confidence': 58,
#  'datetime': '2023-11-12 04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'datetime': '2023-11-12 04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'confidence': 67,
#  'datetime': '2023-11-12 00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'datetime': '2023-11-13 03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'confidence': 51,
#  'datetime': '2023-11-13 01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'confidence': 62,
#  'datetime': '2023-11-13 01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'confidence': 64,
#  'datetime': '2023-11-14 00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'confidence': 64,
#  'datetime': '2023-11-14 00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'confidence': 68,
#  'datetime': '2023-11-23 00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'confidence': 63,
#  'datetime': '2023-11-23 00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'confidence': 50,
#  'datetime': '2023-11-28 00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'confidence': 53,
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'confidence': 68,
#  'datetime': '2023-11-29 13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'confidence': 52,
#  'datetime': '2023-11-29 03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'confidence': 64,
#  'datetime': '2023-11-29 03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'confidence': 52,
#  'datetime': '2023-11-30 23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'confidence': 51,
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'confidence': 64,
#  'datetime': '2023-11-30 15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'datetime': '2023-11-30 15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'confidence': 61,
#  'datetime': '2023-11-30 15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'confidence': 62,
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'confidence': 64,
#  'datetime': '2023-11-30 12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'confidence': 69,
#  'datetime': '2023-11-30 04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'confidence': 60,
#  'datetime': '2023-11-30 00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'confidence': 69,
#  'datetime': '2023-11-30 00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'confidence': 64,
#  'datetime': '2023-11-30 00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'confidence': 56,
#  'datetime': '2023-12-08 13:11:43',
#  'latitude': -36.291,
#  'longitude': 146.159,
#  'surface_temperature_celcius': 40}
# {'confidence': 50,
#  'datetime': '2023-12-10 00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'confidence': 67,
#  'datetime': '2023-12-10 00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'confidence': 53,
#  'datetime': '2023-12-12 00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'confidence': 51,
#  'datetime': '2023-12-15 13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'confidence': 65,
#  'datetime': '2023-12-15 01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'confidence': 69,
#  'datetime': '2023-12-16 15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'confidence': 62,
#  'datetime': '2023-12-16 04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'confidence': 59,
#  'datetime': '2023-12-16 04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'confidence': 60,
#  'datetime': '2023-12-16 00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'confidence': 53,
#  'datetime': '2023-12-16 00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'confidence': 65,
#  'datetime': '2023-12-24 13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'confidence': 67,
#  'datetime': '2023-12-27 00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}

# %% [markdown]
# ##### **h) Average surface temperature (°C) of each day**

# %%
#project only date and number of fires
projected_fields = {
                     "_id": 0,
                     "date": 1,

                     #using conditionals to show average temperature only for dates with hotspots
                     "average_surface_temperature": {
                         "$cond": {
                             "if": {"$eq": ["$hotspots", []]},   #if no hotspots, surface temp = N/A
                             "then": "N/A",
                             "else": {"$avg": "$hotspots.surface_temperature_celcius"}
                         }
                     }
                    }

pipeline_stages = [{"$project": projected_fields}]

data = climate_col.aggregate(pipeline_stages)  #execute aggregation pipeline


for document in data:
    pprint(document)
# Out:
# {'average_surface_temperature': 'N/A', 'date': '31/12/2022'}
# {'average_surface_temperature': 'N/A', 'date': '2/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '3/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '4/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '5/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '6/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '7/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '8/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '9/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '10/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '11/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '12/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '13/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '14/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '15/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '16/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '17/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '18/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '20/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '21/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '22/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '23/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '24/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '26/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '29/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '31/1/2023'}
# {'average_surface_temperature': 'N/A', 'date': '1/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '2/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '3/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '4/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '5/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '6/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '7/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '8/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '9/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '10/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '11/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '12/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '13/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '14/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '15/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '16/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '17/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '18/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '20/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '21/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '22/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '23/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '24/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '26/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/2/2023'}
# {'average_surface_temperature': 'N/A', 'date': '1/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '2/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '3/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '4/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '5/3/2023'}
# {'average_surface_temperature': 60.5, 'date': '6/3/2023'}
# {'average_surface_temperature': 64.0, 'date': '7/3/2023'}
# {'average_surface_temperature': 51.5, 'date': '8/3/2023'}
# {'average_surface_temperature': 46.666666666666664, 'date': '9/3/2023'}
# {'average_surface_temperature': 69.375, 'date': '10/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '11/3/2023'}
# {'average_surface_temperature': 88.2, 'date': '12/3/2023'}
# {'average_surface_temperature': 38.5, 'date': '13/3/2023'}
# {'average_surface_temperature': 65.6, 'date': '14/3/2023'}
# {'average_surface_temperature': 46.0, 'date': '15/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '16/3/2023'}
# {'average_surface_temperature': 59.5, 'date': '17/3/2023'}
# {'average_surface_temperature': 79.33333333333333, 'date': '18/3/2023'}
# {'average_surface_temperature': 65.57142857142857, 'date': '19/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '20/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '21/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '22/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '23/3/2023'}
# {'average_surface_temperature': 49.0, 'date': '24/3/2023'}
# {'average_surface_temperature': 66.0, 'date': '25/3/2023'}
# {'average_surface_temperature': 56.88235294117647, 'date': '26/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/3/2023'}
# {'average_surface_temperature': 60.925925925925924, 'date': '28/3/2023'}
# {'average_surface_temperature': 51.0, 'date': '29/3/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/3/2023'}
# {'average_surface_temperature': 48.72727272727273, 'date': '31/3/2023'}
# {'average_surface_temperature': 46.714285714285715, 'date': '1/4/2023'}
# {'average_surface_temperature': 45.2, 'date': '2/4/2023'}
# {'average_surface_temperature': 58.44444444444444, 'date': '3/4/2023'}
# {'average_surface_temperature': 62.57303370786517, 'date': '4/4/2023'}
# {'average_surface_temperature': 53.142857142857146, 'date': '5/4/2023'}
# {'average_surface_temperature': 61.71186440677966, 'date': '6/4/2023'}
# {'average_surface_temperature': 50.69230769230769, 'date': '7/4/2023'}
# {'average_surface_temperature': 60.75, 'date': '8/4/2023'}
# {'average_surface_temperature': 'N/A', 'date': '9/4/2023'}
# {'average_surface_temperature': 'N/A', 'date': '10/4/2023'}
# {'average_surface_temperature': 46.291666666666664, 'date': '11/4/2023'}
# {'average_surface_temperature': 52.69565217391305, 'date': '12/4/2023'}
# {'average_surface_temperature': 58.57983193277311, 'date': '13/4/2023'}
# {'average_surface_temperature': 61.94444444444444, 'date': '14/4/2023'}
# {'average_surface_temperature': 59.57971014492754, 'date': '15/4/2023'}
# {'average_surface_temperature': 48.72222222222222, 'date': '16/4/2023'}
# {'average_surface_temperature': 50.921052631578945, 'date': '17/4/2023'}
# {'average_surface_temperature': 53.36615384615384, 'date': '18/4/2023'}
# {'average_surface_temperature': 54.16, 'date': '19/4/2023'}
# {'average_surface_temperature': 56.58064516129032, 'date': '20/4/2023'}
# {'average_surface_temperature': 'N/A', 'date': '21/4/2023'}
# {'average_surface_temperature': 54.5, 'date': '22/4/2023'}
# {'average_surface_temperature': 53.89473684210526, 'date': '23/4/2023'}
# {'average_surface_temperature': 59.375, 'date': '24/4/2023'}
# {'average_surface_temperature': 48.666666666666664, 'date': '25/4/2023'}
# {'average_surface_temperature': 34.0, 'date': '26/4/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/4/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/4/2023'}
# {'average_surface_temperature': 63.0, 'date': '29/4/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/4/2023'}
# {'average_surface_temperature': 68.4, 'date': '1/5/2023'}
# {'average_surface_temperature': 55.6, 'date': '2/5/2023'}
# {'average_surface_temperature': 56.796875, 'date': '3/5/2023'}
# {'average_surface_temperature': 56.80740740740741, 'date': '4/5/2023'}
# {'average_surface_temperature': 51.70967741935484, 'date': '5/5/2023'}
# {'average_surface_temperature': 57.529411764705884, 'date': '6/5/2023'}
# {'average_surface_temperature': 50.333333333333336, 'date': '7/5/2023'}
# {'average_surface_temperature': 56.291666666666664, 'date': '8/5/2023'}
# {'average_surface_temperature': 42.46153846153846, 'date': '9/5/2023'}
# {'average_surface_temperature': 52.86842105263158, 'date': '10/5/2023'}
# {'average_surface_temperature': 59.36842105263158, 'date': '11/5/2023'}
# {'average_surface_temperature': 51.5, 'date': '12/5/2023'}
# {'average_surface_temperature': 58.611111111111114, 'date': '13/5/2023'}
# {'average_surface_temperature': 49.0, 'date': '14/5/2023'}
# {'average_surface_temperature': 53.950980392156865, 'date': '15/5/2023'}
# {'average_surface_temperature': 39.666666666666664, 'date': '16/5/2023'}
# {'average_surface_temperature': 52.0, 'date': '17/5/2023'}
# {'average_surface_temperature': 44.142857142857146, 'date': '18/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '20/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '21/5/2023'}
# {'average_surface_temperature': 54.484848484848484, 'date': '22/5/2023'}
# {'average_surface_temperature': 51.2, 'date': '23/5/2023'}
# {'average_surface_temperature': 40.333333333333336, 'date': '24/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/5/2023'}
# {'average_surface_temperature': 49.5, 'date': '26/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '29/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/5/2023'}
# {'average_surface_temperature': 'N/A', 'date': '31/5/2023'}
# {'average_surface_temperature': 54.0, 'date': '1/6/2023'}
# {'average_surface_temperature': 47.72727272727273, 'date': '2/6/2023'}
# {'average_surface_temperature': 47.0, 'date': '3/6/2023'}
# {'average_surface_temperature': 52.22222222222222, 'date': '4/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '5/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '6/6/2023'}
# {'average_surface_temperature': 51.857142857142854, 'date': '7/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '8/6/2023'}
# {'average_surface_temperature': 49.0, 'date': '9/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '10/6/2023'}
# {'average_surface_temperature': 41.5, 'date': '11/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '12/6/2023'}
# {'average_surface_temperature': 41.0, 'date': '13/6/2023'}
# {'average_surface_temperature': 53.25, 'date': '14/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '15/6/2023'}
# {'average_surface_temperature': 42.5, 'date': '16/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '17/6/2023'}
# {'average_surface_temperature': 42.0, 'date': '18/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/6/2023'}
# {'average_surface_temperature': 71.16666666666667, 'date': '20/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '21/6/2023'}
# {'average_surface_temperature': 46.0, 'date': '22/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '23/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '24/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '26/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/6/2023'}
# {'average_surface_temperature': 'N/A', 'date': '29/6/2023'}
# {'average_surface_temperature': 44.333333333333336, 'date': '30/6/2023'}
# {'average_surface_temperature': 30.5, 'date': '1/7/2023'}
# {'average_surface_temperature': 43.5, 'date': '2/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '3/7/2023'}
# {'average_surface_temperature': 40.0, 'date': '4/7/2023'}
# {'average_surface_temperature': 45.0, 'date': '5/7/2023'}
# {'average_surface_temperature': 56.0, 'date': '6/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '7/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '8/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '9/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '10/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '11/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '12/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '13/7/2023'}
# {'average_surface_temperature': 41.5, 'date': '14/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '15/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '16/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '17/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '18/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '20/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '21/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '22/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '23/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '24/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '26/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/7/2023'}
# {'average_surface_temperature': 48.0, 'date': '29/7/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/7/2023'}
# {'average_surface_temperature': 47.0, 'date': '31/7/2023'}
# {'average_surface_temperature': 58.0, 'date': '1/8/2023'}
# {'average_surface_temperature': 63.5, 'date': '2/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '3/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '4/8/2023'}
# {'average_surface_temperature': 40.0, 'date': '5/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '6/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '7/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '8/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '9/8/2023'}
# {'average_surface_temperature': 63.0, 'date': '10/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '11/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '12/8/2023'}
# {'average_surface_temperature': 49.0, 'date': '13/8/2023'}
# {'average_surface_temperature': 40.8, 'date': '14/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '15/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '16/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '17/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '18/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '20/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '21/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '22/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '23/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '24/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '26/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '29/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '31/8/2023'}
# {'average_surface_temperature': 'N/A', 'date': '1/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '2/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '3/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '4/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '5/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '6/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '7/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '8/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '9/9/2023'}
# {'average_surface_temperature': 56.5, 'date': '10/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '11/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '12/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '13/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '14/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '15/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '16/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '17/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '18/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/9/2023'}
# {'average_surface_temperature': 63.6, 'date': '20/9/2023'}
# {'average_surface_temperature': 40.5, 'date': '21/9/2023'}
# {'average_surface_temperature': 45.0, 'date': '22/9/2023'}
# {'average_surface_temperature': 52.73913043478261, 'date': '23/9/2023'}
# {'average_surface_temperature': 53.57142857142857, 'date': '24/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/9/2023'}
# {'average_surface_temperature': 33.0, 'date': '26/9/2023'}
# {'average_surface_temperature': 49.714285714285715, 'date': '27/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/9/2023'}
# {'average_surface_temperature': 43.0, 'date': '29/9/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/9/2023'}
# {'average_surface_temperature': 48.25, 'date': '1/10/2023'}
# {'average_surface_temperature': 43.57142857142857, 'date': '2/10/2023'}
# {'average_surface_temperature': 50.0, 'date': '3/10/2023'}
# {'average_surface_temperature': 49.0, 'date': '4/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '5/10/2023'}
# {'average_surface_temperature': 44.0, 'date': '6/10/2023'}
# {'average_surface_temperature': 42.0, 'date': '7/10/2023'}
# {'average_surface_temperature': 41.0, 'date': '8/10/2023'}
# {'average_surface_temperature': 44.0, 'date': '9/10/2023'}
# {'average_surface_temperature': 53.333333333333336, 'date': '10/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '11/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '12/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '13/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '14/10/2023'}
# {'average_surface_temperature': 72.66666666666667, 'date': '15/10/2023'}
# {'average_surface_temperature': 36.0, 'date': '16/10/2023'}
# {'average_surface_temperature': 51.6, 'date': '17/10/2023'}
# {'average_surface_temperature': 52.166666666666664, 'date': '18/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/10/2023'}
# {'average_surface_temperature': 50.0, 'date': '20/10/2023'}
# {'average_surface_temperature': 51.25, 'date': '21/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '22/10/2023'}
# {'average_surface_temperature': 38.0, 'date': '23/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '24/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/10/2023'}
# {'average_surface_temperature': 44.6, 'date': '26/10/2023'}
# {'average_surface_temperature': 50.4, 'date': '27/10/2023'}
# {'average_surface_temperature': 56.0, 'date': '28/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '29/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '31/10/2023'}
# {'average_surface_temperature': 'N/A', 'date': '1/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '2/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '3/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '4/11/2023'}
# {'average_surface_temperature': 58.5, 'date': '5/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '6/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '7/11/2023'}
# {'average_surface_temperature': 45.5, 'date': '8/11/2023'}
# {'average_surface_temperature': 61.3, 'date': '9/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '10/11/2023'}
# {'average_surface_temperature': 46.25, 'date': '11/11/2023'}
# {'average_surface_temperature': 53.0, 'date': '12/11/2023'}
# {'average_surface_temperature': 47.0, 'date': '13/11/2023'}
# {'average_surface_temperature': 52.0, 'date': '14/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '15/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '16/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '17/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '18/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '20/11/2023'}
# {'average_surface_temperature': 59.0, 'date': '21/11/2023'}
# {'average_surface_temperature': 61.5, 'date': '22/11/2023'}
# {'average_surface_temperature': 58.8, 'date': '23/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '24/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '25/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '26/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '27/11/2023'}
# {'average_surface_temperature': 42.0, 'date': '28/11/2023'}
# {'average_surface_temperature': 60.625, 'date': '29/11/2023'}
# {'average_surface_temperature': 52.41935483870968, 'date': '30/11/2023'}
# {'average_surface_temperature': 'N/A', 'date': '1/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '2/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '3/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '4/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '5/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '6/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '7/12/2023'}
# {'average_surface_temperature': 50.6, 'date': '8/12/2023'}
# {'average_surface_temperature': 58.25, 'date': '9/12/2023'}
# {'average_surface_temperature': 46.0, 'date': '10/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '11/12/2023'}
# {'average_surface_temperature': 44.0, 'date': '12/12/2023'}
# {'average_surface_temperature': 60.0, 'date': '13/12/2023'}
# {'average_surface_temperature': 70.0, 'date': '14/12/2023'}
# {'average_surface_temperature': 39.0, 'date': '15/12/2023'}
# {'average_surface_temperature': 57.8, 'date': '16/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '17/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '18/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '19/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '20/12/2023'}
# {'average_surface_temperature': 46.0, 'date': '21/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '22/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '23/12/2023'}
# {'average_surface_temperature': 32.0, 'date': '24/12/2023'}
# {'average_surface_temperature': 54.0, 'date': '25/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '26/12/2023'}
# {'average_surface_temperature': 62.75, 'date': '27/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '28/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '29/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '30/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '31/12/2023'}
# {'average_surface_temperature': 'N/A', 'date': '1/1/2024'}

# %% [markdown]
# ##### **i) Top 10 records with the lowest GHI**

# %%
pipeline_stages = [{"$sort": {"GHI_w/m2": 1}},  #sort in ascending order based on GHI
                   {"$limit": 10} #output only top 10 records
                  ]

data = climate_col.aggregate(pipeline_stages)  #execute aggregation pipeline

for document in data:
    pprint(document)
# Out:
# {'GHI_w/m2': 47,
#  '_id': ObjectId('663d77f85178059695ff6101'),
#  'air_temperature_celcius': 5,
#  'date': '2/8/2023',
#  'hotspots': [{'confidence': 94,
#                'datetime': '2023-08-02 03:45:40',
#                'latitude': -37.4796,
#                'longitude': 141.9403,
#                'surface_temperature_celcius': 87},
#               {'confidence': 54,
#                'datetime': '2023-08-02 03:45:00',
#                'latitude': -37.491,
#                'longitude': 141.936,
#                'surface_temperature_celcius': 40}],
#  'max_wind_speed': 5.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 48,
#  '_id': ObjectId('663d77f75178059695ff60e0'),
#  'air_temperature_celcius': 5,
#  'date': '30/6/2023',
#  'hotspots': [{'confidence': 78,
#                'datetime': '2023-06-30 04:41:25',
#                'latitude': -36.834,
#                'longitude': 142.524,
#                'surface_temperature_celcius': 44},
#               {'confidence': 78,
#                'datetime': '2023-06-30 04:41:25',
#                'latitude': -36.834,
#                'longitude': 142.524,
#                'surface_temperature_celcius': 44},
#               {'confidence': 81,
#                'datetime': '2023-06-30 00:27:19',
#                'latitude': -37.858,
#                'longitude': 143.428,
#                'surface_temperature_celcius': 48},
#               {'confidence': 75,
#                'datetime': '2023-06-30 00:27:19',
#                'latitude': -37.856,
#                'longitude': 143.416,
#                'surface_temperature_celcius': 41},
#               {'confidence': 75,
#                'datetime': '2023-06-30 00:27:19',
#                'latitude': -37.856,
#                'longitude': 143.416,
#                'surface_temperature_celcius': 41},
#               {'confidence': 81,
#                'datetime': '2023-06-30 00:27:19',
#                'latitude': -37.858,
#                'longitude': 143.428,
#                'surface_temperature_celcius': 48}],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 49,
#  '_id': ObjectId('663d77f75178059695ff60e1'),
#  'air_temperature_celcius': 5,
#  'date': '1/7/2023',
#  'hotspots': [{'confidence': 53,
#                'datetime': '2023-07-01 13:11:41',
#                'latitude': -37.062,
#                'longitude': 141.373,
#                'surface_temperature_celcius': 29},
#               {'confidence': 53,
#                'datetime': '2023-07-01 13:11:41',
#                'latitude': -37.062,
#                'longitude': 141.373,
#                'surface_temperature_celcius': 29},
#               {'confidence': 61,
#                'datetime': '2023-07-01 03:46:08',
#                'latitude': -36.779,
#                'longitude': 146.108,
#                'surface_temperature_celcius': 32},
#               {'confidence': 61,
#                'datetime': '2023-07-01 03:46:08',
#                'latitude': -36.779,
#                'longitude': 146.108,
#                'surface_temperature_celcius': 32}],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 56,
#  '_id': ObjectId('663d77f75178059695ff60eb'),
#  'air_temperature_celcius': 6,
#  'date': '11/7/2023',
#  'hotspots': [],
#  'max_wind_speed': 5.1,
#  'precipitation': '0.01G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 57,
#  '_id': ObjectId('663d77f75178059695ff60ef'),
#  'air_temperature_celcius': 6,
#  'date': '15/7/2023',
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 60,
#  '_id': ObjectId('663d77f75178059695ff60e2'),
#  'air_temperature_celcius': 6,
#  'date': '2/7/2023',
#  'hotspots': [{'confidence': 84,
#                'datetime': '2023-07-02 04:29:18',
#                'latitude': -36.397,
#                'longitude': 142.254,
#                'surface_temperature_celcius': 52},
#               {'confidence': 84,
#                'datetime': '2023-07-02 04:29:18',
#                'latitude': -36.397,
#                'longitude': 142.254,
#                'surface_temperature_celcius': 52},
#               {'confidence': 69,
#                'datetime': '2023-07-02 04:29:10',
#                'latitude': -37.067,
#                'longitude': 141.379,
#                'surface_temperature_celcius': 36},
#               {'confidence': 69,
#                'datetime': '2023-07-02 04:29:10',
#                'latitude': -37.067,
#                'longitude': 141.379,
#                'surface_temperature_celcius': 36},
#               {'confidence': 88,
#                'datetime': '2023-07-02 04:29:00',
#                'latitude': -37.333,
#                'longitude': 143.534,
#                'surface_temperature_celcius': 58},
#               {'confidence': 88,
#                'datetime': '2023-07-02 04:29:00',
#                'latitude': -37.333,
#                'longitude': 143.534,
#                'surface_temperature_celcius': 58},
#               {'confidence': 50,
#                'datetime': '2023-07-02 04:28:42',
#                'latitude': -37.886,
#                'longitude': 147.207,
#                'surface_temperature_celcius': 28},
#               {'confidence': 50,
#                'datetime': '2023-07-02 04:28:42',
#                'latitude': -37.886,
#                'longitude': 147.207,
#                'surface_temperature_celcius': 28}],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('663d77f85178059695ff6100'),
#  'air_temperature_celcius': 7,
#  'date': '1/8/2023',
#  'hotspots': [{'confidence': 89,
#                'datetime': '2023-08-01 00:20:30',
#                'latitude': -38.3998,
#                'longitude': 147.064,
#                'surface_temperature_celcius': 65},
#               {'confidence': 78,
#                'datetime': '2023-08-01 00:19:30',
#                'latitude': -38.3982,
#                'longitude': 147.0509,
#                'surface_temperature_celcius': 51}],
#  'max_wind_speed': 7.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('663d77f75178059695ff60f4'),
#  'air_temperature_celcius': 7,
#  'date': '20/7/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.12G',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('663d77f85178059695ff60ff'),
#  'air_temperature_celcius': 7,
#  'date': '31/7/2023',
#  'hotspots': [{'confidence': 100,
#                'datetime': '2023-07-31 13:21:00',
#                'latitude': -37.8641,
#                'longitude': 143.4276,
#                'surface_temperature_celcius': 51},
#               {'confidence': 92,
#                'datetime': '2023-07-31 13:21:00',
#                'latitude': -37.8658,
#                'longitude': 143.4162,
#                'surface_temperature_celcius': 43}],
#  'max_wind_speed': 8.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'GHI_w/m2': 66,
#  '_id': ObjectId('663d77f85178059695ff6112'),
#  'air_temperature_celcius': 7,
#  'date': '19/8/2023',
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation': '0.04G',
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %% [markdown]
# ##### **j) Records with a 24-hour precipitation recorded between 0.20 to 0.35**

# %%
#since precipitation is stored in alphanumeric format, regex pattern matching is used to fetch required data
#since 24 hour precipitation record is required, the flags checked in regex are D(4*6=24), F(2*12=24) and G(1*24=24)
data = climate_col.find({"precipitation": {"$regex": "^(0\.(2[0-9]|3[0-5]))[D|F|G]"}}) 

for document in data:
    pprint(document)
# Out:
# {'GHI_w/m2': 157,
#  '_id': ObjectId('663d77f75178059695ff6038'),
#  'air_temperature_celcius': 19,
#  'date': '13/1/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.31G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('663d77f75178059695ff6083'),
#  'air_temperature_celcius': 17,
#  'date': '29/3/2023',
#  'hotspots': [{'confidence': 69,
#                'datetime': '2023-03-29 00:48:40',
#                'latitude': -34.2648,
#                'longitude': 141.6325,
#                'surface_temperature_celcius': 51}],
#  'max_wind_speed': 21.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('663d77f75178059695ff6099'),
#  'air_temperature_celcius': 20,
#  'date': '20/4/2023',
#  'hotspots': [{'confidence': 84,
#                'datetime': '2023-04-20 04:44:20',
#                'latitude': -36.8871,
#                'longitude': 145.1536,
#                'surface_temperature_celcius': 58},
#               {'confidence': 59,
#                'datetime': '2023-04-20 04:36:00',
#                'latitude': -38.4685,
#                'longitude': 146.673,
#                'surface_temperature_celcius': 40},
#               {'confidence': 60,
#                'datetime': '2023-04-20 04:34:10',
#                'latitude': -36.8922,
#                'longitude': 145.1252,
#                'surface_temperature_celcius': 40},
#               {'confidence': 93,
#                'datetime': '2023-04-20 04:34:10',
#                'latitude': -37.769,
#                'longitude': 147.94,
#                'surface_temperature_celcius': 72},
#               {'confidence': 77,
#                'datetime': '2023-04-20 04:33:40',
#                'latitude': -36.0799,
#                'longitude': 146.0784,
#                'surface_temperature_celcius': 50},
#               {'confidence': 88,
#                'datetime': '2023-04-20 04:33:20',
#                'latitude': -36.0829,
#                'longitude': 146.0621,
#                'surface_temperature_celcius': 63},
#               {'confidence': 90,
#                'datetime': '2023-04-20 04:32:50',
#                'latitude': -36.1303,
#                'longitude': 146.3606,
#                'surface_temperature_celcius': 67},
#               {'confidence': 67,
#                'datetime': '2023-04-20 04:32:50',
#                'latitude': -37.7615,
#                'longitude': 147.9169,
#                'surface_temperature_celcius': 45},
#               {'confidence': 63,
#                'datetime': '2023-04-20 04:32:30',
#                'latitude': -36.8079,
#                'longitude': 145.1409,
#                'surface_temperature_celcius': 42},
#               {'confidence': 85,
#                'datetime': '2023-04-20 04:32:30',
#                'latitude': -37.7783,
#                'longitude': 147.9284,
#                'surface_temperature_celcius': 60},
#               {'confidence': 79,
#                'datetime': '2023-04-20 04:32:30',
#                'latitude': -36.8846,
#                'longitude': 145.1679,
#                'surface_temperature_celcius': 52},
#               {'confidence': 80,
#                'datetime': '2023-04-20 04:32:30',
#                'latitude': -37.2341,
#                'longitude': 149.1736,
#                'surface_temperature_celcius': 53},
#               {'confidence': 63,
#                'datetime': '2023-04-20 04:32:30',
#                'latitude': -36.9189,
#                'longitude': 147.5603,
#                'surface_temperature_celcius': 52},
#               {'confidence': 98,
#                'datetime': '2023-04-20 04:32:30',
#                'latitude': -36.1345,
#                'longitude': 146.351,
#                'surface_temperature_celcius': 84},
#               {'confidence': 87,
#                'datetime': '2023-04-20 04:32:30',
#                'latitude': -36.9246,
#                'longitude': 147.5559,
#                'surface_temperature_celcius': 62},
#               {'confidence': 64,
#                'datetime': '2023-04-20 00:19:00',
#                'latitude': -36.085,
#                'longitude': 145.9096,
#                'surface_temperature_celcius': 42},
#               {'confidence': 88,
#                'datetime': '2023-04-20 00:18:40',
#                'latitude': -38.1301,
#                'longitude': 143.9398,
#                'surface_temperature_celcius': 63},
#               {'confidence': 69,
#                'datetime': '2023-04-20 00:18:20',
#                'latitude': -37.7087,
#                'longitude': 145.5499,
#                'surface_temperature_celcius': 45},
#               {'confidence': 100,
#                'datetime': '2023-04-20 00:18:20',
#                'latitude': -36.5865,
#                'longitude': 145.2081,
#                'surface_temperature_celcius': 111},
#               {'confidence': 73,
#                'datetime': '2023-04-20 00:17:10',
#                'latitude': -36.8702,
#                'longitude': 144.0381,
#                'surface_temperature_celcius': 47},
#               {'confidence': 99,
#                'datetime': '2023-04-20 00:17:10',
#                'latitude': -36.1586,
#                'longitude': 145.6666,
#                'surface_temperature_celcius': 85},
#               {'confidence': 74,
#                'datetime': '2023-04-20 00:16:50',
#                'latitude': -37.8672,
#                'longitude': 143.8194,
#                'surface_temperature_celcius': 48},
#               {'confidence': 78,
#                'datetime': '2023-04-20 00:15:30',
#                'latitude': -36.5956,
#                'longitude': 145.206,
#                'surface_temperature_celcius': 51},
#               {'confidence': 77,
#                'datetime': '2023-04-20 00:14:20',
#                'latitude': -37.2197,
#                'longitude': 148.8134,
#                'surface_temperature_celcius': 50},
#               {'confidence': 96,
#                'datetime': '2023-04-20 00:14:10',
#                'latitude': -36.5847,
#                'longitude': 145.1968,
#                'surface_temperature_celcius': 78},
#               {'confidence': 89,
#                'datetime': '2023-04-20 00:13:40',
#                'latitude': -37.6997,
#                'longitude': 145.5519,
#                'surface_temperature_celcius': 64},
#               {'confidence': 61,
#                'datetime': '2023-04-20 00:13:30',
#                'latitude': -37.932,
#                'longitude': 146.1845,
#                'surface_temperature_celcius': 50},
#               {'confidence': 76,
#                'datetime': '2023-04-20 00:13:10',
#                'latitude': -36.6407,
#                'longitude': 144.2957,
#                'surface_temperature_celcius': 50},
#               {'confidence': 63,
#                'datetime': '2023-04-20 00:13:00',
#                'latitude': -36.1569,
#                'longitude': 145.6554,
#                'surface_temperature_celcius': 41},
#               {'confidence': 54,
#                'datetime': '2023-04-20 00:13:00',
#                'latitude': -36.6363,
#                'longitude': 144.3033,
#                'surface_temperature_celcius': 40},
#               {'confidence': 76,
#                'datetime': '2023-04-20 00:12:50',
#                'latitude': -37.2212,
#                'longitude': 148.8262,
#                'surface_temperature_celcius': 49}],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.31G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('663d77f75178059695ff609f'),
#  'air_temperature_celcius': 11,
#  'date': '26/4/2023',
#  'hotspots': [{'confidence': 56,
#                'datetime': '2023-04-26 13:26:10',
#                'latitude': -36.5511,
#                'longitude': 146.7819,
#                'surface_temperature_celcius': 34}],
#  'max_wind_speed': 20.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('663d77f75178059695ff60be'),
#  'air_temperature_celcius': 14,
#  'date': '27/5/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.35G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('663d77f75178059695ff60c1'),
#  'air_temperature_celcius': 8,
#  'date': '30/5/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.24G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('663d77f75178059695ff60e3'),
#  'air_temperature_celcius': 11,
#  'date': '3/7/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.20G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('663d77f75178059695ff60fb'),
#  'air_temperature_celcius': 11,
#  'date': '27/7/2023',
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('663d77f85178059695ff6105'),
#  'air_temperature_celcius': 9,
#  'date': '6/8/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('663d77f85178059695ff6119'),
#  'air_temperature_celcius': 11,
#  'date': '26/8/2023',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.28G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  '_id': ObjectId('663d77f85178059695ff6123'),
#  'air_temperature_celcius': 8,
#  'date': '5/9/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.31G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('663d77f85178059695ff6125'),
#  'air_temperature_celcius': 10,
#  'date': '7/9/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  '_id': ObjectId('663d77f85178059695ff612d'),
#  'air_temperature_celcius': 11,
#  'date': '15/9/2023',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.28G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('663d77f85178059695ff6141'),
#  'air_temperature_celcius': 12,
#  'date': '5/10/2023',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.20G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('663d77f85178059695ff6159'),
#  'air_temperature_celcius': 17,
#  'date': '29/10/2023',
#  'hotspots': [],
#  'max_wind_speed': 27.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('663d77f85178059695ff615a'),
#  'air_temperature_celcius': 11,
#  'date': '30/10/2023',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('663d77f85178059695ff616b'),
#  'air_temperature_celcius': 18,
#  'date': '16/11/2023',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.28G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  '_id': ObjectId('663d77f85178059695ff616c'),
#  'air_temperature_celcius': 19,
#  'date': '17/11/2023',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.28G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('663d77f85178059695ff6179'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2023',
#  'hotspots': [{'confidence': 52,
#                'datetime': '2023-11-30 23:25:57',
#                'latitude': -37.635,
#                'longitude': 149.303,
#                'surface_temperature_celcius': 47},
#               {'confidence': 100,
#                'datetime': '2023-11-30 15:38:36',
#                'latitude': -37.591,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 53},
#               {'confidence': 51,
#                'datetime': '2023-11-30 15:38:36',
#                'latitude': -37.59,
#                'longitude': 149.31,
#                'surface_temperature_celcius': 42},
#               {'confidence': 64,
#                'datetime': '2023-11-30 15:38:36',
#                'latitude': -37.633,
#                'longitude': 149.264,
#                'surface_temperature_celcius': 42},
#               {'confidence': 100,
#                'datetime': '2023-11-30 15:38:35',
#                'latitude': -37.585,
#                'longitude': 149.336,
#                'surface_temperature_celcius': 54},
#               {'confidence': 69,
#                'datetime': '2023-11-30 15:38:35',
#                'latitude': -37.58,
#                'longitude': 149.331,
#                'surface_temperature_celcius': 35},
#               {'confidence': 100,
#                'datetime': '2023-11-30 15:38:35',
#                'latitude': -37.583,
#                'longitude': 149.316,
#                'surface_temperature_celcius': 49},
#               {'confidence': 61,
#                'datetime': '2023-11-30 15:38:32',
#                'latitude': -37.38,
#                'longitude': 149.334,
#                'surface_temperature_celcius': 31},
#               {'confidence': 62,
#                'datetime': '2023-11-30 12:22:15',
#                'latitude': -37.602,
#                'longitude': 149.295,
#                'surface_temperature_celcius': 33},
#               {'confidence': 64,
#                'datetime': '2023-11-30 12:22:15',
#                'latitude': -37.598,
#                'longitude': 149.29,
#                'surface_temperature_celcius': 32},
#               {'confidence': 84,
#                'datetime': '2023-11-30 12:22:15',
#                'latitude': -37.596,
#                'longitude': 149.319,
#                'surface_temperature_celcius': 38},
#               {'confidence': 81,
#                'datetime': '2023-11-30 12:22:15',
#                'latitude': -37.63,
#                'longitude': 149.232,
#                'surface_temperature_celcius': 42},
#               {'confidence': 100,
#                'datetime': '2023-11-30 12:22:15',
#                'latitude': -37.644,
#                'longitude': 149.233,
#                'surface_temperature_celcius': 55},
#               {'confidence': 100,
#                'datetime': '2023-11-30 12:22:15',
#                'latitude': -37.642,
#                'longitude': 149.263,
#                'surface_temperature_celcius': 65},
#               {'confidence': 100,
#                'datetime': '2023-11-30 12:22:14',
#                'latitude': -37.634,
#                'longitude': 149.237,
#                'surface_temperature_celcius': 71},
#               {'confidence': 84,
#                'datetime': '2023-11-30 04:35:00',
#                'latitude': -37.384,
#                'longitude': 149.336,
#                'surface_temperature_celcius': 59},
#               {'confidence': 73,
#                'datetime': '2023-11-30 04:35:00',
#                'latitude': -37.389,
#                'longitude': 149.311,
#                'surface_temperature_celcius': 50},
#               {'confidence': 98,
#                'datetime': '2023-11-30 04:34:57',
#                'latitude': -37.605,
#                'longitude': 149.302,
#                'surface_temperature_celcius': 83},
#               {'confidence': 81,
#                'datetime': '2023-11-30 04:34:57',
#                'latitude': -37.627,
#                'longitude': 149.261,
#                'surface_temperature_celcius': 57},
#               {'confidence': 84,
#                'datetime': '2023-11-30 04:34:57',
#                'latitude': -37.623,
#                'longitude': 149.284,
#                'surface_temperature_celcius': 61},
#               {'confidence': 99,
#                'datetime': '2023-11-30 04:34:57',
#                'latitude': -37.6,
#                'longitude': 149.325,
#                'surface_temperature_celcius': 86},
#               {'confidence': 69,
#                'datetime': '2023-11-30 04:34:57',
#                'latitude': -37.61,
#                'longitude': 149.279,
#                'surface_temperature_celcius': 48},
#               {'confidence': 60,
#                'datetime': '2023-11-30 00:21:00',
#                'latitude': -37.637,
#                'longitude': 146.288,
#                'surface_temperature_celcius': 42},
#               {'confidence': 83,
#                'datetime': '2023-11-30 00:20:53',
#                'latitude': -37.608,
#                'longitude': 149.282,
#                'surface_temperature_celcius': 58},
#               {'confidence': 87,
#                'datetime': '2023-11-30 00:20:53',
#                'latitude': -37.62,
#                'longitude': 149.294,
#                'surface_temperature_celcius': 63},
#               {'confidence': 95,
#                'datetime': '2023-11-30 00:20:53',
#                'latitude': -37.618,
#                'longitude': 149.281,
#                'surface_temperature_celcius': 76},
#               {'confidence': 81,
#                'datetime': '2023-11-30 00:20:53',
#                'latitude': -37.61,
#                'longitude': 149.296,
#                'surface_temperature_celcius': 56},
#               {'confidence': 73,
#                'datetime': '2023-11-30 00:20:53',
#                'latitude': -37.603,
#                'longitude': 149.324,
#                'surface_temperature_celcius': 51},
#               {'confidence': 81,
#                'datetime': '2023-11-30 00:20:53',
#                'latitude': -37.602,
#                'longitude': 149.311,
#                'surface_temperature_celcius': 55},
#               {'confidence': 69,
#                'datetime': '2023-11-30 00:20:53',
#                'latitude': -37.6,
#                'longitude': 149.297,
#                'surface_temperature_celcius': 50},
#               {'confidence': 64,
#                'datetime': '2023-11-30 00:20:49',
#                'latitude': -37.382,
#                'longitude': 149.341,
#                'surface_temperature_celcius': 41}],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %% [markdown]
# ## **Task 2.3**

# %% [markdown]
# ##### **Creating Indexes**

# %%
from pymongo import ASCENDING, DESCENDING

#set index models for date and surface temp attributes
climate_col.create_index([("date", ASCENDING)], unique=True)
climate_col.create_index([("hotspots.surface_temperature_celcius", DESCENDING)])

print((list(climate_col.index_information())))
# Out:
# ['_id_', 'date_1', 'hotspots.surface_temperature_celcius_-1']

# %% [markdown]
# ##### **Rationale behind the used indexing**
#
# Simple indexes have been used here by creating indexes for the `date` field of the climate documents and the `surface_temperature_celcius` field of the hotspot documents. Both of these fields have been indexed because they are the most frequently used in queries in the given use case. Most of the queries use date to filter the resulting documents while a lot of queries access values of the surface temperature. Hence indexing both of these fields will improve query execution times for larger datasets as the data retrieval will be faster for the most commonly accessed fields.
#
# The date indexes keys have been sorted in ascending order to allow data to be fetched and studied in a chronological order as given in the dataset. The date indexes also have the unique contraint to ensure that each station produces only 1 climate record on any particular day, thus ensuring consistency. In contrast, the surface temperature index keys have been sorted in descending order because top records with high surface temperatures should primarly be studied for fire predictions.
